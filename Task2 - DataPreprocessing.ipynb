# %% [markdown]
# # DataSet Preprocessing

# %%
import pandas as pd
import numpy as np
import nltk
import string
import re
from nltk.tokenize import word_tokenize
from collections import Counter, OrderedDict
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
df = pd.read_csv("DataSet/Airline-Sentiment-2-w-AA.csv", encoding= 'unicode_escape')

# %%
len(df["text"])
# Out:
# 14640

# %% [markdown]
# ## 1 - Data Cleaning:
# - Replace the mentions with the tag `@mention`
# - Replace URL with the tag `@url`
# - Replace hashtag with the tag `@hashtag`
# - Remove strange characters like \x89ÛÏ that corresponds to apex
# - Replace strange characters and emoji with the tag `@emoji`
# - Punctuation removal
# - Replace numbers with the tag `@number`
# - Convert to lowercase
# - Over space removal

# %%
punctaction = re.sub("@", "", string.punctuation)
punctaction
# Out:
# '!"#$%&\'()*+,-./:;<=>?[\\]^_`{|}~'

# %%
def clean_text(corpus):
    clear_text = []
    for phrase in corpus:
        # Replace the mentions with the tag @mention
        phrase = re.sub("@\S+", "@mention ", phrase)
        # Replace URL with the tag @url
        phrase = re.sub("https*\S+", " @url", phrase)
        # Replace hashtag with the tag @hashtag
        phrase = re.sub("#\S+", " @hashtag", phrase)
        # Remove strange characters
        phrase = re.sub("\x89Ûª|\x89Û\x9d|\x89Ûª|\x89Û÷|\x89Û_", "", phrase)
    
        # Replace strange emoji with the tag @emoji
        phrase = re.sub("\x89\S+", " @emoji", phrase)
        phrase = re.sub("\x95\S+", " @emoji", phrase)
        phrase = re.sub("_Ù\S+", " @emoji", phrase)
        phrase = re.sub("÷\S+", " @emoji", phrase)
        # Replace light emoji like :-D ;D ;p
        phrase = re.sub(":+[';()-/|DPXp]\S*|;+['()-/|DPXp]\S*", " @emoji", phrase)

        # Punctuaction removal
        phrase = re.sub('[%s]' % re.escape(punctaction), ' ', phrase)
        # Replace numbers with the tag @number
        phrase = re.sub("\d+", " @number ", phrase)
        # Convert to lowercase
        phrase = phrase.lower()
        # Replace the over spaces
        phrase = re.sub('\s{2,}', " ", phrase)
        clear_text.append([phrase])
    return clear_text

# %%
cleared_text = clean_text(df["text"])

# %%
cleared_text
# Out:
# [['@mention what @mention said '],
#  ['@mention plus you ve added commercials to the experience tacky '],
#  ['@mention i didn t today must mean i need to take another trip '],
#  ['@mention it s really aggressive to blast obnoxious entertainment in your guests faces amp they have little recourse'],
#  ['@mention and it s a really big bad thing about it'],
#  ['@mention seriously would pay @number a flight for seats that didn t have this playing it s really the only bad thing about flying va'],
#  ['@mention yes nearly every time i fly vx this @emoji worm wont go away @emoji'],
#  ['@mention really missed a prime opportunity for men without hats parody there @url'],
#  ['@mention well i didn tbut now i do @emoji'],
#  ['@mention it was amazing and arrived an hour early you re too good to me '],
#  ['@mention did you know that suicide is the second leading cause of death among teens @number @number '],
#  ['@mention i lt @number pretty graphics so much better than minimal iconography @emoji'],
#  ['@mention this is such a great deal already thinking about my @number nd trip to @mention amp i haven t even gone on my @number st trip yet @emoji'],
#  ['@mention @mention i m flying your @hashtag @hashtag skies again u take all the @hashtag away from travel @url'],
#  ['@mention thanks '],
#  ['@mention sfo pdx schedule is still mia '],
#  ['@mention so excited for my first cross country flight lax to mco i ve heard nothing but great things about virgin america @hashtag'],
#  ['@mention i flew from nyc to sfo last week and couldn t fully sit in my seat due to two large gentleman on either side of me help '],
#  ['i @emoji flying @mention @emoji'],
#  ['@mention you know what would be amazingly awesome bos fll please i want to fly with only you '],
#  ['@mention why are your first fares in may over three times more than other carriers when all seats are available to select '],
#  ['@mention i love this graphic @url'],
#  ['@mention i love the hipster innovation you are a feel good brand '],
#  ['@mention will you be making bos gt las non stop permanently anytime soon '],
#  ['@mention you guys messed up my seating i reserved seating with my friends and you guys gave my seat away @emoji i want free internet'],
#  ['@mention status match program i applied and it s been three weeks called and emailed with no response '],
#  ['@mention what happened @number ur vegan food options at least say on ur site so i know i won t be able @number eat anything for next @number hrs @hashtag'],
#  ['@mention do you miss me don t worry we ll be together very soon '],
#  ['@mention amazing to me that we can t get any cold air from the vents @hashtag @hashtag @hashtag @hashtag @hashtag'],
#  ['@mention lax to ewr middle seat on a red eye such a noob maneuver @hashtag @hashtag'],
#  ['@mention hi i just bked a cool birthday trip with you but i can t add my elevate no cause i entered my middle name during flight booking problems @emoji'],
#  ['@mention are the hours of operation for the club at sfo that are posted online current '],
#  ['@mention help left expensive headphones on flight @number iad to lax today seat @number a no one answering l amp f number at lax '],
#  ['@mention awaiting my return phone call just would prefer to use your online self service option @emoji'],
#  ['@mention this is great news america could start flights to hawaii by end of year @url via @mention '],
#  ['nice rt @mention vibe with the moodlight from takeoff to touchdown @hashtag @hashtag @url'],
#  ['@mention moodlighting is the only way to fly best experience ever cool and calming @emoji @emoji @hashtag'],
#  ['@mention @mention done and done best airline around hands down '],
#  ['@mention when can i book my flight to hawaii '],
#  ['@mention your chat support is not working on your site @url'],
#  ['@mention view of downtown los angeles the hollywood sign and beyond that rain in the mountains @url'],
#  ['@mention hey first time flyer next week excited but i m having a hard time getting my flights added to my elevate account help '],
#  ['@mention plz help me win my bid upgrade for my flight @number @number lax gt sea @emoji @emoji'],
#  ['@mention i have an unused ticket but moved to a new city where you don t fly how can i fly with you before it expires @hashtag'],
#  ['@mention are flights leaving dallas for seattle on time feb @number '],
#  ['@mention i m @hashtag for a good reason you rock '],
#  ['@mention dream @url @url'],
#  ['@mention wow this just blew my mind'],
#  ['@mention @mention @mention after last night @hashtag @hashtag @hashtag @mention i think @mention agree'],
#  ['@mention @mention @mention all were entertaining'],
#  ['@mention is flight @number on it s way was supposed to take off @number minutes ago website still shows on time not in flight thanks '],
#  ['@mention @mention @mention julie andrews all the way though @mention was very impressive no to @mention '],
#  ['@mention wish you flew out of atlanta soon '],
#  ['@mention @mention @mention julie andrews hands down '],
#  ['@mention will flights be leaving dallas for la on february @number th '],
#  ['@mention hi i m so excited about your @number lga gt @emoji deal but i ve been trying @number book since last week amp the page never loads thx '],
#  ['@mention you know it need it on my spotify stat @hashtag'],
#  ['@mention @mention @mention i m lady gaga she is amazing @emoji'],
#  ['@mention @mention @mention carrie '],
#  ['@mention new marketing song @url let us know what you think '],
#  ['@mention @mention @mention julie andrews first but lady gaga wow d me last night carrie meh '],
#  ['@mention i called a @number @number weeks ago about adding @number flights from @number to my elevate they still haven t shown up help '],
#  ['@mention @mention @mention all are great but i have to go with @hashtag @emoji'],
#  ['@mention @mention @mention sorry mary martin had it first '],
#  ['@mention @mention @mention love all three but you really can t beat the classics '],
#  ['@mention flight @number dal to dca @number @number @number @number pm tried to check in could not status please '],
#  ['@mention heyyyy guyyyys been trying to get through for an hour can someone call me please @emoji'],
#  ['@mention hi virgin i m on hold for @number @number minutes are there any earlier flights from la to nyc tonight earlier than @number @number pm '],
#  ['@mention congrats on winning the @mention award for best deals from an airline us @url'],
#  ['@mention everything was fine until you lost my bag'],
#  ['@mention need to change reservation have virgin credit card do i need to modify on phone to waive change fee or can i do online '],
#  ['@mention i emailed your customer service team let me know if you need the tracking number '],
#  ['@mention hi i just booked a flight but need to add baggage how can i do this '],
#  ['@mention your airline is awesome but your lax loft needs to step up its game @number for dirty tables and floors @url'],
#  ['@mention not worried it s been a great ride in a new plane with great crew all airlines should be like this '],
#  ['@mention awesome i flew yall sat morning any way we can correct my bill '],
#  ['@mention or watch some of the best student films in the country at @number @number feet @hashtag @url'],
#  ['@mention first time flying you all do you have a different rate policy for media bags thanks'],
#  ['@mention what is going on with customer service is there anyway to speak to a human asap thank you '],
#  ['@mention what happened to doom '],
#  ['@mention why can t you supp the biz traveler like @mention and have customer service like @mention @hashtag'],
#  ['@mention i ve applied more then once to be a member of the @hashtag crew team im @number interested @hashtag @hashtag g'],
#  ['@mention you re the best whenever i begrudgingly use any other airline i m delayed and late flight @emoji'],
#  ['@mention i have no interesting flying with you after this i will cancelled flight my next four flights i planned @hashtag'],
#  ['@mention it was a disappointing experience which will be shared with every business traveler i meet @hashtag'],
#  ['@mention im having trouble adding this flight my wife booked to my elevate account help @url'],
#  ['@mention can t bring up my reservation online using flight booking problems code'],
#  ['@mention random q what s the distribution of elevate avatars i bet that kitty has a disproportionate share @url'],
#  ['@mention i lt @number flying va but life happens and i am trying to @hashtag my trip jperhi can you help va home page will not let me '],
#  ['@mention why is the site down when will it be back up '],
#  ['@mention you down with rnp yeah you know me '],
#  ['@mention hi i did not get points on my elevate account for my most recent flight how do i add the flight and points to my account '],
#  ['@mention i like the tv and interesting video just disappointed in cancelled flightled flight when other flights went out to jfk on saturday '],
#  ['@mention just landed in lax an hour after i should of been here your no late flight bag check is not business travel friendly @hashtag'],
#  ['@mention why is flight @number redirected '],
#  ['@mention is it me or is your website down btw your new website isn t a great user experience time for another redesign '],
#  ['@mention i can t check in or add a bag your website isn t working i ve tried both desktop and mobile @url'],
#  ['@mention let @number scanned in passengers leave the plane than told someone to remove their bag from @number st class bin @hashtag'],
#  ['@mention what is your phone number i can t find who to call about a flight reservation '],
#  ['@mention is anyone doing anything there today website is useless and no one is answering the phone '],
#  ['@mention trying to add my boy prince to my ressie sf this thursday @mention from lax @url'],
#  ['@mention why must a traveler miss a flight to late flight check a bag i missed my morning appointments and you lost my business @hashtag'],
#  ['@mention check out new music @url'],
#  ['@mention how s a direct flight fll gt sfo have unexpected layover in vegas @number fuel yet peeps next to me bought for vegas flight @hashtag'],
#  ['@mention your no late flight bag check just lost you my business i missed flight and am apt three other people on flight had same exp '],
#  ['@mention amazing customer service again @emoji raeann in sf she s the best @hashtag @hashtag @hashtag'],
#  ['@mention called your service line and was hung up on this is awesome @hashtag'],
#  ['@mention your site is tripping i m trying to check in and i m getting the plain text version i am reluctant to enter any card info '],
#  ['@mention i was scheduled for sfo @number dal flight @number today changed to @number th due weather looks like flight still on '],
#  ['@mention has getaway deals through may from @number one way lots of cool cities @url @hashtag @hashtag'],
#  ['@mention has getaway deals through may from @number one way lots of cool cities @url @hashtag @hashtag'],
#  ['@mention has getaway deals through may from @number one way lots of cool cities @url @hashtag @hashtag'],
#  ['@mention has getaway deals through may from @number one way lots of cool cities @url @hashtag @hashtag'],
#  ['@mention have a great week @emoji @emoji'],
#  ['@mention come back to @hashtag already we need you to take us out of this horrible cold @hashtag @url'],
#  ['@mention should i be concerned that i am about to fly on a plane that needs to be delayed due to a tech stop '],
#  ['@mention is the best airline i have flown on easy to change your reservation helpful representatives amp a comfortable flying experience'],
#  ['@mention and again another rep kicked butt naelah represents your team so beautifully thank you '],
#  ['@mention your beautiful front end design is down right now but it was cool to still book my ticket b c all your back end was secure '],
#  ['@mention love the team running gate e @number at las tonight waited for a delayed flight and they kept things entertaining'],
#  ['@mention use another browser @number amp a brand with a reputation built on tech response doesn t have a cross browser compatible website '],
#  ['@mention and now the flight flight booking problems site is totally down folks what is the problem '],
#  ['@mention i like the customer service but a @number min delay just for connecting passengers seems too long va @number '],
#  ['@mention thanks to your outstanding nyc jfk crew who moved mountains to get me home to san francisco tonight '],
#  ['@mention you have the absolute best team and customer service ever every time i fly with you i m delighted thank you '],
#  ['@mention do you provide complimentary upgrades to first class if there are available seats '],
#  ['@mention i need to change my flight thats scheduled in @number hours and @number min wait time on phone im calling intern help '],
#  ['@mention completely awesome experience last month bos las nonstop thanks for such an awesome flight and depart time @hashtag'],
#  ['@mention how can i watch the @hashtag on my jfk gt sfo flight '],
#  ['@mention is flight @number cancelled flightled and what do i do if it is '],
#  ['@mention you are failing your customers because your check in process does not link to tsa pre check '],
#  ['@mention @mention us too terrible airline just gave us a hotel hotline number and said sorry'],
#  ['@mention has flight number @number from sfo to cabo san lucas arrived yet '],
#  ['@mention @mention your assistance yesterday when u cancelled flightled our flight was to give us a hotel hotline shame on you '],
#  ['@mention another delayed flight @hashtag'],
#  ['@mention i need to register a service dog for a first class ticket from sfo gt dulles the phone queue is an hour or longer pls advise'],
#  ['@mention you rock for making it so i can watch @hashtag on my flight @hashtag @hashtag @hashtag'],
#  ['@mention @mention dropped a track on you @url'],
#  ['@mention always xoxo'],
#  ['@mention why can t we book seats on your flights when we buy them or even during check in creates so much anxiety @hashtag'],
#  ['@mention you d think paying an extra @number bucks rt for luggage might afford you hiring an extra hand at @mention @hashtag'],
#  ['@mention best customer service rep in the world @hashtag takes the cake '],
#  ['@mention can you find us a flt out of lax that is sooner than midnight on monday that would be great customer service @emoji'],
#  ['@mention please provide status for flight @number i cant imagine it s on time as the web indicates dude to weather here and or dallas'],
#  ['@mention you have amazing staff amp super helpful as i just ran the @mention @hashtag they have spoiled me with comfort '],
#  ['@mention i paid the premium to fly you across the country you cancelled flight my flight and offer no check fee or upgrade love sad face @emoji'],
#  ['@mention question is it not possible to book a seat for an infant under @number it s not giving me the option but we want a seat for him '],
#  ['always have it together you re welcome rt @mention @mention you re so welcome '],
#  ['@mention @hashtag home to @hashtag @hashtag @hashtag in @hashtag back to @hashtag @hashtag @url'],
#  [' @mention i don t understand why you need a dm to give me an answer on if you have a damaged luggage policy '],
#  [' @mention does that mean you don t have a policy for destroyed luggage '],
#  ['@mention is there special assistance if i travel alone w @number kids and @number infant priority boarding '],
#  ['@mention thank you for checking in tickets are purchased and customer is happy @emoji'],
#  ['@mention is your website ever coming back online '],
#  ['@mention is flight @number from love field to sfo definitely cancelled flightled for monday february @number '],
#  ['@mention is flight @number out of lga to dfw on time '],
#  ['@mention my drivers license is expired by a little over a month can i fly friday morning using my expired license '],
#  ['@mention having problems flight booking problems on the web site keeps giving me an error and to contact by phone phone is @number minute wait '],
#  ['@mention how do i reschedule my cancelled flightled flights online the change button is greyed out '],
#  ['@mention i rang but there is a wait for @number minutes i can book the same ticket through a vendor fix your site'],
#  ['@mention got a flight we were told for @number @number today checked my email and its for @number @number tomorrow this is unacceptable '],
#  ['@mention our flight into lga was cancelled flighted we re stuck in dallas i called to reschedule told i could get a flight for today @number @number '],
#  ['@mention why don t any of the pairings include red wine only white is offered @emoji @hashtag'],
#  ['@mention is the website down '],
#  ['@mention your site seems a little wonked right now may want to have a look tried on two browsers no css @url'],
#  ['@mention i m disappointed that the agent at the designated silver status check in line @mention closed to assist all pasengers'],
#  ['@mention plans to include austin to its dallas route topnews arab @hashtag @url'],
#  ['@mention is it normal to receive no reply from central baggage @hashtag @hashtag'],
#  ['@mention at logan airport and waiting to checkin for my @number am flight checkin desk not open why '],
#  ['@mention to jump into the dallas austin market @mention @url'],
#  ['@mention beats eps views takes on @hashtag va luv investor s business daily @url'],
#  ['@mention lister to my show my on monday @number @number '],
#  ['@mention to begin dallas austin @hashtag in april @number @number ketr @url'],
#  ['@mention congrats you just got all my business from ewr to sfo lax fuck you @mention fl @number sfo ewr was the clincher '],
#  ['@mention i applied over @number weeks ago haven t heard back and i m flying this week @hashtag'],
#  ['@mention i d love to know what your policy is for damaged luggage '],
#  ['@mention thank you for the follow'],
#  ['@mention too many apologies you r the worse airlines don t even respond to your cudtomers'],
#  ['@mention shame on va for making people spend money in stranded cities when other airlines are landing at jfk who will reimburse me '],
#  ['@mention @mention i dm you'],
#  ['@mention can you please have flights in sjc i have no choice but to fly southwest to vegas @emoji'],
#  ['@mention too bad you say it takes @number to @number days via your confirmation email when i inquired after @number weeks you claim @number to @number weeks '],
#  ['@mention flight from bos gt las tomorrow was cancelled flightled no notification wait times are @number hour will you rebook on another airline '],
#  [' @emoji rt @mention youve met your match got status on another airline upgrade restr @url @url'],
#  ['@mention only way to fly @hashtag @hashtag'],
#  ['@mention if only you guys had flights from cmh '],
#  ['@mention a lot of apologies being thrown out to customers from what i can see very sad thanks for nothing worst airline ever '],
#  ['@mention for all my flight stuff wrong and did nothing about it had @hashtag @hashtag ever'],
#  ['@mention having an issue finding a missing item on a plane can you help me find which airport my plane headed to next '],
#  ['@mention you will match my @hashtag status cool '],
#  [' @emoji met your match got status on another airline upgrade @url @mention @emoji'],
#  ['@mention trying to book a flight with you guys and your website won t let me about to lose my business'],
#  ['@mention you suck '],
#  ['@mention thanks '],
#  ['@mention just dm d same issue persisting '],
#  ['@mention because we never rec d cancelled flightlation notice we were left w no options to fly out of ps driving to la for a red eye mon w kids'],
#  ['@mention trying to book a flight amp your site is down @emoji'],
#  ['@mention you have any flights flying into boston tomorrow i need to be home and you cancelled flightled my flight and didn t do anything'],
#  ['@mention you stink flight cancelled flighted from psp to jfk and no notification or ability to rebook @hashtag @hashtag better'],
#  ['@mention i love your guy s song we re dancing to it for our high school dance revue'],
#  ['@mention your website is down and i m trying to check in '],
#  ['@mention done thank you for the quick response apparently faster than sitting on hold @emoji'],
#  ['@mention nervous about my flight from dc to lax getting cancelled flightled tomorrow just sent you a dm to help me '],
#  ['@mention cool picture of another virginamerica plane off our wing what a site @url'],
#  ['@mention keep up the great work @emoji'],
#  ['@mention my goodness your people @mention field are amazing under pressure @emoji texas @hashtag in crisis please fly me to ny'],
#  ['@mention thanks for a great flight from la to boston pilots did a great job landing in the snow can we go back to la now @hashtag'],
#  ['@mention can you please get me to the new york area before monday afternoon'],
#  ['@mention thanks so much for the awesome support you guys rock '],
#  ['@mention seats in row @number don t recline should mention that on your website @hashtag'],
#  ['@mention flight @number delayed @number hours in la due to mechanical problems handle like pros but you could have tossed us a free drink '],
#  ['@mention why cancelled flight flights today no precipitation to be scared of @emoji'],
#  ['@mention twitter team you guys killed it for rescheduling me asap thank you '],
#  ['@mention you guys charged me @number to reschedule a flight that was then cancelled flighted and are now refusing to refund it what s the deal '],
#  ['@mention cant access your website from safari on iphone @number seems to work on mac and ipad need iphone to add passbook '],
#  ['@mention on ipad and iphone clicking the checkin link in the email i received at @number hrs before flight'],
#  ['@mention your mobile site is broken shows header elevateuser numofpointsavailable @number number points won t let me checkin'],
#  ['@mention i was really looking forward to my flight can you let me know when it will be rescheduled @hashtag'],
#  ['@mention why cancelled flight flight vx @number one sec its delayed on my to airport the next its cancelled flightled gonna email or call me to reschedule '],
#  ['@mention i did it but there was a problem in the link from the email for check in thanks'],
#  ['@mention had to change to another airline to get to dc today why is @mention able to land in dc but not you cost me @number ugh'],
#  ['@mention i was so looking forward to my first flight with you today but it was cancelled flightled along with the subsequent one '],
#  ['@mention when are you putting some great deals from pdx to las or from las to pdx show me your love @url'],
#  ['@mention wish i can afford to fly with you next friday going back home love everything about your airline'],
#  ['@mention how are you gonna have a deal from dallas to dc but no deal from dc to dallas @hashtag'],
#  ['@mention its just a bug report guys'],
#  ['@mention hold times at call center are a bit much'],
#  ['@mention like @url'],
#  ['@mention site down @hashtag'],
#  ['@mention you have the best flight attendant ever @url'],
#  ['awesome rt @mention watch nominated films at @number @number feet @hashtag @hashtag @url'],
#  ['@mention thanks so much '],
#  ['@mention trying to reset my password email never arrives help '],
#  ['@mention the only airline based in silicon valley @hashtag @hashtag @hashtag @mention @url'],
#  ['@mention very nicely done @emoji'],
#  ['@mention im looking forward to watching the oscars on my flight home tomorrow i might even get something bubbly to drink @emoji'],
#  ['@mention what is the reason for the delay of the departure of vx @number from jfk this afternoon '],
#  ['@mention is todays flight from palm springs ca to jfk in ny cancelled flightled '],
#  ['@mention hahaha @emoji you guys are amazing i love you guys @emoji'],
#  ['@mention sounds like fun '],
#  ['@mention any updates on flight @number from jfk gt lax'],
#  ['@mention spruce moose '],
#  ['@mention the css on your site is a @number right now please fix site unusable '],
#  ['@mention we re on flight @number vegas to boston today checked in online but our bag count didn t register can i fix that somehow '],
#  ['@mention classiq luv virgin america greetingz'],
#  ['@mention hi i m trying to do check in but the website is not working i tried @number different browsers and the problem continues'],
#  ['@mention thanks for your great customer service today amp for helping me get all my travel sorted out '],
#  ['@mention thanks guys sweet route over the rockies @hashtag'],
#  ['@mention love the @number s music blasting at gate in @hashtag while waiting for flight to @hashtag only if i could get an iced coffee '],
#  ['@mention the passenger in @number d flt @number that assaulted me shouldn t have flown i trust he s banned crew filed report to @mention '],
#  ['@mention current bug on website shows select departure city when selecting destination city @url'],
#  ['@mention luggage was severely dented missing wheel coming off baggage claim in san luggage agent miranda i think wasn t any help '],
#  ['@mention thank you for the easy itinerary shift for impending weather quick painless amp free '],
#  ['@mention if you d love to see more girls be inspired to become pilots rt our free woaw event march @number @number at abq @url'],
#  ['@mention thanks good times there and back @hashtag the entire flight @emoji @hashtag'],
#  ['@mention beats expectations shares take off santa cruz sentinel @url'],
#  ['@mention any plans to start flying direct from dal to las '],
#  ['@mention big love gratitude mpower w @url werin @hashtag vipswagbags@ @hashtag @url'],
#  ['@mention you re doing a great job adding little luxuries aesthetics that improve the air travel experience thank you keep it up '],
#  ['@mention requested window seat and confirmed window but got stuck in middle seat not a good way to treat silver member @emoji'],
#  ['@mention grand budapest hotel @hashtag'],
#  ['@mention this is what you missed @mention next trip to the @number '],
#  ['@mention @hashtag i paid for direct flight on purpose not to have to stop for fuel exhausted frequent flier and nothing for inconvenience '],
#  ['@mention there is something wrong with you website in safari iphone'],
#  ['@mention thanks for gate checking my baggage on your full flight dfw lax @number and giving me early boarding too @hashtag'],
#  ['@mention already checked in so the page expired @emoji'],
#  ['@mention boo for a not refunding a seat upgrade fee i did not want to buy in the first place '],
#  ['@mention shares rise on q @number financial results usa today @url'],
#  ['@mention adds pillows instead of lie flat seats in first class arms race @url'],
#  ['@mention i see what you did there @emoji'],
#  ['@mention way to take advantage of @hashtag @emoji'],
#  ['@mention you know i m flying virgin for the fight @hashtag'],
#  ['@mention your inflight team makes the experience @hashtag'],
#  ['@mention cutest salt and pepper shaker ever just when i think you guys can t get any better you just do @url'],
#  ['@mention moved my seat with no notice better seat is cabin select not behind the row i selected @emoji @hashtag'],
#  ['@mention shares up on @number q results @mention @url'],
#  ['@mention fav airline'],
#  ['@mention we have a hot female pilot sweet dca to sfo @emoji'],
#  [' @emoji @emoji when are you guys going to start flying to paris @mention @mention you re welcome '],
#  ['@mention what is your policy on flying after surgery i am still waiting for answer so i can tell me doctor '],
#  ['@mention already contacted central baggage amp sent dm @mention is charging me for the dress that was in the lost suitcase @hashtag'],
#  ['@mention thank you '],
#  ['@mention is there anything going on with the website i ve been getting a lot of errors past @number minutes '],
#  ['@mention i think i left something on the plane yesterday who do i call ah '],
#  ['@mention i need you to follow back in order to dm '],
#  ['@mention need to start flying to @mention @emoji'],
#  ['@mention they told to check with the airline regulation first so that is why i contacted you '],
#  ['@mention @mention i have just checked in flight to sfo from lax amp been told as atlantic flying club gold i get no benefits '],
#  ['@mention husband and i ordered three drinks via my screen and they never came awesome '],
#  ['@mention soooo are you guys going to leave the seatbelt light on all flight you can barely call this turbulence @emoji'],
#  ['@mention what is your policy on flying after surgery '],
#  ['@mention posts second consecutive full year net profit @mention @url'],
#  ['@mention funny story your website is broken you have missing javascript and stylesheets on the checkin process i dislike this '],
#  ['@mention would love to do more for virgin just like i do for @mention '],
#  ['@mention results handily exceed forecasts @mention @url'],
#  ['@mention i applied for a position in @mention and i was wondering if you guys received my application '],
#  ['@mention achieves a second year of profitability despite revenue pressure @mention @url'],
#  ['@mention gives positive outlook but sees increased competition @mention @url'],
#  ['@mention i m trying to check into my @number @number am ct flight tmm on the desktop website and it s not working some sort of caching bug sos'],
#  ['@mention weather delays gt next few weeks @emoji @hashtag @hashtag @hashtag'],
#  ['@mention @mention check the website before you go to the airport '],
#  ['@mention do you guys know your check in links from emails are broken @url'],
#  ['@mention pilot says we expect a choppy landing in nyc due to some gusty winds w a temperature of about @number degrees amp w the windchill @number '],
#  ['@mention loved it can t wait for monday s return flight mostly just to watch the inflight safety video again @hashtag'],
#  ['@mention lost my luggage @number days ago on flight vx @number from lax to iad amp i m calling every day no response please give me back my stuff'],
#  ['@mention the flight booking problems section of your website seems to be broken on chrome might wanna look into that '],
#  ['@mention hi just wanted to see if you have any new routes planned this year for newark love flying you guys and hope to do so more '],
#  ['@mention i mean probably inappropriate while on board but it s on '],
#  ['@mention happy to spend the day together let s do this '],
#  ['@mention is saving my sanity right now @url'],
#  ['@mention missed my flight how does standby work '],
#  [' @mention they were very understanding and helped me out thx @hashtag'],
#  ['@mention brought it all the way across the country today i see @url'],
#  ['@mention thank you i absolutely will @emoji'],
#  ['@mention looks like a broken link for your assets @url'],
#  ['@mention are you ready let s say it together noooo turbulence today @emoji'],
#  ['@mention the manage itinerary section of your website seems to be broken for me @url'],
#  ['@mention can t check in your site looks like this every time it loads @url'],
#  ['@mention can u help this @emoji @mention needs urgent treatment in @emoji old battling cancer could u help with flights @emoji @hashtag'],
#  ['@mention may start service to hawaii from @hashtag this year @url @hashtag'],
#  ['@mention other carriers are less than half price for a round trip fare i am stunned @url'],
#  ['@mention wtf is happening in pdx late flight march such that one way from sfo is @number '],
#  ['@mention add dtw and i m sold '],
#  ['@mention how about some free drinks on the flight back for the free promo '],
#  ['@mention @mention thanks '],
#  ['@mention momma i made it @emoji'],
#  ['@mention please contact me about portfolio left on flight vx @number from jfk to sfo tonite seat @number am need it returned call @number @number @number '],
#  ['@mention help i was on flight @number from jkf tonight seat @number c left portfolio need it back '],
#  ['@mention @mention seattle bound wifey got me the duffle for vday she s a keeper holla @url'],
#  ['@mention my luggage is gone i ve filed my paperwork promised a call email still no resolution or response from central luggage '],
#  ['@mention debbie baldwin gave a @hashtag performance of the safety demo this evening on vx @number @hashtag @hashtag @hashtag'],
#  ['@mention thanks '],
#  ['@mention thanks for taking care of @mention on her flight @hashtag @hashtag'],
#  ['@mention thanks for the lovely soft views @hashtag @hashtag to @hashtag @url'],
#  ['@mention i requested a mileage challenge for status several weeks ago online but haven t heard back how do i get help with this '],
#  ['@mention just trying to book tickets to nyc and facing super fun broken styling don t worry i ll keep trying @emoji'],
#  ['@mention many thanks for the follow @hashtag @hashtag @hashtag @hashtag looking for any help @emoji @emoji @emoji @url'],
#  ['@mention nice lofty view @mention @hashtag @url'],
#  ['@mention applied for status match on feb @number got confirmation email same day still no news though you guys have dropped ball late flightly @emoji'],
#  ['@mention is my new go to airline'],
#  ['@mention @mention @mention @mention can you help @hashtag in need of some help in @hashtag @emoji @url'],
#  ['@mention i adore you and am so looking forward to my flight to austin in two weeks '],
#  ['@mention i was so glad it was mentioned i took my first virgin flight a few years back and it was a transformative experience '],
#  ['@mention flight booking problems flight to uphold my status match do taxes on ticket count as earned status points @hashtag @hashtag'],
#  ['@mention trying to check in but looks like your site is down '],
#  ['@mention spending my birthday night with you dal dca get me home '],
#  ['@mention sent a couple messages to the email you provided but to no avail will try again next year cheers '],
#  ['@mention first time flying virgin went to @hashtag thanks for the smooth ride easily my new fav airline '],
#  ['@mention seriously though will there not be direct flights from sfo fll in may '],
#  ['@mention it s fine already done with my purchase but you should try it just go most of the way through then go back @number '],
#  ['@mention not really the experience i was hoping @number i ws forced @number check in a small carry on w nothing but empty cabin space on board'],
#  ['@mention wjere is our luggage @hashtag slow at lax'],
#  ['@mention to jump into the @hashtag @hashtag market @url'],
#  ['@mention i spoke with a representative that offered no solution i am a loyal customer who flies on @mention as well'],
#  ['@mention i am deeply disappointed that your birthday promo was not applied to a trip i booked mere days before i received the email'],
#  ['@mention what happened to direct flights from sfo fll looking in may only see connecting @hashtag @hashtag'],
#  ['@mention can you help left my blazer in kooples jacket bag at @number rd row second seat from right gate @number t @number lax flight to sfo'],
#  ['@mention partners with @mention checkout as mobile payment method to help boost mobile conversion rates @hashtag @hashtag @hashtag'],
#  ['@mention just promoting the product is all had a problem with southwest and recommend noneother than the best @url'],
#  ['@mention love you guys but pls get some direct routes las to aus '],
#  ['@mention i would like help with some flights please '],
#  ['bruh @emoji @mention turn down for what @hashtag'],
#  ['@mention of course i work for @mention and i m obsessed with the entire virgin family '],
#  ['@mention ok first time flying with you tonight @emoji'],
#  ['@mention digging the swanky pink mood lighting during the flight from nyc to sfo just needs a cabaret singer think about it '],
#  ['@mention done but i need the receipt asap could you please help @hashtag'],
#  ['@mention i have @number d and @number d embossed badges and patches superior to the ones you are currently using @url'],
#  ['@mention on vx @number from jfk to la dirty plane not up to your standards '],
#  ['@mention on flight vx @number headed to la from jfk dirtiest va plane i have ever been on sad for a great airline '],
#  ['@mention got it squared away someone picked up as soon as i tweeted should have tweeted sooner @emoji'],
#  ['@mention your avis rental continue button doesn t work on your website to book car tried @number times on phone this sucks '],
#  ['@mention delayed to @number @number '],
#  ['@mention currently in minute @number of being on hold with cust service do i need to do anything to add a lap child to my reservation '],
#  ['@mention adds pillows instead of lie flat seats in first class arms race @url by @mention '],
#  [' @emoji @mention of course have fun celebrating thanks happy chinese new year '],
#  ['@mention flight booking problems last second flight for next week from sfo to san any chance you want to gift me a promo code since i love you guys'],
#  ['@mention comenity bank is a joke please change nothing but constant problems with this bank'],
#  ['@mention i just did how can i dm do u have to also add me '],
#  ['@mention for my grandma ella s @number th she would lt @number a bday greeting from your flight crew she was a stewardess for eastern airlines '],
#  ['@mention just bought tix for atx dallas route thanks for adding that love yr airline amp yr website is best transactional site ever'],
#  ['@mention anytime sugafly '],
#  ['@mention gave a credit for my late flight flight yesterday great service that s a wow moment unexpected gesture '],
#  ['@mention i need a receipt for a flight change can you send one '],
#  ['@mention i submitted a status match request a while back and still havent heard im flying on monday can you look accelerate '],
#  ['@mention had me at their safety video @url loved my first cross country flight @hashtag @hashtag'],
#  ['@mention that doesn t look to fat to me it looks yummy '],
#  ['@mention ceo says @hashtag amp @hashtag have strayed from low cost model @url'],
#  ['@mention a brilliant brisk am in boston in cue for vx @number @url'],
#  ['@mention atlantic ploughs a lone furrow in the @hashtag @url @mention '],
#  ['@mention atlantic ploughs a lone furrow in the @hashtag @url @mention '],
#  ['@mention atlantic ploughs a lone furrow in the @hashtag @url @mention '],
#  ['@mention omg omg @emoji nonstop dallas to austin on virgin @emoji'],
#  ['@mention your planes are really pretty just thought u should know that @emoji'],
#  ['@mention when are you flying to hawaii'],
#  ['@mention i m pulling my hair out trying to book a flight with u your site doesn t work on iphone or ipad don t have a computer @hashtag'],
#  ['@mention thank you'],
#  ['@mention can i get some help with a support ticket it s been @number days incident @number @number thank you '],
#  ['@mention good to be home @hashtag @hashtag @url'],
#  ['@mention i cannot even open my laptop in seat @number c and i paid a premium for this let me out of here '],
#  ['@mention i am in seat @number c and i cannot even open my laptop and i paid extra for this seat '],
#  [' @mention if only you guys were starting those flights at the end of the month guess im still road tripping on feb @number '],
#  ['@mention thanks for that been needing a way to make those austin trips from dca and now you ve come through '],
#  ['@mention announced new route to austin w fares from @number way @url'],
#  ['@mention really sprint i thought you guys were kewl @number @number '],
#  ['@mention this is too cool never been on ur planes but now i will '],
#  ['@mention you should have @number dollar lax las fares '],
#  ['@mention great well deserved '],
#  ['@mention fyi the info@mention email address you say to contact in password reset emails doesn t exist emails bounce '],
#  ['@mention status match @number weeks have gone by and no news flt next week hope flt will count towards requirement cust svc no help '],
#  ['@mention your website sucks donkey dicks just thought you should know all best '],
#  ['@mention you should still develop an app then you will be my favorite airline '],
#  ['@mention all crap channels which is why i pay to watch uk tv'],
#  ['@mention got it all set thanks '],
#  ['@mention no a s channel this year '],
#  ['@mention only thing i see on passbook is virgin mobile mexico how do i integrate '],
#  ['@mention giants and virgin america a match made in heaven '],
#  ['@mention thank goodness also see you friday nwk gt sf boom '],
#  ['@mention how come you don t have an iphone app still using and making me waste paper '],
#  ['@mention your back of seat entertainment system does not accept credit cards that have an apostrophe in the surname @hashtag'],
#  ['@mention when will vx use all @number lga slots instead of @number today adding aus makes this less likely @emoji'],
#  ['@mention is helping me step up my @mention game @hashtag @hashtag @url'],
#  ['@mention i luv ur people and product @number thing is y do u charge for herbal tea but not black tea i m not a caffeine drinker'],
#  ['@mention thank you see y all soon i m excited to see the expansion of destinations spread those wings '],
#  ['@mention announces new nonstop connecting @mention amp @mention @number intro @url @url'],
#  ['@mention adds austin dallas love field route @url @url'],
#  ['@mention sad to learn you no longer fly sfo gt phl hope it returns '],
#  ['@mention can you tweet me the cancelled flight chng fee for a flight or can i rebook under one of your affiliates if so who are afiliates '],
#  ['@mention has the most incredible customer service i ve ever experienced so refreshing '],
#  ['@mention now when will we see virginamerica come to philadelphia phl '],
#  ['@mention am i dreaming did you really just open up a route between dallas and austin and does this mean houston might be next '],
#  ['@mention omg finally'],
#  ['@mention to start @number xweekly @hashtag flights from to @hashtag @mention @hashtag on @number apr @hashtag'],
#  ['@mention nice to see you expanding in texas but don t forget about us here in @hashtag i would love to see more flights out of here '],
#  ['@mention kinda sucked my earphone jack didn t work on my flight they may want to look into that for future passengers'],
#  ['@mention very poor experience first computer problem now seat malfunction stuck missing meeting in san diego '],
#  ['@mention to battle @mention on @mention route @url via @mention '],
#  ['@mention @hashtag the dal aus route makes my day '],
#  ['@mention awesome deals dal aus for only @number each way @url'],
#  ['@mention i miss the @hashtag in san jose'],
#  ['@mention love it taking @mention on in their backyard consumers win when biz competes '],
#  ['@mention @emoji is flying from love to austin now that is most excellent news '],
#  ['@mention can we make every vx plane with @hashtag why should austin be the only one getting nerd love '],
#  ['@mention please add more frequency to pdx portland'],
#  ['@mention congrats vx on the new route @emoji'],
#  ['@mention i tried that you offered to charge me an additional @number k for a new ticket or be stranded until thurs @number st time last time '],
#  ['@mention @mention can u help with flights to get a @number y old battling cancer who needs treatment in @emoji @mention @emoji @emoji @emoji'],
#  ['@mention never had a bad experience before but this one took the cake now extortion for carry on items as well '],
#  ['@mention had to spend @number hours worrying that items in carryon would be broken stolen since i couldn t carry them on plane or lock bag '],
#  ['@mention all of group e was told there was no more room in the bins when i got on the plane was room for at least @number bags in my row '],
#  ['@mention thanks for making my flight from lax to jfk a nightmare by forcing me to check my carry on bag at the gate @number '],
#  ['@mention i have lots of flights to book and your site it not working i ve been on the phone waiting for over @number minutes '],
#  ['@mention i am all about the in flight artisanal cheese and wine pairing '],
#  ['@mention does virgin america fly direct from seattle to nyc or boston '],
#  ['@mention that s classy '],
#  ['@mention i m sure a lot of your @number and @number jfk lhr flights go a lot faster than @number mph with a strong tailwind '],
#  ['@mention now it s just t minus @number minutes until my elevate a silver upgrade window opens @hashtag @emoji'],
#  ['@mention save some for @number tomorrow am '],
#  ['@mention why is it taking @number years to fly home to dallas get your shit together '],
#  ['@mention @mention club virgin is bumping in new york @url'],
#  ['@mention @mention would have been a rough trip but luckily we were on a @hashtag flight @hashtag'],
#  ['@mention is that @hashtag'],
#  ['@mention please come to minneapolis st paul '],
#  ['@mention yes fyi my bff'],
#  ['@mention another perfect flight how come on your planes the sun visors can stay down other carriers make you raise them '],
#  ['nice rt @mention the man of steel might be faster but we have wifi @emoji just saying @hashtag @url'],
#  ['@mention i love the dancing little richard cool beans '],
#  ['@mention i dont use passbook i still love you though lt @number @emoji ill just use my email in the future '],
#  ['@mention thanks for the free birthday points y all are all right with me '],
#  ['@mention do you have an application for ios was looking and only saw virgin mexico @emoji lt @emoji'],
#  ['@mention man of steel flies to more cities though and with more frequency too '],
#  ['@mention thanks so much for sharing just added it to my site @url'],
#  ['@mention good point '],
#  [' @mention i heard he has a virgin mobile hotspot @emoji'],
#  ['@mention you got cheese plate flights too '],
#  ['@mention on all your flights '],
#  ['@mention dad on segway is the best part of this whole infographic '],
#  ['@mention are there any plans for a short haul airline in europe would defiantly fly with you guys @emoji'],
#  ['@mention wifi and better seating '],
#  ['@mention how come abc is the only one of the network channels you don t have '],
#  ['@mention started my flight with a scolding for using an overhead bin that was then offered to the person seated next to me '],
#  [' @mention not only was it great but you return my calls the day after couldn t ask for more @hashtag'],
#  ['@mention while other airlines weren t cancelled flighting flights into bos and helping their customers get home virgin was saying good luck '],
#  ['@mention dear virgin customer while you re stranded in sf for @number days amp @number cost we ll do the very least we can to accommodate you '],
#  ['@mention should use this in their next airline commercial lol @url'],
#  ['@mention grouping virgin in with the others now bos weather has exposed their actual cus serv model never flight booking problems with virgin again '],
#  ['@mention as one of the travelers affected by the boston storm i m shocked at virgin s complete apathy toward their customers '],
#  ['@mention umm so no reason as to why this is is there someone different i should contact or contact me to get a definitive answer '],
#  ['@mention trying to make the change in advance not just @number hours prior tried it online earlier and it wanted @number in change fees '],
#  ['@mention so loyal that i m driving to @hashtag from @hashtag to fly virgin since you cut @hashtag flights @emoji'],
#  ['@mention any way to change from main cabin to main cabin select on same flight without paying a change fee penalty '],
#  ['@mention you guys are perfect as always lt @number @hashtag'],
#  ['@mention thanks y all have some of the best customer service left in the industry '],
#  ['@mention can you give me silver status for @number months '],
#  ['@mention really wish you d fly out of @hashtag @mention those fares are amazings'],
#  ['@mention mood lighting on point @emoji reclining my seat kickin up my feet @emoji'],
#  ['@mention my flight @number scheduled for @number pm departure still says on time but no plane at gate any update on how long of a delay '],
#  ['@mention my group got their cancelled flightlation fees waived but i can t because my ticket is booked for @number @number your reps were no help either @emoji'],
#  ['@mention are there any sign up bonuses to enroll in elevate '],
#  ['@mention just got on the @number pm in newark home to la your folks at ewr are incredible @hashtag'],
#  ['@mention morning if i have a question regarding elevate points amp flights can i dm you '],
#  ['@mention still waiting to see @mention @emoji'],
# ...
#  ['@mention despite shaky connections looks like i ll get home tonight great job @mention was touch and go for a while '],
#  ['@mention @url however is completely under your control @emoji price was and still is displayed on @url'],
#  ['@mention the aircraft closest to gate was for the other flight and the one closest to our gate was going to chicago '],
#  ['@mention can you tell me how to file a claim for clothing that had to be purchased '],
#  ['@mention comically on the return flight from ase there were two united flights boarding at adjacent gates and not clear which plane to board'],
#  ['@mention grk @number m is the file reference'],
#  ['@mention we would how do i contact you to discuss a few poor experiences with customer service but would give it a shot '],
#  ['@mention ua @number pacific rim and date night cut out not constantly or randomly but one spot repeatably '],
#  ['@mention been trying since @number to file a report '],
#  ['@mention i send an email about my bad experience and you send back a generic response yet another reason why i ll never fly with you again '],
#  ['@mention my mom left her kindle on flight @number today burgundy case with a light seat @number d did anyone find it '],
#  ['@mention here is the ticket @number please refund my unnecessary upgrade fee'],
#  ['@mention is horrible they lost our carseat and expect us to use a loner carseat safety regulations say it s illegal to use a used car seat'],
#  ['@mention thank you '],
#  ['decisions decisions @mention @mention we d love for you to try our service we offer status match too @url kp'],
#  ['need more info on that @mention @mention we have great amenity kits pj s not included we status match aa kp'],
#  ['@mention i don t care that a @mention link showed me a wrong price on your site @emoji your site amp responsibility to ensure correctness '],
#  ['@mention do you have any flights with lie flat seating from stl to pdx around the date of march @number '],
#  ['@mention he needs to get to home the @number th they re telling him it ll be the @number th @ night is there compensation or anything that can be done '],
#  [' @emoji @mention the baggage fee is waived for premier members please see @url jp what s the point of membership '],
#  ['@mention wonderful bag claim people finally have my bag but why did i catch earlier flight original flight just landed @hashtag'],
#  ['@mention dmed you thank you'],
#  ['@mention thanks we ll be in touch '],
#  ['@mention thanks to karen salisbury at iah for amazing customer service found my daughter s bag lost on ua @number made her day '],
#  ['@mention @number days late flightr and my bag has not left iad united is not helping at all everyone tells me a different story'],
#  ['@mention @mention hi when do direct flights from houston to reno begin don t see any days in march '],
#  ['@mention like continental s chicken feat fairs'],
#  ['@mention can you assist with current flight status for flt @number out of dfw tomorrow at @number @number am '],
#  ['@mention i left my comment with customer care thanks for contacting me '],
#  ['@mention how do you lose a gate checked bag den to ord direct flight ugh '],
#  ['@mention caught earlier flight to ord gate checked bag and you ve lost it at o hare original flight lands in @number minutes @hashtag'],
#  ['yes thanks so much @emoji @emoji @mention we see you spoke with our reservations team and they ve reinstated the flight thanks ey'],
#  ['@mention captain on behalf of the front office welcome on board never heard that before i laughed hard @hashtag'],
#  ['@mention can you please follow for a dm on a missing bag '],
#  ['@mention to be clear on my luggage comment i am referencing the photo attached flight @number to jac @url'],
#  ['@mention these are great fares '],
#  ['@mention i left an item on the plane and have been calling non stop and no one has been answering can you please help'],
#  ['@mention awesome i ll book my next christmas vacatinn this december any other ways you want to devalue mileage plus '],
#  ['@mention what s a good number to call to speak with someone about how you can fix what you did to @number people and their luggage on saturday '],
#  ['@mention thank u secured room for the night thx to very helpful customer service rep n dorns i thanked her can u @number @hashtag'],
#  ['@mention where s my damn bag '],
#  ['@mention well someone should tell that to the employees at the denver baggage claim still no bag '],
#  ['@mention greetings ua club member here any idea if i can use the air canada lounge at yvr flying ua tomorrow '],
#  ['@mention how is mexico not international from the us '],
#  ['@mention diverted and missed our connecting flight was just told that my bag is on it s way to msy if you only had people that cared'],
#  ['@mention male agnt in las threatens canadian cust when cust takes pic of him at gate after agents announce can t help rebook @hashtag'],
#  ['@mention @mention we just want to go home tonight why did you cancelled flight the last leg of our reserv w out our permission @hashtag'],
#  ['@mention stressed and rude agents overwhelmed by delyd flight las den @number yelling at several people not pretty this is @hashtag'],
#  ['@mention landed in boston at @number last night the @number hours of traveling was rough tho '],
#  ['@mention fail you cancelled flightled our flight frm gjt and then used our reserv home to iah from sea for reflight booking problems w out our permission @hashtag'],
#  ['just sent thank u rt @mention @mention please dm your confirmation number if reflight booking problems is needed thank you ey'],
#  ['@mention has made my no fly list other airlines wait when connector late flight stuck in iah '],
#  ['@mention so whats the deal do u provide voucher for overnight or am i cozy on the floor at @hashtag @hashtag @hashtag @hashtag'],
#  ['@mention also the mere fact that i have to go online to issue a statement vice calling and talking to some directly is one good example '],
#  ['@mention thank you i flew into newark from vail eagle '],
#  ['@mention i have a weekend of dealing with your company that would say otherwise '],
#  ['@mention now what @url flight was gone when i got off plane @hashtag @hashtag'],
#  ['@mention the proper response sorry for your wait what flight were you on so we can look into the issue that s how @mention would handle '],
#  ['@mention your customer service is terrible stood inline @number hours no flights and @number hours late flightr still no bag @hashtag'],
#  ['@mention please upload the march on demand entertainment listing on your website @emoji'],
#  ['@mention so you are inadequate by accident '],
#  ['@mention @mention @mention @ denver international airport @url'],
#  ['@mention thank you for responding so quickly with a helpful tool @mention '],
#  ['@mention boarding time shows @number min and your gate agent started at @number showed up at @number @number and they had to check bag @url'],
#  ['@mention agent in las letting @number customers know they can t help them rebook delayed flight to den @hashtag @url'],
#  ['@mention empathizes w my disappointment that @number stclass flight w nonworking entertainmnt is worth @number @hashtag @url'],
#  ['@mention and when that doesn t work '],
#  ['@mention did you have seen my message today about a mcdonnell douglas dc @number model i will hear it if you read it goodnight now'],
#  ['@mention searched for mileage tickets to bom couldn t find a single one is saver awards i see how you play earn miles but can t use them '],
#  ['@mention flight arrives @number minutes early but then have we to wait for an hour for our bags '],
#  ['@mention that s not the issue the fact that no one even called despite promises to confirm the bag s location is '],
#  ['@mention what s a girl gotta do to get a flight name change when she bought one for a mean ex boyfriend and needs a girl s trip stat '],
#  ['@mention thank you we are signed up for notifications we shall watch and wait @emoji'],
#  ['@mention still waiting to hear back my wallet was stolen from one of your planes so would appreciate a resolution here'],
#  ['@mention i would love if someone could get me back to austin tonight and i do not wish to wait til tomorrow morning '],
#  ['@mention or @mention has lost my baggage heard different things from different employees of @mention @mention has said nothing '],
#  ['@mention cs thinks that miles can repair the damage done it will be interesting if they travel in @mention and exp the worst flight ever '],
#  ['@mention i have a @number flight out of dfw on tuesday how far in advance will you give notice if cancelled flightled '],
#  ['@mention i am signed up for notifications this is the first trip i was not updated on not sure why this happened '],
#  ['@mention thank you took care of everything and made it right that s the experience i m used to opened the app to find flight changed '],
#  ['@mention that is not in line with your responses here and now i m waiting until tomorrow morning because all the flights are overbooked '],
#  ['@mention i took the exact same aircraft in to lax @number days ago it fit no problem the agent today told some nonsense about a policy change'],
#  ['@mention your helpful agents in club helped i am just out baggage fees and a night of my life stop doing business with @mention '],
#  ['@mention never heard of this @url'],
#  ['@mention doesn t charge ticket change fees do they not incur the same mysterious costs that you incur @mention '],
#  ['@mention exhausted amp frustrated link to a fb post abt my travel issue @url'],
#  ['@mention i was denied getting on the plane w o getting the chance to prove it fits i m not a rookie read my bio '],
#  ['@mention that s exactly the point it fits i m premier access boarding group @number this was a return ticket i ve been doing this for @number yrs'],
#  ['@mention i ve never experienced worst customer service placing blame on codeshare partners and not assuming responsibility is unacceptable'],
#  ['@mention currently on board so not now check in was terrible staff rude expensive luggage thrown around etc '],
#  ['@mention fucked up then voided my ticket and kept my money not even an apology i will never fly with your airline again @hashtag'],
#  ['@mention has the worst customer svcs this kevin rep at call center must be investigated my baggage s lost and there s no help but argument '],
#  ['@mention should not sell tickets for @mention on @url has terrible service and ua staff cannot reach silver'],
#  ['@mention just got demoted from gold cuz my hubby got @number of the pqd tho there were enuf spent for @number golds @hashtag'],
#  ['@mention thank you '],
#  ['@mention when will direct flights from belfast intl to newark resume from their winter break thanks '],
#  ['@mention my favorite way to travel thank you @url'],
#  ['@mention yes after this awful weather it appears i can get home'],
#  ['@mention yes lots you have terrible customer service at newark and despite raising a complaint there we were ignored hence the tweet'],
#  ['@mention lovely new plane from lga to ord but no power outlets '],
#  ['@mention but if i tweet the id number won t that reveal my home address to anyone on the web '],
#  ['@mention i filed a delayed bag report on saturday my flight was cancelled flightled and i never went anywhere '],
#  ['@mention the person is currently bettween gates @number a and @number in lax'],
#  ['@mention i need it there before she lands so she can have the ewr baggage claim file to have it sent but the employee has not droppeditoffyet'],
#  ['@mention rarely ceases to amaze for the worse i hope this is the last time i have to fly with you '],
#  ['@mention thank you for the quick response but i cannot dm you until you follow me as well'],
#  ['@mention icloud it is not there yet please help @number @number @number '],
#  ['@mention i need the phone number to baggage claim in lax my mom left her phone and someone called saying they would put it there but on'],
#  ['@mention i did no response back'],
#  ['@mention this is atrocious customer service '],
#  ['@mention will not have to honor absurdly low mistake fares @url vì a @mention '],
#  ['@mention @hashtag delayed departure to check bags at gate claiming space filled and walk on to open spaces a delay @hashtag'],
#  ['@mention you cancelled flighted our flights for no reason amp now we have been on the phone for an hour on our vacation why '],
#  ['@mention @mention that s your response shaking my head back and forth with a tsk you can do better from customer service to your apology'],
#  ['@mention thanks it s @number k miles from rtb to europe to do a multiple destination so we could stop over in us on way way back mileage diff '],
#  ['@mention of course i did the bag should be here by now @emoji @hashtag'],
#  ['@mention you are the worst i will avoid you like the plague '],
#  ['@mention is the worst airline in the world '],
#  ['@mention someone needs to dm me and resolve this correctly extremely disappointed with the service i received terrible management '],
#  ['@mention premier gold desk changes flight waives fees gives me wrong flight now jana acosta in salt lake refuses the same service angry '],
#  ['@mention i will give you one thing you are consistent but unfortunately you are consistent at not doing your job well @hashtag'],
#  ['@mention i will but right now i m to angry'],
#  ['@mention first time flying with united also last time @hashtag back to @mention for me @hashtag @hashtag @hashtag'],
#  ['@mention i used to be a committed @hashtag flyer until merger i remember now why i switched to @mention @hashtag'],
#  ['@mention the least you could do is offer me a ticket in coach instead of just cancelled flighting my reservation because of your glitch @hashtag'],
#  ['@mention i m saying i made the flight but with poor non communication unaccounted for lost time amp lots of frustrated flyers standing around'],
#  ['@mention i think dm would be better'],
#  ['@mention gate announcement states delay due to maintenance yet app says late flight arriving aircraft tell the truth @mention '],
#  ['@mention you are easily the worst company i have ever experienced you have lost someone s personal possessions amp you couldn t care less '],
#  ['@mention how can your app show arriving aircraft is early but departing flight is delayed due to late flight arriving aircraft @mention '],
#  ['@mention already did that at the airport and @number hrs late flightr its still not here you guys are really killing me today trying to stay positive '],
#  ['@mention once united s service levels reaches those of etihad or lets be more realistically lufthansa then ill consider it again'],
#  ['@mention really someone called in sick and then someone forgot to call a replacement now an hour late flight to take off @hashtag'],
#  ['@mention asked flight attendant what typical compensation would be amp says we might get free tv @hashtag'],
#  ['@mention done'],
#  ['@mention thank you jh appreciate the prompt responses me and other passengers will be doing so '],
#  ['@mention has been such a disappointment today simply put rather unpleased with things currently flight delayed cant wait to just get home'],
#  ['@mention during the same round trip my non english speaking friend was stranded twice for @number hours each time most staff members were rude '],
#  ['@mention found a group of people who actually hates people more than isis thats right united airlines '],
#  ['@mention nope walked up amp down the orf terminal amp not a united agent to be found showed up @ last minute to board us many panicked people'],
#  ['@mention thank you'],
#  ['@mention by the time i finally get to dallas i could have driven with less frustration and cheaper '],
#  ['@mention i m trying to get to my final destination we need compensation just about @number hrs of personal time wasted '],
#  ['@mention that guy really has no customer service clue could have spent effort clearing bins for rollerboards instead of art projects in mine '],
#  ['@mention he has no priority and iove it'],
#  ['@mention pleased to be a premier platinum'],
#  ...]

# %%
df['cleared_text'] = np.array(cleared_text)

# %%
df['cleared_text']
# Out:
# 0                             @mention what @mention said
# 1        @mention plus you ve added commercials to the ...
# 2        @mention i didn t today must mean i need to ta...
# 3        @mention it s really aggressive to blast obnox...
# 4        @mention and it s a really big bad thing about it
#                                ...
# 14635    @mention thank you we got on a different fligh...
# 14636    @mention leaving over @number minutes late fli...
# 14637    @mention please bring american airlines to @ha...
# 14638    @mention you have my money you change my fligh...
# 14639    @mention we have @number ppl so we need @numbe...
# Name: cleared_text, Length: 14640, dtype: object

# %%
new_df = df[["text", "airline_sentiment", "negativereason", "airline", "cleared_text"]].copy()

# %%
new_df.head()
# Out:
#                                                 text airline_sentiment  \
# 0                @VirginAmerica What @dhepburn said.           neutral
# 1  @VirginAmerica plus you've added commercials t...          positive
# 2  @VirginAmerica I didn't today... Must mean I n...           neutral
# 3  @VirginAmerica it's really aggressive to blast...          negative
# 4  @VirginAmerica and it's a really big bad thing...          negative
#
#   negativereason         airline  \
# 0            NaN  Virgin America
# 1            NaN  Virgin America
# 2            NaN  Virgin America
# 3     Bad Flight  Virgin America
# 4     Can't Tell  Virgin America
#
#                                         cleared_text
# 0                       @mention what @mention said
# 1  @mention plus you ve added commercials to the ...
# 2  @mention i didn t today must mean i need to ta...
# 3  @mention it s really aggressive to blast obnox...
# 4  @mention and it s a really big bad thing about it

# %% [markdown]
# ## 2 - Tokenization:

# %%
"""
word_tokens = []
for phrase in df["cleared_text"]:
    word_tokens.append(word_tokenize(phrase))
"""
# Out:
# '\nword_tokens = []\nfor phrase in df["cleared_text"]:\n    word_tokens.append(word_tokenize(phrase))\n'

# %%
word_tokens = []
for phrase in df["cleared_text"]:
    word_tokens.append(phrase.split())

# %%
word_tokens
# Out:
# [['@mention', 'what', '@mention', 'said'],
#  ['@mention',
#   'plus',
#   'you',
#   've',
#   'added',
#   'commercials',
#   'to',
#   'the',
#   'experience',
#   'tacky'],
#  ['@mention',
#   'i',
#   'didn',
#   't',
#   'today',
#   'must',
#   'mean',
#   'i',
#   'need',
#   'to',
#   'take',
#   'another',
#   'trip'],
#  ['@mention',
#   'it',
#   's',
#   'really',
#   'aggressive',
#   'to',
#   'blast',
#   'obnoxious',
#   'entertainment',
#   'in',
#   'your',
#   'guests',
#   'faces',
#   'amp',
#   'they',
#   'have',
#   'little',
#   'recourse'],
#  ['@mention',
#   'and',
#   'it',
#   's',
#   'a',
#   'really',
#   'big',
#   'bad',
#   'thing',
#   'about',
#   'it'],
#  ['@mention',
#   'seriously',
#   'would',
#   'pay',
#   '@number',
#   'a',
#   'flight',
#   'for',
#   'seats',
#   'that',
#   'didn',
#   't',
#   'have',
#   'this',
#   'playing',
#   'it',
#   's',
#   'really',
#   'the',
#   'only',
#   'bad',
#   'thing',
#   'about',
#   'flying',
#   'va'],
#  ['@mention',
#   'yes',
#   'nearly',
#   'every',
#   'time',
#   'i',
#   'fly',
#   'vx',
#   'this',
#   '@emoji',
#   'worm',
#   'wont',
#   'go',
#   'away',
#   '@emoji'],
#  ['@mention',
#   'really',
#   'missed',
#   'a',
#   'prime',
#   'opportunity',
#   'for',
#   'men',
#   'without',
#   'hats',
#   'parody',
#   'there',
#   '@url'],
#  ['@mention', 'well', 'i', 'didn', 'tbut', 'now', 'i', 'do', '@emoji'],
#  ['@mention',
#   'it',
#   'was',
#   'amazing',
#   'and',
#   'arrived',
#   'an',
#   'hour',
#   'early',
#   'you',
#   're',
#   'too',
#   'good',
#   'to',
#   'me'],
#  ['@mention',
#   'did',
#   'you',
#   'know',
#   'that',
#   'suicide',
#   'is',
#   'the',
#   'second',
#   'leading',
#   'cause',
#   'of',
#   'death',
#   'among',
#   'teens',
#   '@number',
#   '@number'],
#  ['@mention',
#   'i',
#   'lt',
#   '@number',
#   'pretty',
#   'graphics',
#   'so',
#   'much',
#   'better',
#   'than',
#   'minimal',
#   'iconography',
#   '@emoji'],
#  ['@mention',
#   'this',
#   'is',
#   'such',
#   'a',
#   'great',
#   'deal',
#   'already',
#   'thinking',
#   'about',
#   'my',
#   '@number',
#   'nd',
#   'trip',
#   'to',
#   '@mention',
#   'amp',
#   'i',
#   'haven',
#   't',
#   'even',
#   'gone',
#   'on',
#   'my',
#   '@number',
#   'st',
#   'trip',
#   'yet',
#   '@emoji'],
#  ['@mention',
#   '@mention',
#   'i',
#   'm',
#   'flying',
#   'your',
#   '@hashtag',
#   '@hashtag',
#   'skies',
#   'again',
#   'u',
#   'take',
#   'all',
#   'the',
#   '@hashtag',
#   'away',
#   'from',
#   'travel',
#   '@url'],
#  ['@mention', 'thanks'],
#  ['@mention', 'sfo', 'pdx', 'schedule', 'is', 'still', 'mia'],
#  ['@mention',
#   'so',
#   'excited',
#   'for',
#   'my',
#   'first',
#   'cross',
#   'country',
#   'flight',
#   'lax',
#   'to',
#   'mco',
#   'i',
#   've',
#   'heard',
#   'nothing',
#   'but',
#   'great',
#   'things',
#   'about',
#   'virgin',
#   'america',
#   '@hashtag'],
#  ['@mention',
#   'i',
#   'flew',
#   'from',
#   'nyc',
#   'to',
#   'sfo',
#   'last',
#   'week',
#   'and',
#   'couldn',
#   't',
#   'fully',
#   'sit',
#   'in',
#   'my',
#   'seat',
#   'due',
#   'to',
#   'two',
#   'large',
#   'gentleman',
#   'on',
#   'either',
#   'side',
#   'of',
#   'me',
#   'help'],
#  ['i', '@emoji', 'flying', '@mention', '@emoji'],
#  ['@mention',
#   'you',
#   'know',
#   'what',
#   'would',
#   'be',
#   'amazingly',
#   'awesome',
#   'bos',
#   'fll',
#   'please',
#   'i',
#   'want',
#   'to',
#   'fly',
#   'with',
#   'only',
#   'you'],
#  ['@mention',
#   'why',
#   'are',
#   'your',
#   'first',
#   'fares',
#   'in',
#   'may',
#   'over',
#   'three',
#   'times',
#   'more',
#   'than',
#   'other',
#   'carriers',
#   'when',
#   'all',
#   'seats',
#   'are',
#   'available',
#   'to',
#   'select'],
#  ['@mention', 'i', 'love', 'this', 'graphic', '@url'],
#  ['@mention',
#   'i',
#   'love',
#   'the',
#   'hipster',
#   'innovation',
#   'you',
#   'are',
#   'a',
#   'feel',
#   'good',
#   'brand'],
#  ['@mention',
#   'will',
#   'you',
#   'be',
#   'making',
#   'bos',
#   'gt',
#   'las',
#   'non',
#   'stop',
#   'permanently',
#   'anytime',
#   'soon'],
#  ['@mention',
#   'you',
#   'guys',
#   'messed',
#   'up',
#   'my',
#   'seating',
#   'i',
#   'reserved',
#   'seating',
#   'with',
#   'my',
#   'friends',
#   'and',
#   'you',
#   'guys',
#   'gave',
#   'my',
#   'seat',
#   'away',
#   '@emoji',
#   'i',
#   'want',
#   'free',
#   'internet'],
#  ['@mention',
#   'status',
#   'match',
#   'program',
#   'i',
#   'applied',
#   'and',
#   'it',
#   's',
#   'been',
#   'three',
#   'weeks',
#   'called',
#   'and',
#   'emailed',
#   'with',
#   'no',
#   'response'],
#  ['@mention',
#   'what',
#   'happened',
#   '@number',
#   'ur',
#   'vegan',
#   'food',
#   'options',
#   'at',
#   'least',
#   'say',
#   'on',
#   'ur',
#   'site',
#   'so',
#   'i',
#   'know',
#   'i',
#   'won',
#   't',
#   'be',
#   'able',
#   '@number',
#   'eat',
#   'anything',
#   'for',
#   'next',
#   '@number',
#   'hrs',
#   '@hashtag'],
#  ['@mention',
#   'do',
#   'you',
#   'miss',
#   'me',
#   'don',
#   't',
#   'worry',
#   'we',
#   'll',
#   'be',
#   'together',
#   'very',
#   'soon'],
#  ['@mention',
#   'amazing',
#   'to',
#   'me',
#   'that',
#   'we',
#   'can',
#   't',
#   'get',
#   'any',
#   'cold',
#   'air',
#   'from',
#   'the',
#   'vents',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'lax',
#   'to',
#   'ewr',
#   'middle',
#   'seat',
#   'on',
#   'a',
#   'red',
#   'eye',
#   'such',
#   'a',
#   'noob',
#   'maneuver',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'hi',
#   'i',
#   'just',
#   'bked',
#   'a',
#   'cool',
#   'birthday',
#   'trip',
#   'with',
#   'you',
#   'but',
#   'i',
#   'can',
#   't',
#   'add',
#   'my',
#   'elevate',
#   'no',
#   'cause',
#   'i',
#   'entered',
#   'my',
#   'middle',
#   'name',
#   'during',
#   'flight',
#   'booking',
#   'problems',
#   '@emoji'],
#  ['@mention',
#   'are',
#   'the',
#   'hours',
#   'of',
#   'operation',
#   'for',
#   'the',
#   'club',
#   'at',
#   'sfo',
#   'that',
#   'are',
#   'posted',
#   'online',
#   'current'],
#  ['@mention',
#   'help',
#   'left',
#   'expensive',
#   'headphones',
#   'on',
#   'flight',
#   '@number',
#   'iad',
#   'to',
#   'lax',
#   'today',
#   'seat',
#   '@number',
#   'a',
#   'no',
#   'one',
#   'answering',
#   'l',
#   'amp',
#   'f',
#   'number',
#   'at',
#   'lax'],
#  ['@mention',
#   'awaiting',
#   'my',
#   'return',
#   'phone',
#   'call',
#   'just',
#   'would',
#   'prefer',
#   'to',
#   'use',
#   'your',
#   'online',
#   'self',
#   'service',
#   'option',
#   '@emoji'],
#  ['@mention',
#   'this',
#   'is',
#   'great',
#   'news',
#   'america',
#   'could',
#   'start',
#   'flights',
#   'to',
#   'hawaii',
#   'by',
#   'end',
#   'of',
#   'year',
#   '@url',
#   'via',
#   '@mention'],
#  ['nice',
#   'rt',
#   '@mention',
#   'vibe',
#   'with',
#   'the',
#   'moodlight',
#   'from',
#   'takeoff',
#   'to',
#   'touchdown',
#   '@hashtag',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'moodlighting',
#   'is',
#   'the',
#   'only',
#   'way',
#   'to',
#   'fly',
#   'best',
#   'experience',
#   'ever',
#   'cool',
#   'and',
#   'calming',
#   '@emoji',
#   '@emoji',
#   '@hashtag'],
#  ['@mention',
#   '@mention',
#   'done',
#   'and',
#   'done',
#   'best',
#   'airline',
#   'around',
#   'hands',
#   'down'],
#  ['@mention', 'when', 'can', 'i', 'book', 'my', 'flight', 'to', 'hawaii'],
#  ['@mention',
#   'your',
#   'chat',
#   'support',
#   'is',
#   'not',
#   'working',
#   'on',
#   'your',
#   'site',
#   '@url'],
#  ['@mention',
#   'view',
#   'of',
#   'downtown',
#   'los',
#   'angeles',
#   'the',
#   'hollywood',
#   'sign',
#   'and',
#   'beyond',
#   'that',
#   'rain',
#   'in',
#   'the',
#   'mountains',
#   '@url'],
#  ['@mention',
#   'hey',
#   'first',
#   'time',
#   'flyer',
#   'next',
#   'week',
#   'excited',
#   'but',
#   'i',
#   'm',
#   'having',
#   'a',
#   'hard',
#   'time',
#   'getting',
#   'my',
#   'flights',
#   'added',
#   'to',
#   'my',
#   'elevate',
#   'account',
#   'help'],
#  ['@mention',
#   'plz',
#   'help',
#   'me',
#   'win',
#   'my',
#   'bid',
#   'upgrade',
#   'for',
#   'my',
#   'flight',
#   '@number',
#   '@number',
#   'lax',
#   'gt',
#   'sea',
#   '@emoji',
#   '@emoji'],
#  ['@mention',
#   'i',
#   'have',
#   'an',
#   'unused',
#   'ticket',
#   'but',
#   'moved',
#   'to',
#   'a',
#   'new',
#   'city',
#   'where',
#   'you',
#   'don',
#   't',
#   'fly',
#   'how',
#   'can',
#   'i',
#   'fly',
#   'with',
#   'you',
#   'before',
#   'it',
#   'expires',
#   '@hashtag'],
#  ['@mention',
#   'are',
#   'flights',
#   'leaving',
#   'dallas',
#   'for',
#   'seattle',
#   'on',
#   'time',
#   'feb',
#   '@number'],
#  ['@mention',
#   'i',
#   'm',
#   '@hashtag',
#   'for',
#   'a',
#   'good',
#   'reason',
#   'you',
#   'rock'],
#  ['@mention', 'dream', '@url', '@url'],
#  ['@mention', 'wow', 'this', 'just', 'blew', 'my', 'mind'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   'after',
#   'last',
#   'night',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@mention',
#   'i',
#   'think',
#   '@mention',
#   'agree'],
#  ['@mention', '@mention', '@mention', 'all', 'were', 'entertaining'],
#  ['@mention',
#   'is',
#   'flight',
#   '@number',
#   'on',
#   'it',
#   's',
#   'way',
#   'was',
#   'supposed',
#   'to',
#   'take',
#   'off',
#   '@number',
#   'minutes',
#   'ago',
#   'website',
#   'still',
#   'shows',
#   'on',
#   'time',
#   'not',
#   'in',
#   'flight',
#   'thanks'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   'julie',
#   'andrews',
#   'all',
#   'the',
#   'way',
#   'though',
#   '@mention',
#   'was',
#   'very',
#   'impressive',
#   'no',
#   'to',
#   '@mention'],
#  ['@mention', 'wish', 'you', 'flew', 'out', 'of', 'atlanta', 'soon'],
#  ['@mention', '@mention', '@mention', 'julie', 'andrews', 'hands', 'down'],
#  ['@mention',
#   'will',
#   'flights',
#   'be',
#   'leaving',
#   'dallas',
#   'for',
#   'la',
#   'on',
#   'february',
#   '@number',
#   'th'],
#  ['@mention',
#   'hi',
#   'i',
#   'm',
#   'so',
#   'excited',
#   'about',
#   'your',
#   '@number',
#   'lga',
#   'gt',
#   '@emoji',
#   'deal',
#   'but',
#   'i',
#   've',
#   'been',
#   'trying',
#   '@number',
#   'book',
#   'since',
#   'last',
#   'week',
#   'amp',
#   'the',
#   'page',
#   'never',
#   'loads',
#   'thx'],
#  ['@mention',
#   'you',
#   'know',
#   'it',
#   'need',
#   'it',
#   'on',
#   'my',
#   'spotify',
#   'stat',
#   '@hashtag'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   'i',
#   'm',
#   'lady',
#   'gaga',
#   'she',
#   'is',
#   'amazing',
#   '@emoji'],
#  ['@mention', '@mention', '@mention', 'carrie'],
#  ['@mention',
#   'new',
#   'marketing',
#   'song',
#   '@url',
#   'let',
#   'us',
#   'know',
#   'what',
#   'you',
#   'think'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   'julie',
#   'andrews',
#   'first',
#   'but',
#   'lady',
#   'gaga',
#   'wow',
#   'd',
#   'me',
#   'last',
#   'night',
#   'carrie',
#   'meh'],
#  ['@mention',
#   'i',
#   'called',
#   'a',
#   '@number',
#   '@number',
#   'weeks',
#   'ago',
#   'about',
#   'adding',
#   '@number',
#   'flights',
#   'from',
#   '@number',
#   'to',
#   'my',
#   'elevate',
#   'they',
#   'still',
#   'haven',
#   't',
#   'shown',
#   'up',
#   'help'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   'all',
#   'are',
#   'great',
#   'but',
#   'i',
#   'have',
#   'to',
#   'go',
#   'with',
#   '@hashtag',
#   '@emoji'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   'sorry',
#   'mary',
#   'martin',
#   'had',
#   'it',
#   'first'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   'love',
#   'all',
#   'three',
#   'but',
#   'you',
#   'really',
#   'can',
#   't',
#   'beat',
#   'the',
#   'classics'],
#  ['@mention',
#   'flight',
#   '@number',
#   'dal',
#   'to',
#   'dca',
#   '@number',
#   '@number',
#   '@number',
#   '@number',
#   'pm',
#   'tried',
#   'to',
#   'check',
#   'in',
#   'could',
#   'not',
#   'status',
#   'please'],
#  ['@mention',
#   'heyyyy',
#   'guyyyys',
#   'been',
#   'trying',
#   'to',
#   'get',
#   'through',
#   'for',
#   'an',
#   'hour',
#   'can',
#   'someone',
#   'call',
#   'me',
#   'please',
#   '@emoji'],
#  ['@mention',
#   'hi',
#   'virgin',
#   'i',
#   'm',
#   'on',
#   'hold',
#   'for',
#   '@number',
#   '@number',
#   'minutes',
#   'are',
#   'there',
#   'any',
#   'earlier',
#   'flights',
#   'from',
#   'la',
#   'to',
#   'nyc',
#   'tonight',
#   'earlier',
#   'than',
#   '@number',
#   '@number',
#   'pm'],
#  ['@mention',
#   'congrats',
#   'on',
#   'winning',
#   'the',
#   '@mention',
#   'award',
#   'for',
#   'best',
#   'deals',
#   'from',
#   'an',
#   'airline',
#   'us',
#   '@url'],
#  ['@mention',
#   'everything',
#   'was',
#   'fine',
#   'until',
#   'you',
#   'lost',
#   'my',
#   'bag'],
#  ['@mention',
#   'need',
#   'to',
#   'change',
#   'reservation',
#   'have',
#   'virgin',
#   'credit',
#   'card',
#   'do',
#   'i',
#   'need',
#   'to',
#   'modify',
#   'on',
#   'phone',
#   'to',
#   'waive',
#   'change',
#   'fee',
#   'or',
#   'can',
#   'i',
#   'do',
#   'online'],
#  ['@mention',
#   'i',
#   'emailed',
#   'your',
#   'customer',
#   'service',
#   'team',
#   'let',
#   'me',
#   'know',
#   'if',
#   'you',
#   'need',
#   'the',
#   'tracking',
#   'number'],
#  ['@mention',
#   'hi',
#   'i',
#   'just',
#   'booked',
#   'a',
#   'flight',
#   'but',
#   'need',
#   'to',
#   'add',
#   'baggage',
#   'how',
#   'can',
#   'i',
#   'do',
#   'this'],
#  ['@mention',
#   'your',
#   'airline',
#   'is',
#   'awesome',
#   'but',
#   'your',
#   'lax',
#   'loft',
#   'needs',
#   'to',
#   'step',
#   'up',
#   'its',
#   'game',
#   '@number',
#   'for',
#   'dirty',
#   'tables',
#   'and',
#   'floors',
#   '@url'],
#  ['@mention',
#   'not',
#   'worried',
#   'it',
#   's',
#   'been',
#   'a',
#   'great',
#   'ride',
#   'in',
#   'a',
#   'new',
#   'plane',
#   'with',
#   'great',
#   'crew',
#   'all',
#   'airlines',
#   'should',
#   'be',
#   'like',
#   'this'],
#  ['@mention',
#   'awesome',
#   'i',
#   'flew',
#   'yall',
#   'sat',
#   'morning',
#   'any',
#   'way',
#   'we',
#   'can',
#   'correct',
#   'my',
#   'bill'],
#  ['@mention',
#   'or',
#   'watch',
#   'some',
#   'of',
#   'the',
#   'best',
#   'student',
#   'films',
#   'in',
#   'the',
#   'country',
#   'at',
#   '@number',
#   '@number',
#   'feet',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'first',
#   'time',
#   'flying',
#   'you',
#   'all',
#   'do',
#   'you',
#   'have',
#   'a',
#   'different',
#   'rate',
#   'policy',
#   'for',
#   'media',
#   'bags',
#   'thanks'],
#  ['@mention',
#   'what',
#   'is',
#   'going',
#   'on',
#   'with',
#   'customer',
#   'service',
#   'is',
#   'there',
#   'anyway',
#   'to',
#   'speak',
#   'to',
#   'a',
#   'human',
#   'asap',
#   'thank',
#   'you'],
#  ['@mention', 'what', 'happened', 'to', 'doom'],
#  ['@mention',
#   'why',
#   'can',
#   't',
#   'you',
#   'supp',
#   'the',
#   'biz',
#   'traveler',
#   'like',
#   '@mention',
#   'and',
#   'have',
#   'customer',
#   'service',
#   'like',
#   '@mention',
#   '@hashtag'],
#  ['@mention',
#   'i',
#   've',
#   'applied',
#   'more',
#   'then',
#   'once',
#   'to',
#   'be',
#   'a',
#   'member',
#   'of',
#   'the',
#   '@hashtag',
#   'crew',
#   'team',
#   'im',
#   '@number',
#   'interested',
#   '@hashtag',
#   '@hashtag',
#   'g'],
#  ['@mention',
#   'you',
#   're',
#   'the',
#   'best',
#   'whenever',
#   'i',
#   'begrudgingly',
#   'use',
#   'any',
#   'other',
#   'airline',
#   'i',
#   'm',
#   'delayed',
#   'and',
#   'late',
#   'flight',
#   '@emoji'],
#  ['@mention',
#   'i',
#   'have',
#   'no',
#   'interesting',
#   'flying',
#   'with',
#   'you',
#   'after',
#   'this',
#   'i',
#   'will',
#   'cancelled',
#   'flight',
#   'my',
#   'next',
#   'four',
#   'flights',
#   'i',
#   'planned',
#   '@hashtag'],
#  ['@mention',
#   'it',
#   'was',
#   'a',
#   'disappointing',
#   'experience',
#   'which',
#   'will',
#   'be',
#   'shared',
#   'with',
#   'every',
#   'business',
#   'traveler',
#   'i',
#   'meet',
#   '@hashtag'],
#  ['@mention',
#   'im',
#   'having',
#   'trouble',
#   'adding',
#   'this',
#   'flight',
#   'my',
#   'wife',
#   'booked',
#   'to',
#   'my',
#   'elevate',
#   'account',
#   'help',
#   '@url'],
#  ['@mention',
#   'can',
#   't',
#   'bring',
#   'up',
#   'my',
#   'reservation',
#   'online',
#   'using',
#   'flight',
#   'booking',
#   'problems',
#   'code'],
#  ['@mention',
#   'random',
#   'q',
#   'what',
#   's',
#   'the',
#   'distribution',
#   'of',
#   'elevate',
#   'avatars',
#   'i',
#   'bet',
#   'that',
#   'kitty',
#   'has',
#   'a',
#   'disproportionate',
#   'share',
#   '@url'],
#  ['@mention',
#   'i',
#   'lt',
#   '@number',
#   'flying',
#   'va',
#   'but',
#   'life',
#   'happens',
#   'and',
#   'i',
#   'am',
#   'trying',
#   'to',
#   '@hashtag',
#   'my',
#   'trip',
#   'jperhi',
#   'can',
#   'you',
#   'help',
#   'va',
#   'home',
#   'page',
#   'will',
#   'not',
#   'let',
#   'me'],
#  ['@mention',
#   'why',
#   'is',
#   'the',
#   'site',
#   'down',
#   'when',
#   'will',
#   'it',
#   'be',
#   'back',
#   'up'],
#  ['@mention', 'you', 'down', 'with', 'rnp', 'yeah', 'you', 'know', 'me'],
#  ['@mention',
#   'hi',
#   'i',
#   'did',
#   'not',
#   'get',
#   'points',
#   'on',
#   'my',
#   'elevate',
#   'account',
#   'for',
#   'my',
#   'most',
#   'recent',
#   'flight',
#   'how',
#   'do',
#   'i',
#   'add',
#   'the',
#   'flight',
#   'and',
#   'points',
#   'to',
#   'my',
#   'account'],
#  ['@mention',
#   'i',
#   'like',
#   'the',
#   'tv',
#   'and',
#   'interesting',
#   'video',
#   'just',
#   'disappointed',
#   'in',
#   'cancelled',
#   'flightled',
#   'flight',
#   'when',
#   'other',
#   'flights',
#   'went',
#   'out',
#   'to',
#   'jfk',
#   'on',
#   'saturday'],
#  ['@mention',
#   'just',
#   'landed',
#   'in',
#   'lax',
#   'an',
#   'hour',
#   'after',
#   'i',
#   'should',
#   'of',
#   'been',
#   'here',
#   'your',
#   'no',
#   'late',
#   'flight',
#   'bag',
#   'check',
#   'is',
#   'not',
#   'business',
#   'travel',
#   'friendly',
#   '@hashtag'],
#  ['@mention', 'why', 'is', 'flight', '@number', 'redirected'],
#  ['@mention',
#   'is',
#   'it',
#   'me',
#   'or',
#   'is',
#   'your',
#   'website',
#   'down',
#   'btw',
#   'your',
#   'new',
#   'website',
#   'isn',
#   't',
#   'a',
#   'great',
#   'user',
#   'experience',
#   'time',
#   'for',
#   'another',
#   'redesign'],
#  ['@mention',
#   'i',
#   'can',
#   't',
#   'check',
#   'in',
#   'or',
#   'add',
#   'a',
#   'bag',
#   'your',
#   'website',
#   'isn',
#   't',
#   'working',
#   'i',
#   've',
#   'tried',
#   'both',
#   'desktop',
#   'and',
#   'mobile',
#   '@url'],
#  ['@mention',
#   'let',
#   '@number',
#   'scanned',
#   'in',
#   'passengers',
#   'leave',
#   'the',
#   'plane',
#   'than',
#   'told',
#   'someone',
#   'to',
#   'remove',
#   'their',
#   'bag',
#   'from',
#   '@number',
#   'st',
#   'class',
#   'bin',
#   '@hashtag'],
#  ['@mention',
#   'what',
#   'is',
#   'your',
#   'phone',
#   'number',
#   'i',
#   'can',
#   't',
#   'find',
#   'who',
#   'to',
#   'call',
#   'about',
#   'a',
#   'flight',
#   'reservation'],
#  ['@mention',
#   'is',
#   'anyone',
#   'doing',
#   'anything',
#   'there',
#   'today',
#   'website',
#   'is',
#   'useless',
#   'and',
#   'no',
#   'one',
#   'is',
#   'answering',
#   'the',
#   'phone'],
#  ['@mention',
#   'trying',
#   'to',
#   'add',
#   'my',
#   'boy',
#   'prince',
#   'to',
#   'my',
#   'ressie',
#   'sf',
#   'this',
#   'thursday',
#   '@mention',
#   'from',
#   'lax',
#   '@url'],
#  ['@mention',
#   'why',
#   'must',
#   'a',
#   'traveler',
#   'miss',
#   'a',
#   'flight',
#   'to',
#   'late',
#   'flight',
#   'check',
#   'a',
#   'bag',
#   'i',
#   'missed',
#   'my',
#   'morning',
#   'appointments',
#   'and',
#   'you',
#   'lost',
#   'my',
#   'business',
#   '@hashtag'],
#  ['@mention', 'check', 'out', 'new', 'music', '@url'],
#  ['@mention',
#   'how',
#   's',
#   'a',
#   'direct',
#   'flight',
#   'fll',
#   'gt',
#   'sfo',
#   'have',
#   'unexpected',
#   'layover',
#   'in',
#   'vegas',
#   '@number',
#   'fuel',
#   'yet',
#   'peeps',
#   'next',
#   'to',
#   'me',
#   'bought',
#   'for',
#   'vegas',
#   'flight',
#   '@hashtag'],
#  ['@mention',
#   'your',
#   'no',
#   'late',
#   'flight',
#   'bag',
#   'check',
#   'just',
#   'lost',
#   'you',
#   'my',
#   'business',
#   'i',
#   'missed',
#   'flight',
#   'and',
#   'am',
#   'apt',
#   'three',
#   'other',
#   'people',
#   'on',
#   'flight',
#   'had',
#   'same',
#   'exp'],
#  ['@mention',
#   'amazing',
#   'customer',
#   'service',
#   'again',
#   '@emoji',
#   'raeann',
#   'in',
#   'sf',
#   'she',
#   's',
#   'the',
#   'best',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'called',
#   'your',
#   'service',
#   'line',
#   'and',
#   'was',
#   'hung',
#   'up',
#   'on',
#   'this',
#   'is',
#   'awesome',
#   '@hashtag'],
#  ['@mention',
#   'your',
#   'site',
#   'is',
#   'tripping',
#   'i',
#   'm',
#   'trying',
#   'to',
#   'check',
#   'in',
#   'and',
#   'i',
#   'm',
#   'getting',
#   'the',
#   'plain',
#   'text',
#   'version',
#   'i',
#   'am',
#   'reluctant',
#   'to',
#   'enter',
#   'any',
#   'card',
#   'info'],
#  ['@mention',
#   'i',
#   'was',
#   'scheduled',
#   'for',
#   'sfo',
#   '@number',
#   'dal',
#   'flight',
#   '@number',
#   'today',
#   'changed',
#   'to',
#   '@number',
#   'th',
#   'due',
#   'weather',
#   'looks',
#   'like',
#   'flight',
#   'still',
#   'on'],
#  ['@mention',
#   'has',
#   'getaway',
#   'deals',
#   'through',
#   'may',
#   'from',
#   '@number',
#   'one',
#   'way',
#   'lots',
#   'of',
#   'cool',
#   'cities',
#   '@url',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'has',
#   'getaway',
#   'deals',
#   'through',
#   'may',
#   'from',
#   '@number',
#   'one',
#   'way',
#   'lots',
#   'of',
#   'cool',
#   'cities',
#   '@url',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'has',
#   'getaway',
#   'deals',
#   'through',
#   'may',
#   'from',
#   '@number',
#   'one',
#   'way',
#   'lots',
#   'of',
#   'cool',
#   'cities',
#   '@url',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'has',
#   'getaway',
#   'deals',
#   'through',
#   'may',
#   'from',
#   '@number',
#   'one',
#   'way',
#   'lots',
#   'of',
#   'cool',
#   'cities',
#   '@url',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention', 'have', 'a', 'great', 'week', '@emoji', '@emoji'],
#  ['@mention',
#   'come',
#   'back',
#   'to',
#   '@hashtag',
#   'already',
#   'we',
#   'need',
#   'you',
#   'to',
#   'take',
#   'us',
#   'out',
#   'of',
#   'this',
#   'horrible',
#   'cold',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'should',
#   'i',
#   'be',
#   'concerned',
#   'that',
#   'i',
#   'am',
#   'about',
#   'to',
#   'fly',
#   'on',
#   'a',
#   'plane',
#   'that',
#   'needs',
#   'to',
#   'be',
#   'delayed',
#   'due',
#   'to',
#   'a',
#   'tech',
#   'stop'],
#  ['@mention',
#   'is',
#   'the',
#   'best',
#   'airline',
#   'i',
#   'have',
#   'flown',
#   'on',
#   'easy',
#   'to',
#   'change',
#   'your',
#   'reservation',
#   'helpful',
#   'representatives',
#   'amp',
#   'a',
#   'comfortable',
#   'flying',
#   'experience'],
#  ['@mention',
#   'and',
#   'again',
#   'another',
#   'rep',
#   'kicked',
#   'butt',
#   'naelah',
#   'represents',
#   'your',
#   'team',
#   'so',
#   'beautifully',
#   'thank',
#   'you'],
#  ['@mention',
#   'your',
#   'beautiful',
#   'front',
#   'end',
#   'design',
#   'is',
#   'down',
#   'right',
#   'now',
#   'but',
#   'it',
#   'was',
#   'cool',
#   'to',
#   'still',
#   'book',
#   'my',
#   'ticket',
#   'b',
#   'c',
#   'all',
#   'your',
#   'back',
#   'end',
#   'was',
#   'secure'],
#  ['@mention',
#   'love',
#   'the',
#   'team',
#   'running',
#   'gate',
#   'e',
#   '@number',
#   'at',
#   'las',
#   'tonight',
#   'waited',
#   'for',
#   'a',
#   'delayed',
#   'flight',
#   'and',
#   'they',
#   'kept',
#   'things',
#   'entertaining'],
#  ['@mention',
#   'use',
#   'another',
#   'browser',
#   '@number',
#   'amp',
#   'a',
#   'brand',
#   'with',
#   'a',
#   'reputation',
#   'built',
#   'on',
#   'tech',
#   'response',
#   'doesn',
#   't',
#   'have',
#   'a',
#   'cross',
#   'browser',
#   'compatible',
#   'website'],
#  ['@mention',
#   'and',
#   'now',
#   'the',
#   'flight',
#   'flight',
#   'booking',
#   'problems',
#   'site',
#   'is',
#   'totally',
#   'down',
#   'folks',
#   'what',
#   'is',
#   'the',
#   'problem'],
#  ['@mention',
#   'i',
#   'like',
#   'the',
#   'customer',
#   'service',
#   'but',
#   'a',
#   '@number',
#   'min',
#   'delay',
#   'just',
#   'for',
#   'connecting',
#   'passengers',
#   'seems',
#   'too',
#   'long',
#   'va',
#   '@number'],
#  ['@mention',
#   'thanks',
#   'to',
#   'your',
#   'outstanding',
#   'nyc',
#   'jfk',
#   'crew',
#   'who',
#   'moved',
#   'mountains',
#   'to',
#   'get',
#   'me',
#   'home',
#   'to',
#   'san',
#   'francisco',
#   'tonight'],
#  ['@mention',
#   'you',
#   'have',
#   'the',
#   'absolute',
#   'best',
#   'team',
#   'and',
#   'customer',
#   'service',
#   'ever',
#   'every',
#   'time',
#   'i',
#   'fly',
#   'with',
#   'you',
#   'i',
#   'm',
#   'delighted',
#   'thank',
#   'you'],
#  ['@mention',
#   'do',
#   'you',
#   'provide',
#   'complimentary',
#   'upgrades',
#   'to',
#   'first',
#   'class',
#   'if',
#   'there',
#   'are',
#   'available',
#   'seats'],
#  ['@mention',
#   'i',
#   'need',
#   'to',
#   'change',
#   'my',
#   'flight',
#   'thats',
#   'scheduled',
#   'in',
#   '@number',
#   'hours',
#   'and',
#   '@number',
#   'min',
#   'wait',
#   'time',
#   'on',
#   'phone',
#   'im',
#   'calling',
#   'intern',
#   'help'],
#  ['@mention',
#   'completely',
#   'awesome',
#   'experience',
#   'last',
#   'month',
#   'bos',
#   'las',
#   'nonstop',
#   'thanks',
#   'for',
#   'such',
#   'an',
#   'awesome',
#   'flight',
#   'and',
#   'depart',
#   'time',
#   '@hashtag'],
#  ['@mention',
#   'how',
#   'can',
#   'i',
#   'watch',
#   'the',
#   '@hashtag',
#   'on',
#   'my',
#   'jfk',
#   'gt',
#   'sfo',
#   'flight'],
#  ['@mention',
#   'is',
#   'flight',
#   '@number',
#   'cancelled',
#   'flightled',
#   'and',
#   'what',
#   'do',
#   'i',
#   'do',
#   'if',
#   'it',
#   'is'],
#  ['@mention',
#   'you',
#   'are',
#   'failing',
#   'your',
#   'customers',
#   'because',
#   'your',
#   'check',
#   'in',
#   'process',
#   'does',
#   'not',
#   'link',
#   'to',
#   'tsa',
#   'pre',
#   'check'],
#  ['@mention',
#   '@mention',
#   'us',
#   'too',
#   'terrible',
#   'airline',
#   'just',
#   'gave',
#   'us',
#   'a',
#   'hotel',
#   'hotline',
#   'number',
#   'and',
#   'said',
#   'sorry'],
#  ['@mention',
#   'has',
#   'flight',
#   'number',
#   '@number',
#   'from',
#   'sfo',
#   'to',
#   'cabo',
#   'san',
#   'lucas',
#   'arrived',
#   'yet'],
#  ['@mention',
#   '@mention',
#   'your',
#   'assistance',
#   'yesterday',
#   'when',
#   'u',
#   'cancelled',
#   'flightled',
#   'our',
#   'flight',
#   'was',
#   'to',
#   'give',
#   'us',
#   'a',
#   'hotel',
#   'hotline',
#   'shame',
#   'on',
#   'you'],
#  ['@mention', 'another', 'delayed', 'flight', '@hashtag'],
#  ['@mention',
#   'i',
#   'need',
#   'to',
#   'register',
#   'a',
#   'service',
#   'dog',
#   'for',
#   'a',
#   'first',
#   'class',
#   'ticket',
#   'from',
#   'sfo',
#   'gt',
#   'dulles',
#   'the',
#   'phone',
#   'queue',
#   'is',
#   'an',
#   'hour',
#   'or',
#   'longer',
#   'pls',
#   'advise'],
#  ['@mention',
#   'you',
#   'rock',
#   'for',
#   'making',
#   'it',
#   'so',
#   'i',
#   'can',
#   'watch',
#   '@hashtag',
#   'on',
#   'my',
#   'flight',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention', '@mention', 'dropped', 'a', 'track', 'on', 'you', '@url'],
#  ['@mention', 'always', 'xoxo'],
#  ['@mention',
#   'why',
#   'can',
#   't',
#   'we',
#   'book',
#   'seats',
#   'on',
#   'your',
#   'flights',
#   'when',
#   'we',
#   'buy',
#   'them',
#   'or',
#   'even',
#   'during',
#   'check',
#   'in',
#   'creates',
#   'so',
#   'much',
#   'anxiety',
#   '@hashtag'],
#  ['@mention',
#   'you',
#   'd',
#   'think',
#   'paying',
#   'an',
#   'extra',
#   '@number',
#   'bucks',
#   'rt',
#   'for',
#   'luggage',
#   'might',
#   'afford',
#   'you',
#   'hiring',
#   'an',
#   'extra',
#   'hand',
#   'at',
#   '@mention',
#   '@hashtag'],
#  ['@mention',
#   'best',
#   'customer',
#   'service',
#   'rep',
#   'in',
#   'the',
#   'world',
#   '@hashtag',
#   'takes',
#   'the',
#   'cake'],
#  ['@mention',
#   'can',
#   'you',
#   'find',
#   'us',
#   'a',
#   'flt',
#   'out',
#   'of',
#   'lax',
#   'that',
#   'is',
#   'sooner',
#   'than',
#   'midnight',
#   'on',
#   'monday',
#   'that',
#   'would',
#   'be',
#   'great',
#   'customer',
#   'service',
#   '@emoji'],
#  ['@mention',
#   'please',
#   'provide',
#   'status',
#   'for',
#   'flight',
#   '@number',
#   'i',
#   'cant',
#   'imagine',
#   'it',
#   's',
#   'on',
#   'time',
#   'as',
#   'the',
#   'web',
#   'indicates',
#   'dude',
#   'to',
#   'weather',
#   'here',
#   'and',
#   'or',
#   'dallas'],
#  ['@mention',
#   'you',
#   'have',
#   'amazing',
#   'staff',
#   'amp',
#   'super',
#   'helpful',
#   'as',
#   'i',
#   'just',
#   'ran',
#   'the',
#   '@mention',
#   '@hashtag',
#   'they',
#   'have',
#   'spoiled',
#   'me',
#   'with',
#   'comfort'],
#  ['@mention',
#   'i',
#   'paid',
#   'the',
#   'premium',
#   'to',
#   'fly',
#   'you',
#   'across',
#   'the',
#   'country',
#   'you',
#   'cancelled',
#   'flight',
#   'my',
#   'flight',
#   'and',
#   'offer',
#   'no',
#   'check',
#   'fee',
#   'or',
#   'upgrade',
#   'love',
#   'sad',
#   'face',
#   '@emoji'],
#  ['@mention',
#   'question',
#   'is',
#   'it',
#   'not',
#   'possible',
#   'to',
#   'book',
#   'a',
#   'seat',
#   'for',
#   'an',
#   'infant',
#   'under',
#   '@number',
#   'it',
#   's',
#   'not',
#   'giving',
#   'me',
#   'the',
#   'option',
#   'but',
#   'we',
#   'want',
#   'a',
#   'seat',
#   'for',
#   'him'],
#  ['always',
#   'have',
#   'it',
#   'together',
#   'you',
#   're',
#   'welcome',
#   'rt',
#   '@mention',
#   '@mention',
#   'you',
#   're',
#   'so',
#   'welcome'],
#  ['@mention',
#   '@hashtag',
#   'home',
#   'to',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   'in',
#   '@hashtag',
#   'back',
#   'to',
#   '@hashtag',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'i',
#   'don',
#   't',
#   'understand',
#   'why',
#   'you',
#   'need',
#   'a',
#   'dm',
#   'to',
#   'give',
#   'me',
#   'an',
#   'answer',
#   'on',
#   'if',
#   'you',
#   'have',
#   'a',
#   'damaged',
#   'luggage',
#   'policy'],
#  ['@mention',
#   'does',
#   'that',
#   'mean',
#   'you',
#   'don',
#   't',
#   'have',
#   'a',
#   'policy',
#   'for',
#   'destroyed',
#   'luggage'],
#  ['@mention',
#   'is',
#   'there',
#   'special',
#   'assistance',
#   'if',
#   'i',
#   'travel',
#   'alone',
#   'w',
#   '@number',
#   'kids',
#   'and',
#   '@number',
#   'infant',
#   'priority',
#   'boarding'],
#  ['@mention',
#   'thank',
#   'you',
#   'for',
#   'checking',
#   'in',
#   'tickets',
#   'are',
#   'purchased',
#   'and',
#   'customer',
#   'is',
#   'happy',
#   '@emoji'],
#  ['@mention', 'is', 'your', 'website', 'ever', 'coming', 'back', 'online'],
#  ['@mention',
#   'is',
#   'flight',
#   '@number',
#   'from',
#   'love',
#   'field',
#   'to',
#   'sfo',
#   'definitely',
#   'cancelled',
#   'flightled',
#   'for',
#   'monday',
#   'february',
#   '@number'],
#  ['@mention',
#   'is',
#   'flight',
#   '@number',
#   'out',
#   'of',
#   'lga',
#   'to',
#   'dfw',
#   'on',
#   'time'],
#  ['@mention',
#   'my',
#   'drivers',
#   'license',
#   'is',
#   'expired',
#   'by',
#   'a',
#   'little',
#   'over',
#   'a',
#   'month',
#   'can',
#   'i',
#   'fly',
#   'friday',
#   'morning',
#   'using',
#   'my',
#   'expired',
#   'license'],
#  ['@mention',
#   'having',
#   'problems',
#   'flight',
#   'booking',
#   'problems',
#   'on',
#   'the',
#   'web',
#   'site',
#   'keeps',
#   'giving',
#   'me',
#   'an',
#   'error',
#   'and',
#   'to',
#   'contact',
#   'by',
#   'phone',
#   'phone',
#   'is',
#   '@number',
#   'minute',
#   'wait'],
#  ['@mention',
#   'how',
#   'do',
#   'i',
#   'reschedule',
#   'my',
#   'cancelled',
#   'flightled',
#   'flights',
#   'online',
#   'the',
#   'change',
#   'button',
#   'is',
#   'greyed',
#   'out'],
#  ['@mention',
#   'i',
#   'rang',
#   'but',
#   'there',
#   'is',
#   'a',
#   'wait',
#   'for',
#   '@number',
#   'minutes',
#   'i',
#   'can',
#   'book',
#   'the',
#   'same',
#   'ticket',
#   'through',
#   'a',
#   'vendor',
#   'fix',
#   'your',
#   'site'],
#  ['@mention',
#   'got',
#   'a',
#   'flight',
#   'we',
#   'were',
#   'told',
#   'for',
#   '@number',
#   '@number',
#   'today',
#   'checked',
#   'my',
#   'email',
#   'and',
#   'its',
#   'for',
#   '@number',
#   '@number',
#   'tomorrow',
#   'this',
#   'is',
#   'unacceptable'],
#  ['@mention',
#   'our',
#   'flight',
#   'into',
#   'lga',
#   'was',
#   'cancelled',
#   'flighted',
#   'we',
#   're',
#   'stuck',
#   'in',
#   'dallas',
#   'i',
#   'called',
#   'to',
#   'reschedule',
#   'told',
#   'i',
#   'could',
#   'get',
#   'a',
#   'flight',
#   'for',
#   'today',
#   '@number',
#   '@number'],
#  ['@mention',
#   'why',
#   'don',
#   't',
#   'any',
#   'of',
#   'the',
#   'pairings',
#   'include',
#   'red',
#   'wine',
#   'only',
#   'white',
#   'is',
#   'offered',
#   '@emoji',
#   '@hashtag'],
#  ['@mention', 'is', 'the', 'website', 'down'],
#  ['@mention',
#   'your',
#   'site',
#   'seems',
#   'a',
#   'little',
#   'wonked',
#   'right',
#   'now',
#   'may',
#   'want',
#   'to',
#   'have',
#   'a',
#   'look',
#   'tried',
#   'on',
#   'two',
#   'browsers',
#   'no',
#   'css',
#   '@url'],
#  ['@mention',
#   'i',
#   'm',
#   'disappointed',
#   'that',
#   'the',
#   'agent',
#   'at',
#   'the',
#   'designated',
#   'silver',
#   'status',
#   'check',
#   'in',
#   'line',
#   '@mention',
#   'closed',
#   'to',
#   'assist',
#   'all',
#   'pasengers'],
#  ['@mention',
#   'plans',
#   'to',
#   'include',
#   'austin',
#   'to',
#   'its',
#   'dallas',
#   'route',
#   'topnews',
#   'arab',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'is',
#   'it',
#   'normal',
#   'to',
#   'receive',
#   'no',
#   'reply',
#   'from',
#   'central',
#   'baggage',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'at',
#   'logan',
#   'airport',
#   'and',
#   'waiting',
#   'to',
#   'checkin',
#   'for',
#   'my',
#   '@number',
#   'am',
#   'flight',
#   'checkin',
#   'desk',
#   'not',
#   'open',
#   'why'],
#  ['@mention',
#   'to',
#   'jump',
#   'into',
#   'the',
#   'dallas',
#   'austin',
#   'market',
#   '@mention',
#   '@url'],
#  ['@mention',
#   'beats',
#   'eps',
#   'views',
#   'takes',
#   'on',
#   '@hashtag',
#   'va',
#   'luv',
#   'investor',
#   's',
#   'business',
#   'daily',
#   '@url'],
#  ['@mention',
#   'lister',
#   'to',
#   'my',
#   'show',
#   'my',
#   'on',
#   'monday',
#   '@number',
#   '@number'],
#  ['@mention',
#   'to',
#   'begin',
#   'dallas',
#   'austin',
#   '@hashtag',
#   'in',
#   'april',
#   '@number',
#   '@number',
#   'ketr',
#   '@url'],
#  ['@mention',
#   'congrats',
#   'you',
#   'just',
#   'got',
#   'all',
#   'my',
#   'business',
#   'from',
#   'ewr',
#   'to',
#   'sfo',
#   'lax',
#   'fuck',
#   'you',
#   '@mention',
#   'fl',
#   '@number',
#   'sfo',
#   'ewr',
#   'was',
#   'the',
#   'clincher'],
#  ['@mention',
#   'i',
#   'applied',
#   'over',
#   '@number',
#   'weeks',
#   'ago',
#   'haven',
#   't',
#   'heard',
#   'back',
#   'and',
#   'i',
#   'm',
#   'flying',
#   'this',
#   'week',
#   '@hashtag'],
#  ['@mention',
#   'i',
#   'd',
#   'love',
#   'to',
#   'know',
#   'what',
#   'your',
#   'policy',
#   'is',
#   'for',
#   'damaged',
#   'luggage'],
#  ['@mention', 'thank', 'you', 'for', 'the', 'follow'],
#  ['@mention',
#   'too',
#   'many',
#   'apologies',
#   'you',
#   'r',
#   'the',
#   'worse',
#   'airlines',
#   'don',
#   't',
#   'even',
#   'respond',
#   'to',
#   'your',
#   'cudtomers'],
#  ['@mention',
#   'shame',
#   'on',
#   'va',
#   'for',
#   'making',
#   'people',
#   'spend',
#   'money',
#   'in',
#   'stranded',
#   'cities',
#   'when',
#   'other',
#   'airlines',
#   'are',
#   'landing',
#   'at',
#   'jfk',
#   'who',
#   'will',
#   'reimburse',
#   'me'],
#  ['@mention', '@mention', 'i', 'dm', 'you'],
#  ['@mention',
#   'can',
#   'you',
#   'please',
#   'have',
#   'flights',
#   'in',
#   'sjc',
#   'i',
#   'have',
#   'no',
#   'choice',
#   'but',
#   'to',
#   'fly',
#   'southwest',
#   'to',
#   'vegas',
#   '@emoji'],
#  ['@mention',
#   'too',
#   'bad',
#   'you',
#   'say',
#   'it',
#   'takes',
#   '@number',
#   'to',
#   '@number',
#   'days',
#   'via',
#   'your',
#   'confirmation',
#   'email',
#   'when',
#   'i',
#   'inquired',
#   'after',
#   '@number',
#   'weeks',
#   'you',
#   'claim',
#   '@number',
#   'to',
#   '@number',
#   'weeks'],
#  ['@mention',
#   'flight',
#   'from',
#   'bos',
#   'gt',
#   'las',
#   'tomorrow',
#   'was',
#   'cancelled',
#   'flightled',
#   'no',
#   'notification',
#   'wait',
#   'times',
#   'are',
#   '@number',
#   'hour',
#   'will',
#   'you',
#   'rebook',
#   'on',
#   'another',
#   'airline'],
#  ['@emoji',
#   'rt',
#   '@mention',
#   'youve',
#   'met',
#   'your',
#   'match',
#   'got',
#   'status',
#   'on',
#   'another',
#   'airline',
#   'upgrade',
#   'restr',
#   '@url',
#   '@url'],
#  ['@mention', 'only', 'way', 'to', 'fly', '@hashtag', '@hashtag'],
#  ['@mention', 'if', 'only', 'you', 'guys', 'had', 'flights', 'from', 'cmh'],
#  ['@mention',
#   'a',
#   'lot',
#   'of',
#   'apologies',
#   'being',
#   'thrown',
#   'out',
#   'to',
#   'customers',
#   'from',
#   'what',
#   'i',
#   'can',
#   'see',
#   'very',
#   'sad',
#   'thanks',
#   'for',
#   'nothing',
#   'worst',
#   'airline',
#   'ever'],
#  ['@mention',
#   'for',
#   'all',
#   'my',
#   'flight',
#   'stuff',
#   'wrong',
#   'and',
#   'did',
#   'nothing',
#   'about',
#   'it',
#   'had',
#   '@hashtag',
#   '@hashtag',
#   'ever'],
#  ['@mention',
#   'having',
#   'an',
#   'issue',
#   'finding',
#   'a',
#   'missing',
#   'item',
#   'on',
#   'a',
#   'plane',
#   'can',
#   'you',
#   'help',
#   'me',
#   'find',
#   'which',
#   'airport',
#   'my',
#   'plane',
#   'headed',
#   'to',
#   'next'],
#  ['@mention', 'you', 'will', 'match', 'my', '@hashtag', 'status', 'cool'],
#  ['@emoji',
#   'met',
#   'your',
#   'match',
#   'got',
#   'status',
#   'on',
#   'another',
#   'airline',
#   'upgrade',
#   '@url',
#   '@mention',
#   '@emoji'],
#  ['@mention',
#   'trying',
#   'to',
#   'book',
#   'a',
#   'flight',
#   'with',
#   'you',
#   'guys',
#   'and',
#   'your',
#   'website',
#   'won',
#   't',
#   'let',
#   'me',
#   'about',
#   'to',
#   'lose',
#   'my',
#   'business'],
#  ['@mention', 'you', 'suck'],
#  ['@mention', 'thanks'],
#  ['@mention', 'just', 'dm', 'd', 'same', 'issue', 'persisting'],
#  ['@mention',
#   'because',
#   'we',
#   'never',
#   'rec',
#   'd',
#   'cancelled',
#   'flightlation',
#   'notice',
#   'we',
#   'were',
#   'left',
#   'w',
#   'no',
#   'options',
#   'to',
#   'fly',
#   'out',
#   'of',
#   'ps',
#   'driving',
#   'to',
#   'la',
#   'for',
#   'a',
#   'red',
#   'eye',
#   'mon',
#   'w',
#   'kids'],
#  ['@mention',
#   'trying',
#   'to',
#   'book',
#   'a',
#   'flight',
#   'amp',
#   'your',
#   'site',
#   'is',
#   'down',
#   '@emoji'],
#  ['@mention',
#   'you',
#   'have',
#   'any',
#   'flights',
#   'flying',
#   'into',
#   'boston',
#   'tomorrow',
#   'i',
#   'need',
#   'to',
#   'be',
#   'home',
#   'and',
#   'you',
#   'cancelled',
#   'flightled',
#   'my',
#   'flight',
#   'and',
#   'didn',
#   't',
#   'do',
#   'anything'],
#  ['@mention',
#   'you',
#   'stink',
#   'flight',
#   'cancelled',
#   'flighted',
#   'from',
#   'psp',
#   'to',
#   'jfk',
#   'and',
#   'no',
#   'notification',
#   'or',
#   'ability',
#   'to',
#   'rebook',
#   '@hashtag',
#   '@hashtag',
#   'better'],
#  ['@mention',
#   'i',
#   'love',
#   'your',
#   'guy',
#   's',
#   'song',
#   'we',
#   're',
#   'dancing',
#   'to',
#   'it',
#   'for',
#   'our',
#   'high',
#   'school',
#   'dance',
#   'revue'],
#  ['@mention',
#   'your',
#   'website',
#   'is',
#   'down',
#   'and',
#   'i',
#   'm',
#   'trying',
#   'to',
#   'check',
#   'in'],
#  ['@mention',
#   'done',
#   'thank',
#   'you',
#   'for',
#   'the',
#   'quick',
#   'response',
#   'apparently',
#   'faster',
#   'than',
#   'sitting',
#   'on',
#   'hold',
#   '@emoji'],
#  ['@mention',
#   'nervous',
#   'about',
#   'my',
#   'flight',
#   'from',
#   'dc',
#   'to',
#   'lax',
#   'getting',
#   'cancelled',
#   'flightled',
#   'tomorrow',
#   'just',
#   'sent',
#   'you',
#   'a',
#   'dm',
#   'to',
#   'help',
#   'me'],
#  ['@mention',
#   'cool',
#   'picture',
#   'of',
#   'another',
#   'virginamerica',
#   'plane',
#   'off',
#   'our',
#   'wing',
#   'what',
#   'a',
#   'site',
#   '@url'],
#  ['@mention', 'keep', 'up', 'the', 'great', 'work', '@emoji'],
#  ['@mention',
#   'my',
#   'goodness',
#   'your',
#   'people',
#   '@mention',
#   'field',
#   'are',
#   'amazing',
#   'under',
#   'pressure',
#   '@emoji',
#   'texas',
#   '@hashtag',
#   'in',
#   'crisis',
#   'please',
#   'fly',
#   'me',
#   'to',
#   'ny'],
#  ['@mention',
#   'thanks',
#   'for',
#   'a',
#   'great',
#   'flight',
#   'from',
#   'la',
#   'to',
#   'boston',
#   'pilots',
#   'did',
#   'a',
#   'great',
#   'job',
#   'landing',
#   'in',
#   'the',
#   'snow',
#   'can',
#   'we',
#   'go',
#   'back',
#   'to',
#   'la',
#   'now',
#   '@hashtag'],
#  ['@mention',
#   'can',
#   'you',
#   'please',
#   'get',
#   'me',
#   'to',
#   'the',
#   'new',
#   'york',
#   'area',
#   'before',
#   'monday',
#   'afternoon'],
#  ['@mention',
#   'thanks',
#   'so',
#   'much',
#   'for',
#   'the',
#   'awesome',
#   'support',
#   'you',
#   'guys',
#   'rock'],
#  ['@mention',
#   'seats',
#   'in',
#   'row',
#   '@number',
#   'don',
#   't',
#   'recline',
#   'should',
#   'mention',
#   'that',
#   'on',
#   'your',
#   'website',
#   '@hashtag'],
#  ['@mention',
#   'flight',
#   '@number',
#   'delayed',
#   '@number',
#   'hours',
#   'in',
#   'la',
#   'due',
#   'to',
#   'mechanical',
#   'problems',
#   'handle',
#   'like',
#   'pros',
#   'but',
#   'you',
#   'could',
#   'have',
#   'tossed',
#   'us',
#   'a',
#   'free',
#   'drink'],
#  ['@mention',
#   'why',
#   'cancelled',
#   'flight',
#   'flights',
#   'today',
#   'no',
#   'precipitation',
#   'to',
#   'be',
#   'scared',
#   'of',
#   '@emoji'],
#  ['@mention',
#   'twitter',
#   'team',
#   'you',
#   'guys',
#   'killed',
#   'it',
#   'for',
#   'rescheduling',
#   'me',
#   'asap',
#   'thank',
#   'you'],
#  ['@mention',
#   'you',
#   'guys',
#   'charged',
#   'me',
#   '@number',
#   'to',
#   'reschedule',
#   'a',
#   'flight',
#   'that',
#   'was',
#   'then',
#   'cancelled',
#   'flighted',
#   'and',
#   'are',
#   'now',
#   'refusing',
#   'to',
#   'refund',
#   'it',
#   'what',
#   's',
#   'the',
#   'deal'],
#  ['@mention',
#   'cant',
#   'access',
#   'your',
#   'website',
#   'from',
#   'safari',
#   'on',
#   'iphone',
#   '@number',
#   'seems',
#   'to',
#   'work',
#   'on',
#   'mac',
#   'and',
#   'ipad',
#   'need',
#   'iphone',
#   'to',
#   'add',
#   'passbook'],
#  ['@mention',
#   'on',
#   'ipad',
#   'and',
#   'iphone',
#   'clicking',
#   'the',
#   'checkin',
#   'link',
#   'in',
#   'the',
#   'email',
#   'i',
#   'received',
#   'at',
#   '@number',
#   'hrs',
#   'before',
#   'flight'],
#  ['@mention',
#   'your',
#   'mobile',
#   'site',
#   'is',
#   'broken',
#   'shows',
#   'header',
#   'elevateuser',
#   'numofpointsavailable',
#   '@number',
#   'number',
#   'points',
#   'won',
#   't',
#   'let',
#   'me',
#   'checkin'],
#  ['@mention',
#   'i',
#   'was',
#   'really',
#   'looking',
#   'forward',
#   'to',
#   'my',
#   'flight',
#   'can',
#   'you',
#   'let',
#   'me',
#   'know',
#   'when',
#   'it',
#   'will',
#   'be',
#   'rescheduled',
#   '@hashtag'],
#  ['@mention',
#   'why',
#   'cancelled',
#   'flight',
#   'flight',
#   'vx',
#   '@number',
#   'one',
#   'sec',
#   'its',
#   'delayed',
#   'on',
#   'my',
#   'to',
#   'airport',
#   'the',
#   'next',
#   'its',
#   'cancelled',
#   'flightled',
#   'gonna',
#   'email',
#   'or',
#   'call',
#   'me',
#   'to',
#   'reschedule'],
#  ['@mention',
#   'i',
#   'did',
#   'it',
#   'but',
#   'there',
#   'was',
#   'a',
#   'problem',
#   'in',
#   'the',
#   'link',
#   'from',
#   'the',
#   'email',
#   'for',
#   'check',
#   'in',
#   'thanks'],
#  ['@mention',
#   'had',
#   'to',
#   'change',
#   'to',
#   'another',
#   'airline',
#   'to',
#   'get',
#   'to',
#   'dc',
#   'today',
#   'why',
#   'is',
#   '@mention',
#   'able',
#   'to',
#   'land',
#   'in',
#   'dc',
#   'but',
#   'not',
#   'you',
#   'cost',
#   'me',
#   '@number',
#   'ugh'],
#  ['@mention',
#   'i',
#   'was',
#   'so',
#   'looking',
#   'forward',
#   'to',
#   'my',
#   'first',
#   'flight',
#   'with',
#   'you',
#   'today',
#   'but',
#   'it',
#   'was',
#   'cancelled',
#   'flightled',
#   'along',
#   'with',
#   'the',
#   'subsequent',
#   'one'],
#  ['@mention',
#   'when',
#   'are',
#   'you',
#   'putting',
#   'some',
#   'great',
#   'deals',
#   'from',
#   'pdx',
#   'to',
#   'las',
#   'or',
#   'from',
#   'las',
#   'to',
#   'pdx',
#   'show',
#   'me',
#   'your',
#   'love',
#   '@url'],
#  ['@mention',
#   'wish',
#   'i',
#   'can',
#   'afford',
#   'to',
#   'fly',
#   'with',
#   'you',
#   'next',
#   'friday',
#   'going',
#   'back',
#   'home',
#   'love',
#   'everything',
#   'about',
#   'your',
#   'airline'],
#  ['@mention',
#   'how',
#   'are',
#   'you',
#   'gonna',
#   'have',
#   'a',
#   'deal',
#   'from',
#   'dallas',
#   'to',
#   'dc',
#   'but',
#   'no',
#   'deal',
#   'from',
#   'dc',
#   'to',
#   'dallas',
#   '@hashtag'],
#  ['@mention', 'its', 'just', 'a', 'bug', 'report', 'guys'],
#  ['@mention',
#   'hold',
#   'times',
#   'at',
#   'call',
#   'center',
#   'are',
#   'a',
#   'bit',
#   'much'],
#  ['@mention', 'like', '@url'],
#  ['@mention', 'site', 'down', '@hashtag'],
#  ['@mention',
#   'you',
#   'have',
#   'the',
#   'best',
#   'flight',
#   'attendant',
#   'ever',
#   '@url'],
#  ['awesome',
#   'rt',
#   '@mention',
#   'watch',
#   'nominated',
#   'films',
#   'at',
#   '@number',
#   '@number',
#   'feet',
#   '@hashtag',
#   '@hashtag',
#   '@url'],
#  ['@mention', 'thanks', 'so', 'much'],
#  ['@mention',
#   'trying',
#   'to',
#   'reset',
#   'my',
#   'password',
#   'email',
#   'never',
#   'arrives',
#   'help'],
#  ['@mention',
#   'the',
#   'only',
#   'airline',
#   'based',
#   'in',
#   'silicon',
#   'valley',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@mention',
#   '@url'],
#  ['@mention', 'very', 'nicely', 'done', '@emoji'],
#  ['@mention',
#   'im',
#   'looking',
#   'forward',
#   'to',
#   'watching',
#   'the',
#   'oscars',
#   'on',
#   'my',
#   'flight',
#   'home',
#   'tomorrow',
#   'i',
#   'might',
#   'even',
#   'get',
#   'something',
#   'bubbly',
#   'to',
#   'drink',
#   '@emoji'],
#  ['@mention',
#   'what',
#   'is',
#   'the',
#   'reason',
#   'for',
#   'the',
#   'delay',
#   'of',
#   'the',
#   'departure',
#   'of',
#   'vx',
#   '@number',
#   'from',
#   'jfk',
#   'this',
#   'afternoon'],
#  ['@mention',
#   'is',
#   'todays',
#   'flight',
#   'from',
#   'palm',
#   'springs',
#   'ca',
#   'to',
#   'jfk',
#   'in',
#   'ny',
#   'cancelled',
#   'flightled'],
#  ['@mention',
#   'hahaha',
#   '@emoji',
#   'you',
#   'guys',
#   'are',
#   'amazing',
#   'i',
#   'love',
#   'you',
#   'guys',
#   '@emoji'],
#  ['@mention', 'sounds', 'like', 'fun'],
#  ['@mention',
#   'any',
#   'updates',
#   'on',
#   'flight',
#   '@number',
#   'from',
#   'jfk',
#   'gt',
#   'lax'],
#  ['@mention', 'spruce', 'moose'],
#  ['@mention',
#   'the',
#   'css',
#   'on',
#   'your',
#   'site',
#   'is',
#   'a',
#   '@number',
#   'right',
#   'now',
#   'please',
#   'fix',
#   'site',
#   'unusable'],
#  ['@mention',
#   'we',
#   're',
#   'on',
#   'flight',
#   '@number',
#   'vegas',
#   'to',
#   'boston',
#   'today',
#   'checked',
#   'in',
#   'online',
#   'but',
#   'our',
#   'bag',
#   'count',
#   'didn',
#   't',
#   'register',
#   'can',
#   'i',
#   'fix',
#   'that',
#   'somehow'],
#  ['@mention', 'classiq', 'luv', 'virgin', 'america', 'greetingz'],
#  ['@mention',
#   'hi',
#   'i',
#   'm',
#   'trying',
#   'to',
#   'do',
#   'check',
#   'in',
#   'but',
#   'the',
#   'website',
#   'is',
#   'not',
#   'working',
#   'i',
#   'tried',
#   '@number',
#   'different',
#   'browsers',
#   'and',
#   'the',
#   'problem',
#   'continues'],
#  ['@mention',
#   'thanks',
#   'for',
#   'your',
#   'great',
#   'customer',
#   'service',
#   'today',
#   'amp',
#   'for',
#   'helping',
#   'me',
#   'get',
#   'all',
#   'my',
#   'travel',
#   'sorted',
#   'out'],
#  ['@mention',
#   'thanks',
#   'guys',
#   'sweet',
#   'route',
#   'over',
#   'the',
#   'rockies',
#   '@hashtag'],
#  ['@mention',
#   'love',
#   'the',
#   '@number',
#   's',
#   'music',
#   'blasting',
#   'at',
#   'gate',
#   'in',
#   '@hashtag',
#   'while',
#   'waiting',
#   'for',
#   'flight',
#   'to',
#   '@hashtag',
#   'only',
#   'if',
#   'i',
#   'could',
#   'get',
#   'an',
#   'iced',
#   'coffee'],
#  ['@mention',
#   'the',
#   'passenger',
#   'in',
#   '@number',
#   'd',
#   'flt',
#   '@number',
#   'that',
#   'assaulted',
#   'me',
#   'shouldn',
#   't',
#   'have',
#   'flown',
#   'i',
#   'trust',
#   'he',
#   's',
#   'banned',
#   'crew',
#   'filed',
#   'report',
#   'to',
#   '@mention'],
#  ['@mention',
#   'current',
#   'bug',
#   'on',
#   'website',
#   'shows',
#   'select',
#   'departure',
#   'city',
#   'when',
#   'selecting',
#   'destination',
#   'city',
#   '@url'],
#  ['@mention',
#   'luggage',
#   'was',
#   'severely',
#   'dented',
#   'missing',
#   'wheel',
#   'coming',
#   'off',
#   'baggage',
#   'claim',
#   'in',
#   'san',
#   'luggage',
#   'agent',
#   'miranda',
#   'i',
#   'think',
#   'wasn',
#   't',
#   'any',
#   'help'],
#  ['@mention',
#   'thank',
#   'you',
#   'for',
#   'the',
#   'easy',
#   'itinerary',
#   'shift',
#   'for',
#   'impending',
#   'weather',
#   'quick',
#   'painless',
#   'amp',
#   'free'],
#  ['@mention',
#   'if',
#   'you',
#   'd',
#   'love',
#   'to',
#   'see',
#   'more',
#   'girls',
#   'be',
#   'inspired',
#   'to',
#   'become',
#   'pilots',
#   'rt',
#   'our',
#   'free',
#   'woaw',
#   'event',
#   'march',
#   '@number',
#   '@number',
#   'at',
#   'abq',
#   '@url'],
#  ['@mention',
#   'thanks',
#   'good',
#   'times',
#   'there',
#   'and',
#   'back',
#   '@hashtag',
#   'the',
#   'entire',
#   'flight',
#   '@emoji',
#   '@hashtag'],
#  ['@mention',
#   'beats',
#   'expectations',
#   'shares',
#   'take',
#   'off',
#   'santa',
#   'cruz',
#   'sentinel',
#   '@url'],
#  ['@mention',
#   'any',
#   'plans',
#   'to',
#   'start',
#   'flying',
#   'direct',
#   'from',
#   'dal',
#   'to',
#   'las'],
#  ['@mention',
#   'big',
#   'love',
#   'gratitude',
#   'mpower',
#   'w',
#   '@url',
#   'werin',
#   '@hashtag',
#   'vipswagbags@',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'you',
#   're',
#   'doing',
#   'a',
#   'great',
#   'job',
#   'adding',
#   'little',
#   'luxuries',
#   'aesthetics',
#   'that',
#   'improve',
#   'the',
#   'air',
#   'travel',
#   'experience',
#   'thank',
#   'you',
#   'keep',
#   'it',
#   'up'],
#  ['@mention',
#   'requested',
#   'window',
#   'seat',
#   'and',
#   'confirmed',
#   'window',
#   'but',
#   'got',
#   'stuck',
#   'in',
#   'middle',
#   'seat',
#   'not',
#   'a',
#   'good',
#   'way',
#   'to',
#   'treat',
#   'silver',
#   'member',
#   '@emoji'],
#  ['@mention', 'grand', 'budapest', 'hotel', '@hashtag'],
#  ['@mention',
#   'this',
#   'is',
#   'what',
#   'you',
#   'missed',
#   '@mention',
#   'next',
#   'trip',
#   'to',
#   'the',
#   '@number'],
#  ['@mention',
#   '@hashtag',
#   'i',
#   'paid',
#   'for',
#   'direct',
#   'flight',
#   'on',
#   'purpose',
#   'not',
#   'to',
#   'have',
#   'to',
#   'stop',
#   'for',
#   'fuel',
#   'exhausted',
#   'frequent',
#   'flier',
#   'and',
#   'nothing',
#   'for',
#   'inconvenience'],
#  ['@mention',
#   'there',
#   'is',
#   'something',
#   'wrong',
#   'with',
#   'you',
#   'website',
#   'in',
#   'safari',
#   'iphone'],
#  ['@mention',
#   'thanks',
#   'for',
#   'gate',
#   'checking',
#   'my',
#   'baggage',
#   'on',
#   'your',
#   'full',
#   'flight',
#   'dfw',
#   'lax',
#   '@number',
#   'and',
#   'giving',
#   'me',
#   'early',
#   'boarding',
#   'too',
#   '@hashtag'],
#  ['@mention',
#   'already',
#   'checked',
#   'in',
#   'so',
#   'the',
#   'page',
#   'expired',
#   '@emoji'],
#  ['@mention',
#   'boo',
#   'for',
#   'a',
#   'not',
#   'refunding',
#   'a',
#   'seat',
#   'upgrade',
#   'fee',
#   'i',
#   'did',
#   'not',
#   'want',
#   'to',
#   'buy',
#   'in',
#   'the',
#   'first',
#   'place'],
#  ['@mention',
#   'shares',
#   'rise',
#   'on',
#   'q',
#   '@number',
#   'financial',
#   'results',
#   'usa',
#   'today',
#   '@url'],
#  ['@mention',
#   'adds',
#   'pillows',
#   'instead',
#   'of',
#   'lie',
#   'flat',
#   'seats',
#   'in',
#   'first',
#   'class',
#   'arms',
#   'race',
#   '@url'],
#  ['@mention', 'i', 'see', 'what', 'you', 'did', 'there', '@emoji'],
#  ['@mention', 'way', 'to', 'take', 'advantage', 'of', '@hashtag', '@emoji'],
#  ['@mention',
#   'you',
#   'know',
#   'i',
#   'm',
#   'flying',
#   'virgin',
#   'for',
#   'the',
#   'fight',
#   '@hashtag'],
#  ['@mention',
#   'your',
#   'inflight',
#   'team',
#   'makes',
#   'the',
#   'experience',
#   '@hashtag'],
#  ['@mention',
#   'cutest',
#   'salt',
#   'and',
#   'pepper',
#   'shaker',
#   'ever',
#   'just',
#   'when',
#   'i',
#   'think',
#   'you',
#   'guys',
#   'can',
#   't',
#   'get',
#   'any',
#   'better',
#   'you',
#   'just',
#   'do',
#   '@url'],
#  ['@mention',
#   'moved',
#   'my',
#   'seat',
#   'with',
#   'no',
#   'notice',
#   'better',
#   'seat',
#   'is',
#   'cabin',
#   'select',
#   'not',
#   'behind',
#   'the',
#   'row',
#   'i',
#   'selected',
#   '@emoji',
#   '@hashtag'],
#  ['@mention',
#   'shares',
#   'up',
#   'on',
#   '@number',
#   'q',
#   'results',
#   '@mention',
#   '@url'],
#  ['@mention', 'fav', 'airline'],
#  ['@mention',
#   'we',
#   'have',
#   'a',
#   'hot',
#   'female',
#   'pilot',
#   'sweet',
#   'dca',
#   'to',
#   'sfo',
#   '@emoji'],
#  ['@emoji',
#   '@emoji',
#   'when',
#   'are',
#   'you',
#   'guys',
#   'going',
#   'to',
#   'start',
#   'flying',
#   'to',
#   'paris',
#   '@mention',
#   '@mention',
#   'you',
#   're',
#   'welcome'],
#  ['@mention',
#   'what',
#   'is',
#   'your',
#   'policy',
#   'on',
#   'flying',
#   'after',
#   'surgery',
#   'i',
#   'am',
#   'still',
# ...
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'empathizes',
#   'w',
#   'my',
#   'disappointment',
#   'that',
#   '@number',
#   'stclass',
#   'flight',
#   'w',
#   'nonworking',
#   'entertainmnt',
#   'is',
#   'worth',
#   '@number',
#   '@hashtag',
#   '@url'],
#  ['@mention', 'and', 'when', 'that', 'doesn', 't', 'work'],
#  ['@mention',
#   'did',
#   'you',
#   'have',
#   'seen',
#   'my',
#   'message',
#   'today',
#   'about',
#   'a',
#   'mcdonnell',
#   'douglas',
#   'dc',
#   '@number',
#   'model',
#   'i',
#   'will',
#   'hear',
#   'it',
#   'if',
#   'you',
#   'read',
#   'it',
#   'goodnight',
#   'now'],
#  ['@mention',
#   'searched',
#   'for',
#   'mileage',
#   'tickets',
#   'to',
#   'bom',
#   'couldn',
#   't',
#   'find',
#   'a',
#   'single',
#   'one',
#   'is',
#   'saver',
#   'awards',
#   'i',
#   'see',
#   'how',
#   'you',
#   'play',
#   'earn',
#   'miles',
#   'but',
#   'can',
#   't',
#   'use',
#   'them'],
#  ['@mention',
#   'flight',
#   'arrives',
#   '@number',
#   'minutes',
#   'early',
#   'but',
#   'then',
#   'have',
#   'we',
#   'to',
#   'wait',
#   'for',
#   'an',
#   'hour',
#   'for',
#   'our',
#   'bags'],
#  ['@mention',
#   'that',
#   's',
#   'not',
#   'the',
#   'issue',
#   'the',
#   'fact',
#   'that',
#   'no',
#   'one',
#   'even',
#   'called',
#   'despite',
#   'promises',
#   'to',
#   'confirm',
#   'the',
#   'bag',
#   's',
#   'location',
#   'is'],
#  ['@mention',
#   'what',
#   's',
#   'a',
#   'girl',
#   'gotta',
#   'do',
#   'to',
#   'get',
#   'a',
#   'flight',
#   'name',
#   'change',
#   'when',
#   'she',
#   'bought',
#   'one',
#   'for',
#   'a',
#   'mean',
#   'ex',
#   'boyfriend',
#   'and',
#   'needs',
#   'a',
#   'girl',
#   's',
#   'trip',
#   'stat'],
#  ['@mention',
#   'thank',
#   'you',
#   'we',
#   'are',
#   'signed',
#   'up',
#   'for',
#   'notifications',
#   'we',
#   'shall',
#   'watch',
#   'and',
#   'wait',
#   '@emoji'],
#  ['@mention',
#   'still',
#   'waiting',
#   'to',
#   'hear',
#   'back',
#   'my',
#   'wallet',
#   'was',
#   'stolen',
#   'from',
#   'one',
#   'of',
#   'your',
#   'planes',
#   'so',
#   'would',
#   'appreciate',
#   'a',
#   'resolution',
#   'here'],
#  ['@mention',
#   'i',
#   'would',
#   'love',
#   'if',
#   'someone',
#   'could',
#   'get',
#   'me',
#   'back',
#   'to',
#   'austin',
#   'tonight',
#   'and',
#   'i',
#   'do',
#   'not',
#   'wish',
#   'to',
#   'wait',
#   'til',
#   'tomorrow',
#   'morning'],
#  ['@mention',
#   'or',
#   '@mention',
#   'has',
#   'lost',
#   'my',
#   'baggage',
#   'heard',
#   'different',
#   'things',
#   'from',
#   'different',
#   'employees',
#   'of',
#   '@mention',
#   '@mention',
#   'has',
#   'said',
#   'nothing'],
#  ['@mention',
#   'cs',
#   'thinks',
#   'that',
#   'miles',
#   'can',
#   'repair',
#   'the',
#   'damage',
#   'done',
#   'it',
#   'will',
#   'be',
#   'interesting',
#   'if',
#   'they',
#   'travel',
#   'in',
#   '@mention',
#   'and',
#   'exp',
#   'the',
#   'worst',
#   'flight',
#   'ever'],
#  ['@mention',
#   'i',
#   'have',
#   'a',
#   '@number',
#   'flight',
#   'out',
#   'of',
#   'dfw',
#   'on',
#   'tuesday',
#   'how',
#   'far',
#   'in',
#   'advance',
#   'will',
#   'you',
#   'give',
#   'notice',
#   'if',
#   'cancelled',
#   'flightled'],
#  ['@mention',
#   'i',
#   'am',
#   'signed',
#   'up',
#   'for',
#   'notifications',
#   'this',
#   'is',
#   'the',
#   'first',
#   'trip',
#   'i',
#   'was',
#   'not',
#   'updated',
#   'on',
#   'not',
#   'sure',
#   'why',
#   'this',
#   'happened'],
#  ['@mention',
#   'thank',
#   'you',
#   'took',
#   'care',
#   'of',
#   'everything',
#   'and',
#   'made',
#   'it',
#   'right',
#   'that',
#   's',
#   'the',
#   'experience',
#   'i',
#   'm',
#   'used',
#   'to',
#   'opened',
#   'the',
#   'app',
#   'to',
#   'find',
#   'flight',
#   'changed'],
#  ['@mention',
#   'that',
#   'is',
#   'not',
#   'in',
#   'line',
#   'with',
#   'your',
#   'responses',
#   'here',
#   'and',
#   'now',
#   'i',
#   'm',
#   'waiting',
#   'until',
#   'tomorrow',
#   'morning',
#   'because',
#   'all',
#   'the',
#   'flights',
#   'are',
#   'overbooked'],
#  ['@mention',
#   'i',
#   'took',
#   'the',
#   'exact',
#   'same',
#   'aircraft',
#   'in',
#   'to',
#   'lax',
#   '@number',
#   'days',
#   'ago',
#   'it',
#   'fit',
#   'no',
#   'problem',
#   'the',
#   'agent',
#   'today',
#   'told',
#   'some',
#   'nonsense',
#   'about',
#   'a',
#   'policy',
#   'change'],
#  ['@mention',
#   'your',
#   'helpful',
#   'agents',
#   'in',
#   'club',
#   'helped',
#   'i',
#   'am',
#   'just',
#   'out',
#   'baggage',
#   'fees',
#   'and',
#   'a',
#   'night',
#   'of',
#   'my',
#   'life',
#   'stop',
#   'doing',
#   'business',
#   'with',
#   '@mention'],
#  ['@mention', 'never', 'heard', 'of', 'this', '@url'],
#  ['@mention',
#   'doesn',
#   't',
#   'charge',
#   'ticket',
#   'change',
#   'fees',
#   'do',
#   'they',
#   'not',
#   'incur',
#   'the',
#   'same',
#   'mysterious',
#   'costs',
#   'that',
#   'you',
#   'incur',
#   '@mention'],
#  ['@mention',
#   'exhausted',
#   'amp',
#   'frustrated',
#   'link',
#   'to',
#   'a',
#   'fb',
#   'post',
#   'abt',
#   'my',
#   'travel',
#   'issue',
#   '@url'],
#  ['@mention',
#   'i',
#   'was',
#   'denied',
#   'getting',
#   'on',
#   'the',
#   'plane',
#   'w',
#   'o',
#   'getting',
#   'the',
#   'chance',
#   'to',
#   'prove',
#   'it',
#   'fits',
#   'i',
#   'm',
#   'not',
#   'a',
#   'rookie',
#   'read',
#   'my',
#   'bio'],
#  ['@mention',
#   'that',
#   's',
#   'exactly',
#   'the',
#   'point',
#   'it',
#   'fits',
#   'i',
#   'm',
#   'premier',
#   'access',
#   'boarding',
#   'group',
#   '@number',
#   'this',
#   'was',
#   'a',
#   'return',
#   'ticket',
#   'i',
#   've',
#   'been',
#   'doing',
#   'this',
#   'for',
#   '@number',
#   'yrs'],
#  ['@mention',
#   'i',
#   've',
#   'never',
#   'experienced',
#   'worst',
#   'customer',
#   'service',
#   'placing',
#   'blame',
#   'on',
#   'codeshare',
#   'partners',
#   'and',
#   'not',
#   'assuming',
#   'responsibility',
#   'is',
#   'unacceptable'],
#  ['@mention',
#   'currently',
#   'on',
#   'board',
#   'so',
#   'not',
#   'now',
#   'check',
#   'in',
#   'was',
#   'terrible',
#   'staff',
#   'rude',
#   'expensive',
#   'luggage',
#   'thrown',
#   'around',
#   'etc'],
#  ['@mention',
#   'fucked',
#   'up',
#   'then',
#   'voided',
#   'my',
#   'ticket',
#   'and',
#   'kept',
#   'my',
#   'money',
#   'not',
#   'even',
#   'an',
#   'apology',
#   'i',
#   'will',
#   'never',
#   'fly',
#   'with',
#   'your',
#   'airline',
#   'again',
#   '@hashtag'],
#  ['@mention',
#   'has',
#   'the',
#   'worst',
#   'customer',
#   'svcs',
#   'this',
#   'kevin',
#   'rep',
#   'at',
#   'call',
#   'center',
#   'must',
#   'be',
#   'investigated',
#   'my',
#   'baggage',
#   's',
#   'lost',
#   'and',
#   'there',
#   's',
#   'no',
#   'help',
#   'but',
#   'argument'],
#  ['@mention',
#   'should',
#   'not',
#   'sell',
#   'tickets',
#   'for',
#   '@mention',
#   'on',
#   '@url',
#   'has',
#   'terrible',
#   'service',
#   'and',
#   'ua',
#   'staff',
#   'cannot',
#   'reach',
#   'silver'],
#  ['@mention',
#   'just',
#   'got',
#   'demoted',
#   'from',
#   'gold',
#   'cuz',
#   'my',
#   'hubby',
#   'got',
#   '@number',
#   'of',
#   'the',
#   'pqd',
#   'tho',
#   'there',
#   'were',
#   'enuf',
#   'spent',
#   'for',
#   '@number',
#   'golds',
#   '@hashtag'],
#  ['@mention', 'thank', 'you'],
#  ['@mention',
#   'when',
#   'will',
#   'direct',
#   'flights',
#   'from',
#   'belfast',
#   'intl',
#   'to',
#   'newark',
#   'resume',
#   'from',
#   'their',
#   'winter',
#   'break',
#   'thanks'],
#  ['@mention', 'my', 'favorite', 'way', 'to', 'travel', 'thank', 'you', '@url'],
#  ['@mention',
#   'yes',
#   'after',
#   'this',
#   'awful',
#   'weather',
#   'it',
#   'appears',
#   'i',
#   'can',
#   'get',
#   'home'],
#  ['@mention',
#   'yes',
#   'lots',
#   'you',
#   'have',
#   'terrible',
#   'customer',
#   'service',
#   'at',
#   'newark',
#   'and',
#   'despite',
#   'raising',
#   'a',
#   'complaint',
#   'there',
#   'we',
#   'were',
#   'ignored',
#   'hence',
#   'the',
#   'tweet'],
#  ['@mention',
#   'lovely',
#   'new',
#   'plane',
#   'from',
#   'lga',
#   'to',
#   'ord',
#   'but',
#   'no',
#   'power',
#   'outlets'],
#  ['@mention',
#   'but',
#   'if',
#   'i',
#   'tweet',
#   'the',
#   'id',
#   'number',
#   'won',
#   't',
#   'that',
#   'reveal',
#   'my',
#   'home',
#   'address',
#   'to',
#   'anyone',
#   'on',
#   'the',
#   'web'],
#  ['@mention',
#   'i',
#   'filed',
#   'a',
#   'delayed',
#   'bag',
#   'report',
#   'on',
#   'saturday',
#   'my',
#   'flight',
#   'was',
#   'cancelled',
#   'flightled',
#   'and',
#   'i',
#   'never',
#   'went',
#   'anywhere'],
#  ['@mention',
#   'the',
#   'person',
#   'is',
#   'currently',
#   'bettween',
#   'gates',
#   '@number',
#   'a',
#   'and',
#   '@number',
#   'in',
#   'lax'],
#  ['@mention',
#   'i',
#   'need',
#   'it',
#   'there',
#   'before',
#   'she',
#   'lands',
#   'so',
#   'she',
#   'can',
#   'have',
#   'the',
#   'ewr',
#   'baggage',
#   'claim',
#   'file',
#   'to',
#   'have',
#   'it',
#   'sent',
#   'but',
#   'the',
#   'employee',
#   'has',
#   'not',
#   'droppeditoffyet'],
#  ['@mention',
#   'rarely',
#   'ceases',
#   'to',
#   'amaze',
#   'for',
#   'the',
#   'worse',
#   'i',
#   'hope',
#   'this',
#   'is',
#   'the',
#   'last',
#   'time',
#   'i',
#   'have',
#   'to',
#   'fly',
#   'with',
#   'you'],
#  ['@mention',
#   'thank',
#   'you',
#   'for',
#   'the',
#   'quick',
#   'response',
#   'but',
#   'i',
#   'cannot',
#   'dm',
#   'you',
#   'until',
#   'you',
#   'follow',
#   'me',
#   'as',
#   'well'],
#  ['@mention',
#   'icloud',
#   'it',
#   'is',
#   'not',
#   'there',
#   'yet',
#   'please',
#   'help',
#   '@number',
#   '@number',
#   '@number'],
#  ['@mention',
#   'i',
#   'need',
#   'the',
#   'phone',
#   'number',
#   'to',
#   'baggage',
#   'claim',
#   'in',
#   'lax',
#   'my',
#   'mom',
#   'left',
#   'her',
#   'phone',
#   'and',
#   'someone',
#   'called',
#   'saying',
#   'they',
#   'would',
#   'put',
#   'it',
#   'there',
#   'but',
#   'on'],
#  ['@mention', 'i', 'did', 'no', 'response', 'back'],
#  ['@mention', 'this', 'is', 'atrocious', 'customer', 'service'],
#  ['@mention',
#   'will',
#   'not',
#   'have',
#   'to',
#   'honor',
#   'absurdly',
#   'low',
#   'mistake',
#   'fares',
#   '@url',
#   'vì',
#   'a',
#   '@mention'],
#  ['@mention',
#   '@hashtag',
#   'delayed',
#   'departure',
#   'to',
#   'check',
#   'bags',
#   'at',
#   'gate',
#   'claiming',
#   'space',
#   'filled',
#   'and',
#   'walk',
#   'on',
#   'to',
#   'open',
#   'spaces',
#   'a',
#   'delay',
#   '@hashtag'],
#  ['@mention',
#   'you',
#   'cancelled',
#   'flighted',
#   'our',
#   'flights',
#   'for',
#   'no',
#   'reason',
#   'amp',
#   'now',
#   'we',
#   'have',
#   'been',
#   'on',
#   'the',
#   'phone',
#   'for',
#   'an',
#   'hour',
#   'on',
#   'our',
#   'vacation',
#   'why'],
#  ['@mention',
#   '@mention',
#   'that',
#   's',
#   'your',
#   'response',
#   'shaking',
#   'my',
#   'head',
#   'back',
#   'and',
#   'forth',
#   'with',
#   'a',
#   'tsk',
#   'you',
#   'can',
#   'do',
#   'better',
#   'from',
#   'customer',
#   'service',
#   'to',
#   'your',
#   'apology'],
#  ['@mention',
#   'thanks',
#   'it',
#   's',
#   '@number',
#   'k',
#   'miles',
#   'from',
#   'rtb',
#   'to',
#   'europe',
#   'to',
#   'do',
#   'a',
#   'multiple',
#   'destination',
#   'so',
#   'we',
#   'could',
#   'stop',
#   'over',
#   'in',
#   'us',
#   'on',
#   'way',
#   'way',
#   'back',
#   'mileage',
#   'diff'],
#  ['@mention',
#   'of',
#   'course',
#   'i',
#   'did',
#   'the',
#   'bag',
#   'should',
#   'be',
#   'here',
#   'by',
#   'now',
#   '@emoji',
#   '@hashtag'],
#  ['@mention',
#   'you',
#   'are',
#   'the',
#   'worst',
#   'i',
#   'will',
#   'avoid',
#   'you',
#   'like',
#   'the',
#   'plague'],
#  ['@mention', 'is', 'the', 'worst', 'airline', 'in', 'the', 'world'],
#  ['@mention',
#   'someone',
#   'needs',
#   'to',
#   'dm',
#   'me',
#   'and',
#   'resolve',
#   'this',
#   'correctly',
#   'extremely',
#   'disappointed',
#   'with',
#   'the',
#   'service',
#   'i',
#   'received',
#   'terrible',
#   'management'],
#  ['@mention',
#   'premier',
#   'gold',
#   'desk',
#   'changes',
#   'flight',
#   'waives',
#   'fees',
#   'gives',
#   'me',
#   'wrong',
#   'flight',
#   'now',
#   'jana',
#   'acosta',
#   'in',
#   'salt',
#   'lake',
#   'refuses',
#   'the',
#   'same',
#   'service',
#   'angry'],
#  ['@mention',
#   'i',
#   'will',
#   'give',
#   'you',
#   'one',
#   'thing',
#   'you',
#   'are',
#   'consistent',
#   'but',
#   'unfortunately',
#   'you',
#   'are',
#   'consistent',
#   'at',
#   'not',
#   'doing',
#   'your',
#   'job',
#   'well',
#   '@hashtag'],
#  ['@mention', 'i', 'will', 'but', 'right', 'now', 'i', 'm', 'to', 'angry'],
#  ['@mention',
#   'first',
#   'time',
#   'flying',
#   'with',
#   'united',
#   'also',
#   'last',
#   'time',
#   '@hashtag',
#   'back',
#   'to',
#   '@mention',
#   'for',
#   'me',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'i',
#   'used',
#   'to',
#   'be',
#   'a',
#   'committed',
#   '@hashtag',
#   'flyer',
#   'until',
#   'merger',
#   'i',
#   'remember',
#   'now',
#   'why',
#   'i',
#   'switched',
#   'to',
#   '@mention',
#   '@hashtag'],
#  ['@mention',
#   'the',
#   'least',
#   'you',
#   'could',
#   'do',
#   'is',
#   'offer',
#   'me',
#   'a',
#   'ticket',
#   'in',
#   'coach',
#   'instead',
#   'of',
#   'just',
#   'cancelled',
#   'flighting',
#   'my',
#   'reservation',
#   'because',
#   'of',
#   'your',
#   'glitch',
#   '@hashtag'],
#  ['@mention',
#   'i',
#   'm',
#   'saying',
#   'i',
#   'made',
#   'the',
#   'flight',
#   'but',
#   'with',
#   'poor',
#   'non',
#   'communication',
#   'unaccounted',
#   'for',
#   'lost',
#   'time',
#   'amp',
#   'lots',
#   'of',
#   'frustrated',
#   'flyers',
#   'standing',
#   'around'],
#  ['@mention', 'i', 'think', 'dm', 'would', 'be', 'better'],
#  ['@mention',
#   'gate',
#   'announcement',
#   'states',
#   'delay',
#   'due',
#   'to',
#   'maintenance',
#   'yet',
#   'app',
#   'says',
#   'late',
#   'flight',
#   'arriving',
#   'aircraft',
#   'tell',
#   'the',
#   'truth',
#   '@mention'],
#  ['@mention',
#   'you',
#   'are',
#   'easily',
#   'the',
#   'worst',
#   'company',
#   'i',
#   'have',
#   'ever',
#   'experienced',
#   'you',
#   'have',
#   'lost',
#   'someone',
#   's',
#   'personal',
#   'possessions',
#   'amp',
#   'you',
#   'couldn',
#   't',
#   'care',
#   'less'],
#  ['@mention',
#   'how',
#   'can',
#   'your',
#   'app',
#   'show',
#   'arriving',
#   'aircraft',
#   'is',
#   'early',
#   'but',
#   'departing',
#   'flight',
#   'is',
#   'delayed',
#   'due',
#   'to',
#   'late',
#   'flight',
#   'arriving',
#   'aircraft',
#   '@mention'],
#  ['@mention',
#   'already',
#   'did',
#   'that',
#   'at',
#   'the',
#   'airport',
#   'and',
#   '@number',
#   'hrs',
#   'late',
#   'flightr',
#   'its',
#   'still',
#   'not',
#   'here',
#   'you',
#   'guys',
#   'are',
#   'really',
#   'killing',
#   'me',
#   'today',
#   'trying',
#   'to',
#   'stay',
#   'positive'],
#  ['@mention',
#   'once',
#   'united',
#   's',
#   'service',
#   'levels',
#   'reaches',
#   'those',
#   'of',
#   'etihad',
#   'or',
#   'lets',
#   'be',
#   'more',
#   'realistically',
#   'lufthansa',
#   'then',
#   'ill',
#   'consider',
#   'it',
#   'again'],
#  ['@mention',
#   'really',
#   'someone',
#   'called',
#   'in',
#   'sick',
#   'and',
#   'then',
#   'someone',
#   'forgot',
#   'to',
#   'call',
#   'a',
#   'replacement',
#   'now',
#   'an',
#   'hour',
#   'late',
#   'flight',
#   'to',
#   'take',
#   'off',
#   '@hashtag'],
#  ['@mention',
#   'asked',
#   'flight',
#   'attendant',
#   'what',
#   'typical',
#   'compensation',
#   'would',
#   'be',
#   'amp',
#   'says',
#   'we',
#   'might',
#   'get',
#   'free',
#   'tv',
#   '@hashtag'],
#  ['@mention', 'done'],
#  ['@mention',
#   'thank',
#   'you',
#   'jh',
#   'appreciate',
#   'the',
#   'prompt',
#   'responses',
#   'me',
#   'and',
#   'other',
#   'passengers',
#   'will',
#   'be',
#   'doing',
#   'so'],
#  ['@mention',
#   'has',
#   'been',
#   'such',
#   'a',
#   'disappointment',
#   'today',
#   'simply',
#   'put',
#   'rather',
#   'unpleased',
#   'with',
#   'things',
#   'currently',
#   'flight',
#   'delayed',
#   'cant',
#   'wait',
#   'to',
#   'just',
#   'get',
#   'home'],
#  ['@mention',
#   'during',
#   'the',
#   'same',
#   'round',
#   'trip',
#   'my',
#   'non',
#   'english',
#   'speaking',
#   'friend',
#   'was',
#   'stranded',
#   'twice',
#   'for',
#   '@number',
#   'hours',
#   'each',
#   'time',
#   'most',
#   'staff',
#   'members',
#   'were',
#   'rude'],
#  ['@mention',
#   'found',
#   'a',
#   'group',
#   'of',
#   'people',
#   'who',
#   'actually',
#   'hates',
#   'people',
#   'more',
#   'than',
#   'isis',
#   'thats',
#   'right',
#   'united',
#   'airlines'],
#  ['@mention',
#   'nope',
#   'walked',
#   'up',
#   'amp',
#   'down',
#   'the',
#   'orf',
#   'terminal',
#   'amp',
#   'not',
#   'a',
#   'united',
#   'agent',
#   'to',
#   'be',
#   'found',
#   'showed',
#   'up',
#   '@',
#   'last',
#   'minute',
#   'to',
#   'board',
#   'us',
#   'many',
#   'panicked',
#   'people'],
#  ['@mention', 'thank', 'you'],
#  ['@mention',
#   'by',
#   'the',
#   'time',
#   'i',
#   'finally',
#   'get',
#   'to',
#   'dallas',
#   'i',
#   'could',
#   'have',
#   'driven',
#   'with',
#   'less',
#   'frustration',
#   'and',
#   'cheaper'],
#  ['@mention',
#   'i',
#   'm',
#   'trying',
#   'to',
#   'get',
#   'to',
#   'my',
#   'final',
#   'destination',
#   'we',
#   'need',
#   'compensation',
#   'just',
#   'about',
#   '@number',
#   'hrs',
#   'of',
#   'personal',
#   'time',
#   'wasted'],
#  ['@mention',
#   'that',
#   'guy',
#   'really',
#   'has',
#   'no',
#   'customer',
#   'service',
#   'clue',
#   'could',
#   'have',
#   'spent',
#   'effort',
#   'clearing',
#   'bins',
#   'for',
#   'rollerboards',
#   'instead',
#   'of',
#   'art',
#   'projects',
#   'in',
#   'mine'],
#  ['@mention', 'he', 'has', 'no', 'priority', 'and', 'iove', 'it'],
#  ['@mention', 'pleased', 'to', 'be', 'a', 'premier', 'platinum'],
#  ...]

# %% [markdown]
# ## 3 - Remove Stopwords:

# %%
stop_words = stopwords.words('english')

# %%
# Removing quotes
stop_words_wq = []
for w in stop_words:
    w = re.sub("\'", "", w)
    stop_words_wq.append(w)

# %%
stop_words_wq
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  'youre',
#  'youve',
#  'youll',
#  'youd',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  'shes',
#  'her',
#  'hers',
#  'herself',
#  'it',
#  'its',
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  'thatll',
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  'dont',
#  'should',
#  'shouldve',
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  'arent',
#  'couldn',
#  'couldnt',
#  'didn',
#  'didnt',
#  'doesn',
#  'doesnt',
#  'hadn',
#  'hadnt',
#  'hasn',
#  'hasnt',
#  'haven',
#  'havent',
#  'isn',
#  'isnt',
#  'ma',
#  'mightn',
#  'mightnt',
#  'mustn',
#  'mustnt',
#  'needn',
#  'neednt',
#  'shan',
#  'shant',
#  'shouldn',
#  'shouldnt',
#  'wasn',
#  'wasnt',
#  'weren',
#  'werent',
#  'won',
#  'wont',
#  'wouldn',
#  'wouldnt']

# %%
no_sw=[]
for phrase in word_tokens:
    no_sw_tmp=[]
    for word in phrase:
        if word not in stop_words_wq:
            no_sw_tmp.append(word)
    no_sw.append(no_sw_tmp)

# %%
no_sw
# Out:
# [['@mention', '@mention', 'said'],
#  ['@mention', 'plus', 'added', 'commercials', 'experience', 'tacky'],
#  ['@mention', 'today', 'must', 'mean', 'need', 'take', 'another', 'trip'],
#  ['@mention',
#   'really',
#   'aggressive',
#   'blast',
#   'obnoxious',
#   'entertainment',
#   'guests',
#   'faces',
#   'amp',
#   'little',
#   'recourse'],
#  ['@mention', 'really', 'big', 'bad', 'thing'],
#  ['@mention',
#   'seriously',
#   'would',
#   'pay',
#   '@number',
#   'flight',
#   'seats',
#   'playing',
#   'really',
#   'bad',
#   'thing',
#   'flying',
#   'va'],
#  ['@mention',
#   'yes',
#   'nearly',
#   'every',
#   'time',
#   'fly',
#   'vx',
#   '@emoji',
#   'worm',
#   'go',
#   'away',
#   '@emoji'],
#  ['@mention',
#   'really',
#   'missed',
#   'prime',
#   'opportunity',
#   'men',
#   'without',
#   'hats',
#   'parody',
#   '@url'],
#  ['@mention', 'well', 'tbut', '@emoji'],
#  ['@mention', 'amazing', 'arrived', 'hour', 'early', 'good'],
#  ['@mention',
#   'know',
#   'suicide',
#   'second',
#   'leading',
#   'cause',
#   'death',
#   'among',
#   'teens',
#   '@number',
#   '@number'],
#  ['@mention',
#   'lt',
#   '@number',
#   'pretty',
#   'graphics',
#   'much',
#   'better',
#   'minimal',
#   'iconography',
#   '@emoji'],
#  ['@mention',
#   'great',
#   'deal',
#   'already',
#   'thinking',
#   '@number',
#   'nd',
#   'trip',
#   '@mention',
#   'amp',
#   'even',
#   'gone',
#   '@number',
#   'st',
#   'trip',
#   'yet',
#   '@emoji'],
#  ['@mention',
#   '@mention',
#   'flying',
#   '@hashtag',
#   '@hashtag',
#   'skies',
#   'u',
#   'take',
#   '@hashtag',
#   'away',
#   'travel',
#   '@url'],
#  ['@mention', 'thanks'],
#  ['@mention', 'sfo', 'pdx', 'schedule', 'still', 'mia'],
#  ['@mention',
#   'excited',
#   'first',
#   'cross',
#   'country',
#   'flight',
#   'lax',
#   'mco',
#   'heard',
#   'nothing',
#   'great',
#   'things',
#   'virgin',
#   'america',
#   '@hashtag'],
#  ['@mention',
#   'flew',
#   'nyc',
#   'sfo',
#   'last',
#   'week',
#   'fully',
#   'sit',
#   'seat',
#   'due',
#   'two',
#   'large',
#   'gentleman',
#   'either',
#   'side',
#   'help'],
#  ['@emoji', 'flying', '@mention', '@emoji'],
#  ['@mention',
#   'know',
#   'would',
#   'amazingly',
#   'awesome',
#   'bos',
#   'fll',
#   'please',
#   'want',
#   'fly'],
#  ['@mention',
#   'first',
#   'fares',
#   'may',
#   'three',
#   'times',
#   'carriers',
#   'seats',
#   'available',
#   'select'],
#  ['@mention', 'love', 'graphic', '@url'],
#  ['@mention', 'love', 'hipster', 'innovation', 'feel', 'good', 'brand'],
#  ['@mention',
#   'making',
#   'bos',
#   'gt',
#   'las',
#   'non',
#   'stop',
#   'permanently',
#   'anytime',
#   'soon'],
#  ['@mention',
#   'guys',
#   'messed',
#   'seating',
#   'reserved',
#   'seating',
#   'friends',
#   'guys',
#   'gave',
#   'seat',
#   'away',
#   '@emoji',
#   'want',
#   'free',
#   'internet'],
#  ['@mention',
#   'status',
#   'match',
#   'program',
#   'applied',
#   'three',
#   'weeks',
#   'called',
#   'emailed',
#   'response'],
#  ['@mention',
#   'happened',
#   '@number',
#   'ur',
#   'vegan',
#   'food',
#   'options',
#   'least',
#   'say',
#   'ur',
#   'site',
#   'know',
#   'able',
#   '@number',
#   'eat',
#   'anything',
#   'next',
#   '@number',
#   'hrs',
#   '@hashtag'],
#  ['@mention', 'miss', 'worry', 'together', 'soon'],
#  ['@mention',
#   'amazing',
#   'get',
#   'cold',
#   'air',
#   'vents',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'lax',
#   'ewr',
#   'middle',
#   'seat',
#   'red',
#   'eye',
#   'noob',
#   'maneuver',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'hi',
#   'bked',
#   'cool',
#   'birthday',
#   'trip',
#   'add',
#   'elevate',
#   'cause',
#   'entered',
#   'middle',
#   'name',
#   'flight',
#   'booking',
#   'problems',
#   '@emoji'],
#  ['@mention',
#   'hours',
#   'operation',
#   'club',
#   'sfo',
#   'posted',
#   'online',
#   'current'],
#  ['@mention',
#   'help',
#   'left',
#   'expensive',
#   'headphones',
#   'flight',
#   '@number',
#   'iad',
#   'lax',
#   'today',
#   'seat',
#   '@number',
#   'one',
#   'answering',
#   'l',
#   'amp',
#   'f',
#   'number',
#   'lax'],
#  ['@mention',
#   'awaiting',
#   'return',
#   'phone',
#   'call',
#   'would',
#   'prefer',
#   'use',
#   'online',
#   'self',
#   'service',
#   'option',
#   '@emoji'],
#  ['@mention',
#   'great',
#   'news',
#   'america',
#   'could',
#   'start',
#   'flights',
#   'hawaii',
#   'end',
#   'year',
#   '@url',
#   'via',
#   '@mention'],
#  ['nice',
#   'rt',
#   '@mention',
#   'vibe',
#   'moodlight',
#   'takeoff',
#   'touchdown',
#   '@hashtag',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'moodlighting',
#   'way',
#   'fly',
#   'best',
#   'experience',
#   'ever',
#   'cool',
#   'calming',
#   '@emoji',
#   '@emoji',
#   '@hashtag'],
#  ['@mention',
#   '@mention',
#   'done',
#   'done',
#   'best',
#   'airline',
#   'around',
#   'hands'],
#  ['@mention', 'book', 'flight', 'hawaii'],
#  ['@mention', 'chat', 'support', 'working', 'site', '@url'],
#  ['@mention',
#   'view',
#   'downtown',
#   'los',
#   'angeles',
#   'hollywood',
#   'sign',
#   'beyond',
#   'rain',
#   'mountains',
#   '@url'],
#  ['@mention',
#   'hey',
#   'first',
#   'time',
#   'flyer',
#   'next',
#   'week',
#   'excited',
#   'hard',
#   'time',
#   'getting',
#   'flights',
#   'added',
#   'elevate',
#   'account',
#   'help'],
#  ['@mention',
#   'plz',
#   'help',
#   'win',
#   'bid',
#   'upgrade',
#   'flight',
#   '@number',
#   '@number',
#   'lax',
#   'gt',
#   'sea',
#   '@emoji',
#   '@emoji'],
#  ['@mention',
#   'unused',
#   'ticket',
#   'moved',
#   'new',
#   'city',
#   'fly',
#   'fly',
#   'expires',
#   '@hashtag'],
#  ['@mention',
#   'flights',
#   'leaving',
#   'dallas',
#   'seattle',
#   'time',
#   'feb',
#   '@number'],
#  ['@mention', '@hashtag', 'good', 'reason', 'rock'],
#  ['@mention', 'dream', '@url', '@url'],
#  ['@mention', 'wow', 'blew', 'mind'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   'last',
#   'night',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@mention',
#   'think',
#   '@mention',
#   'agree'],
#  ['@mention', '@mention', '@mention', 'entertaining'],
#  ['@mention',
#   'flight',
#   '@number',
#   'way',
#   'supposed',
#   'take',
#   '@number',
#   'minutes',
#   'ago',
#   'website',
#   'still',
#   'shows',
#   'time',
#   'flight',
#   'thanks'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   'julie',
#   'andrews',
#   'way',
#   'though',
#   '@mention',
#   'impressive',
#   '@mention'],
#  ['@mention', 'wish', 'flew', 'atlanta', 'soon'],
#  ['@mention', '@mention', '@mention', 'julie', 'andrews', 'hands'],
#  ['@mention',
#   'flights',
#   'leaving',
#   'dallas',
#   'la',
#   'february',
#   '@number',
#   'th'],
#  ['@mention',
#   'hi',
#   'excited',
#   '@number',
#   'lga',
#   'gt',
#   '@emoji',
#   'deal',
#   'trying',
#   '@number',
#   'book',
#   'since',
#   'last',
#   'week',
#   'amp',
#   'page',
#   'never',
#   'loads',
#   'thx'],
#  ['@mention', 'know', 'need', 'spotify', 'stat', '@hashtag'],
#  ['@mention', '@mention', '@mention', 'lady', 'gaga', 'amazing', '@emoji'],
#  ['@mention', '@mention', '@mention', 'carrie'],
#  ['@mention',
#   'new',
#   'marketing',
#   'song',
#   '@url',
#   'let',
#   'us',
#   'know',
#   'think'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   'julie',
#   'andrews',
#   'first',
#   'lady',
#   'gaga',
#   'wow',
#   'last',
#   'night',
#   'carrie',
#   'meh'],
#  ['@mention',
#   'called',
#   '@number',
#   '@number',
#   'weeks',
#   'ago',
#   'adding',
#   '@number',
#   'flights',
#   '@number',
#   'elevate',
#   'still',
#   'shown',
#   'help'],
#  ['@mention', '@mention', '@mention', 'great', 'go', '@hashtag', '@emoji'],
#  ['@mention', '@mention', '@mention', 'sorry', 'mary', 'martin', 'first'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   'love',
#   'three',
#   'really',
#   'beat',
#   'classics'],
#  ['@mention',
#   'flight',
#   '@number',
#   'dal',
#   'dca',
#   '@number',
#   '@number',
#   '@number',
#   '@number',
#   'pm',
#   'tried',
#   'check',
#   'could',
#   'status',
#   'please'],
#  ['@mention',
#   'heyyyy',
#   'guyyyys',
#   'trying',
#   'get',
#   'hour',
#   'someone',
#   'call',
#   'please',
#   '@emoji'],
#  ['@mention',
#   'hi',
#   'virgin',
#   'hold',
#   '@number',
#   '@number',
#   'minutes',
#   'earlier',
#   'flights',
#   'la',
#   'nyc',
#   'tonight',
#   'earlier',
#   '@number',
#   '@number',
#   'pm'],
#  ['@mention',
#   'congrats',
#   'winning',
#   '@mention',
#   'award',
#   'best',
#   'deals',
#   'airline',
#   'us',
#   '@url'],
#  ['@mention', 'everything', 'fine', 'lost', 'bag'],
#  ['@mention',
#   'need',
#   'change',
#   'reservation',
#   'virgin',
#   'credit',
#   'card',
#   'need',
#   'modify',
#   'phone',
#   'waive',
#   'change',
#   'fee',
#   'online'],
#  ['@mention',
#   'emailed',
#   'customer',
#   'service',
#   'team',
#   'let',
#   'know',
#   'need',
#   'tracking',
#   'number'],
#  ['@mention', 'hi', 'booked', 'flight', 'need', 'add', 'baggage'],
#  ['@mention',
#   'airline',
#   'awesome',
#   'lax',
#   'loft',
#   'needs',
#   'step',
#   'game',
#   '@number',
#   'dirty',
#   'tables',
#   'floors',
#   '@url'],
#  ['@mention',
#   'worried',
#   'great',
#   'ride',
#   'new',
#   'plane',
#   'great',
#   'crew',
#   'airlines',
#   'like'],
#  ['@mention',
#   'awesome',
#   'flew',
#   'yall',
#   'sat',
#   'morning',
#   'way',
#   'correct',
#   'bill'],
#  ['@mention',
#   'watch',
#   'best',
#   'student',
#   'films',
#   'country',
#   '@number',
#   '@number',
#   'feet',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'first',
#   'time',
#   'flying',
#   'different',
#   'rate',
#   'policy',
#   'media',
#   'bags',
#   'thanks'],
#  ['@mention',
#   'going',
#   'customer',
#   'service',
#   'anyway',
#   'speak',
#   'human',
#   'asap',
#   'thank'],
#  ['@mention', 'happened', 'doom'],
#  ['@mention',
#   'supp',
#   'biz',
#   'traveler',
#   'like',
#   '@mention',
#   'customer',
#   'service',
#   'like',
#   '@mention',
#   '@hashtag'],
#  ['@mention',
#   'applied',
#   'member',
#   '@hashtag',
#   'crew',
#   'team',
#   'im',
#   '@number',
#   'interested',
#   '@hashtag',
#   '@hashtag',
#   'g'],
#  ['@mention',
#   'best',
#   'whenever',
#   'begrudgingly',
#   'use',
#   'airline',
#   'delayed',
#   'late',
#   'flight',
#   '@emoji'],
#  ['@mention',
#   'interesting',
#   'flying',
#   'cancelled',
#   'flight',
#   'next',
#   'four',
#   'flights',
#   'planned',
#   '@hashtag'],
#  ['@mention',
#   'disappointing',
#   'experience',
#   'shared',
#   'every',
#   'business',
#   'traveler',
#   'meet',
#   '@hashtag'],
#  ['@mention',
#   'im',
#   'trouble',
#   'adding',
#   'flight',
#   'wife',
#   'booked',
#   'elevate',
#   'account',
#   'help',
#   '@url'],
#  ['@mention',
#   'bring',
#   'reservation',
#   'online',
#   'using',
#   'flight',
#   'booking',
#   'problems',
#   'code'],
#  ['@mention',
#   'random',
#   'q',
#   'distribution',
#   'elevate',
#   'avatars',
#   'bet',
#   'kitty',
#   'disproportionate',
#   'share',
#   '@url'],
#  ['@mention',
#   'lt',
#   '@number',
#   'flying',
#   'va',
#   'life',
#   'happens',
#   'trying',
#   '@hashtag',
#   'trip',
#   'jperhi',
#   'help',
#   'va',
#   'home',
#   'page',
#   'let'],
#  ['@mention', 'site', 'back'],
#  ['@mention', 'rnp', 'yeah', 'know'],
#  ['@mention',
#   'hi',
#   'get',
#   'points',
#   'elevate',
#   'account',
#   'recent',
#   'flight',
#   'add',
#   'flight',
#   'points',
#   'account'],
#  ['@mention',
#   'like',
#   'tv',
#   'interesting',
#   'video',
#   'disappointed',
#   'cancelled',
#   'flightled',
#   'flight',
#   'flights',
#   'went',
#   'jfk',
#   'saturday'],
#  ['@mention',
#   'landed',
#   'lax',
#   'hour',
#   'late',
#   'flight',
#   'bag',
#   'check',
#   'business',
#   'travel',
#   'friendly',
#   '@hashtag'],
#  ['@mention', 'flight', '@number', 'redirected'],
#  ['@mention',
#   'website',
#   'btw',
#   'new',
#   'website',
#   'great',
#   'user',
#   'experience',
#   'time',
#   'another',
#   'redesign'],
#  ['@mention',
#   'check',
#   'add',
#   'bag',
#   'website',
#   'working',
#   'tried',
#   'desktop',
#   'mobile',
#   '@url'],
#  ['@mention',
#   'let',
#   '@number',
#   'scanned',
#   'passengers',
#   'leave',
#   'plane',
#   'told',
#   'someone',
#   'remove',
#   'bag',
#   '@number',
#   'st',
#   'class',
#   'bin',
#   '@hashtag'],
#  ['@mention', 'phone', 'number', 'find', 'call', 'flight', 'reservation'],
#  ['@mention',
#   'anyone',
#   'anything',
#   'today',
#   'website',
#   'useless',
#   'one',
#   'answering',
#   'phone'],
#  ['@mention',
#   'trying',
#   'add',
#   'boy',
#   'prince',
#   'ressie',
#   'sf',
#   'thursday',
#   '@mention',
#   'lax',
#   '@url'],
#  ['@mention',
#   'must',
#   'traveler',
#   'miss',
#   'flight',
#   'late',
#   'flight',
#   'check',
#   'bag',
#   'missed',
#   'morning',
#   'appointments',
#   'lost',
#   'business',
#   '@hashtag'],
#  ['@mention', 'check', 'new', 'music', '@url'],
#  ['@mention',
#   'direct',
#   'flight',
#   'fll',
#   'gt',
#   'sfo',
#   'unexpected',
#   'layover',
#   'vegas',
#   '@number',
#   'fuel',
#   'yet',
#   'peeps',
#   'next',
#   'bought',
#   'vegas',
#   'flight',
#   '@hashtag'],
#  ['@mention',
#   'late',
#   'flight',
#   'bag',
#   'check',
#   'lost',
#   'business',
#   'missed',
#   'flight',
#   'apt',
#   'three',
#   'people',
#   'flight',
#   'exp'],
#  ['@mention',
#   'amazing',
#   'customer',
#   'service',
#   '@emoji',
#   'raeann',
#   'sf',
#   'best',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention', 'called', 'service', 'line', 'hung', 'awesome', '@hashtag'],
#  ['@mention',
#   'site',
#   'tripping',
#   'trying',
#   'check',
#   'getting',
#   'plain',
#   'text',
#   'version',
#   'reluctant',
#   'enter',
#   'card',
#   'info'],
#  ['@mention',
#   'scheduled',
#   'sfo',
#   '@number',
#   'dal',
#   'flight',
#   '@number',
#   'today',
#   'changed',
#   '@number',
#   'th',
#   'due',
#   'weather',
#   'looks',
#   'like',
#   'flight',
#   'still'],
#  ['@mention',
#   'getaway',
#   'deals',
#   'may',
#   '@number',
#   'one',
#   'way',
#   'lots',
#   'cool',
#   'cities',
#   '@url',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'getaway',
#   'deals',
#   'may',
#   '@number',
#   'one',
#   'way',
#   'lots',
#   'cool',
#   'cities',
#   '@url',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'getaway',
#   'deals',
#   'may',
#   '@number',
#   'one',
#   'way',
#   'lots',
#   'cool',
#   'cities',
#   '@url',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'getaway',
#   'deals',
#   'may',
#   '@number',
#   'one',
#   'way',
#   'lots',
#   'cool',
#   'cities',
#   '@url',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention', 'great', 'week', '@emoji', '@emoji'],
#  ['@mention',
#   'come',
#   'back',
#   '@hashtag',
#   'already',
#   'need',
#   'take',
#   'us',
#   'horrible',
#   'cold',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'concerned',
#   'fly',
#   'plane',
#   'needs',
#   'delayed',
#   'due',
#   'tech',
#   'stop'],
#  ['@mention',
#   'best',
#   'airline',
#   'flown',
#   'easy',
#   'change',
#   'reservation',
#   'helpful',
#   'representatives',
#   'amp',
#   'comfortable',
#   'flying',
#   'experience'],
#  ['@mention',
#   'another',
#   'rep',
#   'kicked',
#   'butt',
#   'naelah',
#   'represents',
#   'team',
#   'beautifully',
#   'thank'],
#  ['@mention',
#   'beautiful',
#   'front',
#   'end',
#   'design',
#   'right',
#   'cool',
#   'still',
#   'book',
#   'ticket',
#   'b',
#   'c',
#   'back',
#   'end',
#   'secure'],
#  ['@mention',
#   'love',
#   'team',
#   'running',
#   'gate',
#   'e',
#   '@number',
#   'las',
#   'tonight',
#   'waited',
#   'delayed',
#   'flight',
#   'kept',
#   'things',
#   'entertaining'],
#  ['@mention',
#   'use',
#   'another',
#   'browser',
#   '@number',
#   'amp',
#   'brand',
#   'reputation',
#   'built',
#   'tech',
#   'response',
#   'cross',
#   'browser',
#   'compatible',
#   'website'],
#  ['@mention',
#   'flight',
#   'flight',
#   'booking',
#   'problems',
#   'site',
#   'totally',
#   'folks',
#   'problem'],
#  ['@mention',
#   'like',
#   'customer',
#   'service',
#   '@number',
#   'min',
#   'delay',
#   'connecting',
#   'passengers',
#   'seems',
#   'long',
#   'va',
#   '@number'],
#  ['@mention',
#   'thanks',
#   'outstanding',
#   'nyc',
#   'jfk',
#   'crew',
#   'moved',
#   'mountains',
#   'get',
#   'home',
#   'san',
#   'francisco',
#   'tonight'],
#  ['@mention',
#   'absolute',
#   'best',
#   'team',
#   'customer',
#   'service',
#   'ever',
#   'every',
#   'time',
#   'fly',
#   'delighted',
#   'thank'],
#  ['@mention',
#   'provide',
#   'complimentary',
#   'upgrades',
#   'first',
#   'class',
#   'available',
#   'seats'],
#  ['@mention',
#   'need',
#   'change',
#   'flight',
#   'thats',
#   'scheduled',
#   '@number',
#   'hours',
#   '@number',
#   'min',
#   'wait',
#   'time',
#   'phone',
#   'im',
#   'calling',
#   'intern',
#   'help'],
#  ['@mention',
#   'completely',
#   'awesome',
#   'experience',
#   'last',
#   'month',
#   'bos',
#   'las',
#   'nonstop',
#   'thanks',
#   'awesome',
#   'flight',
#   'depart',
#   'time',
#   '@hashtag'],
#  ['@mention', 'watch', '@hashtag', 'jfk', 'gt', 'sfo', 'flight'],
#  ['@mention', 'flight', '@number', 'cancelled', 'flightled'],
#  ['@mention',
#   'failing',
#   'customers',
#   'check',
#   'process',
#   'link',
#   'tsa',
#   'pre',
#   'check'],
#  ['@mention',
#   '@mention',
#   'us',
#   'terrible',
#   'airline',
#   'gave',
#   'us',
#   'hotel',
#   'hotline',
#   'number',
#   'said',
#   'sorry'],
#  ['@mention',
#   'flight',
#   'number',
#   '@number',
#   'sfo',
#   'cabo',
#   'san',
#   'lucas',
#   'arrived',
#   'yet'],
#  ['@mention',
#   '@mention',
#   'assistance',
#   'yesterday',
#   'u',
#   'cancelled',
#   'flightled',
#   'flight',
#   'give',
#   'us',
#   'hotel',
#   'hotline',
#   'shame'],
#  ['@mention', 'another', 'delayed', 'flight', '@hashtag'],
#  ['@mention',
#   'need',
#   'register',
#   'service',
#   'dog',
#   'first',
#   'class',
#   'ticket',
#   'sfo',
#   'gt',
#   'dulles',
#   'phone',
#   'queue',
#   'hour',
#   'longer',
#   'pls',
#   'advise'],
#  ['@mention',
#   'rock',
#   'making',
#   'watch',
#   '@hashtag',
#   'flight',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention', '@mention', 'dropped', 'track', '@url'],
#  ['@mention', 'always', 'xoxo'],
#  ['@mention',
#   'book',
#   'seats',
#   'flights',
#   'buy',
#   'even',
#   'check',
#   'creates',
#   'much',
#   'anxiety',
#   '@hashtag'],
#  ['@mention',
#   'think',
#   'paying',
#   'extra',
#   '@number',
#   'bucks',
#   'rt',
#   'luggage',
#   'might',
#   'afford',
#   'hiring',
#   'extra',
#   'hand',
#   '@mention',
#   '@hashtag'],
#  ['@mention',
#   'best',
#   'customer',
#   'service',
#   'rep',
#   'world',
#   '@hashtag',
#   'takes',
#   'cake'],
#  ['@mention',
#   'find',
#   'us',
#   'flt',
#   'lax',
#   'sooner',
#   'midnight',
#   'monday',
#   'would',
#   'great',
#   'customer',
#   'service',
#   '@emoji'],
#  ['@mention',
#   'please',
#   'provide',
#   'status',
#   'flight',
#   '@number',
#   'cant',
#   'imagine',
#   'time',
#   'web',
#   'indicates',
#   'dude',
#   'weather',
#   'dallas'],
#  ['@mention',
#   'amazing',
#   'staff',
#   'amp',
#   'super',
#   'helpful',
#   'ran',
#   '@mention',
#   '@hashtag',
#   'spoiled',
#   'comfort'],
#  ['@mention',
#   'paid',
#   'premium',
#   'fly',
#   'across',
#   'country',
#   'cancelled',
#   'flight',
#   'flight',
#   'offer',
#   'check',
#   'fee',
#   'upgrade',
#   'love',
#   'sad',
#   'face',
#   '@emoji'],
#  ['@mention',
#   'question',
#   'possible',
#   'book',
#   'seat',
#   'infant',
#   '@number',
#   'giving',
#   'option',
#   'want',
#   'seat'],
#  ['always', 'together', 'welcome', 'rt', '@mention', '@mention', 'welcome'],
#  ['@mention',
#   '@hashtag',
#   'home',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   'back',
#   '@hashtag',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'understand',
#   'need',
#   'dm',
#   'give',
#   'answer',
#   'damaged',
#   'luggage',
#   'policy'],
#  ['@mention', 'mean', 'policy', 'destroyed', 'luggage'],
#  ['@mention',
#   'special',
#   'assistance',
#   'travel',
#   'alone',
#   'w',
#   '@number',
#   'kids',
#   '@number',
#   'infant',
#   'priority',
#   'boarding'],
#  ['@mention',
#   'thank',
#   'checking',
#   'tickets',
#   'purchased',
#   'customer',
#   'happy',
#   '@emoji'],
#  ['@mention', 'website', 'ever', 'coming', 'back', 'online'],
#  ['@mention',
#   'flight',
#   '@number',
#   'love',
#   'field',
#   'sfo',
#   'definitely',
#   'cancelled',
#   'flightled',
#   'monday',
#   'february',
#   '@number'],
#  ['@mention', 'flight', '@number', 'lga', 'dfw', 'time'],
#  ['@mention',
#   'drivers',
#   'license',
#   'expired',
#   'little',
#   'month',
#   'fly',
#   'friday',
#   'morning',
#   'using',
#   'expired',
#   'license'],
#  ['@mention',
#   'problems',
#   'flight',
#   'booking',
#   'problems',
#   'web',
#   'site',
#   'keeps',
#   'giving',
#   'error',
#   'contact',
#   'phone',
#   'phone',
#   '@number',
#   'minute',
#   'wait'],
#  ['@mention',
#   'reschedule',
#   'cancelled',
#   'flightled',
#   'flights',
#   'online',
#   'change',
#   'button',
#   'greyed'],
#  ['@mention',
#   'rang',
#   'wait',
#   '@number',
#   'minutes',
#   'book',
#   'ticket',
#   'vendor',
#   'fix',
#   'site'],
#  ['@mention',
#   'got',
#   'flight',
#   'told',
#   '@number',
#   '@number',
#   'today',
#   'checked',
#   'email',
#   '@number',
#   '@number',
#   'tomorrow',
#   'unacceptable'],
#  ['@mention',
#   'flight',
#   'lga',
#   'cancelled',
#   'flighted',
#   'stuck',
#   'dallas',
#   'called',
#   'reschedule',
#   'told',
#   'could',
#   'get',
#   'flight',
#   'today',
#   '@number',
#   '@number'],
#  ['@mention',
#   'pairings',
#   'include',
#   'red',
#   'wine',
#   'white',
#   'offered',
#   '@emoji',
#   '@hashtag'],
#  ['@mention', 'website'],
#  ['@mention',
#   'site',
#   'seems',
#   'little',
#   'wonked',
#   'right',
#   'may',
#   'want',
#   'look',
#   'tried',
#   'two',
#   'browsers',
#   'css',
#   '@url'],
#  ['@mention',
#   'disappointed',
#   'agent',
#   'designated',
#   'silver',
#   'status',
#   'check',
#   'line',
#   '@mention',
#   'closed',
#   'assist',
#   'pasengers'],
#  ['@mention',
#   'plans',
#   'include',
#   'austin',
#   'dallas',
#   'route',
#   'topnews',
#   'arab',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'normal',
#   'receive',
#   'reply',
#   'central',
#   'baggage',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'logan',
#   'airport',
#   'waiting',
#   'checkin',
#   '@number',
#   'flight',
#   'checkin',
#   'desk',
#   'open'],
#  ['@mention', 'jump', 'dallas', 'austin', 'market', '@mention', '@url'],
#  ['@mention',
#   'beats',
#   'eps',
#   'views',
#   'takes',
#   '@hashtag',
#   'va',
#   'luv',
#   'investor',
#   'business',
#   'daily',
#   '@url'],
#  ['@mention', 'lister', 'show', 'monday', '@number', '@number'],
#  ['@mention',
#   'begin',
#   'dallas',
#   'austin',
#   '@hashtag',
#   'april',
#   '@number',
#   '@number',
#   'ketr',
#   '@url'],
#  ['@mention',
#   'congrats',
#   'got',
#   'business',
#   'ewr',
#   'sfo',
#   'lax',
#   'fuck',
#   '@mention',
#   'fl',
#   '@number',
#   'sfo',
#   'ewr',
#   'clincher'],
#  ['@mention',
#   'applied',
#   '@number',
#   'weeks',
#   'ago',
#   'heard',
#   'back',
#   'flying',
#   'week',
#   '@hashtag'],
#  ['@mention', 'love', 'know', 'policy', 'damaged', 'luggage'],
#  ['@mention', 'thank', 'follow'],
#  ['@mention',
#   'many',
#   'apologies',
#   'r',
#   'worse',
#   'airlines',
#   'even',
#   'respond',
#   'cudtomers'],
#  ['@mention',
#   'shame',
#   'va',
#   'making',
#   'people',
#   'spend',
#   'money',
#   'stranded',
#   'cities',
#   'airlines',
#   'landing',
#   'jfk',
#   'reimburse'],
#  ['@mention', '@mention', 'dm'],
#  ['@mention',
#   'please',
#   'flights',
#   'sjc',
#   'choice',
#   'fly',
#   'southwest',
#   'vegas',
#   '@emoji'],
#  ['@mention',
#   'bad',
#   'say',
#   'takes',
#   '@number',
#   '@number',
#   'days',
#   'via',
#   'confirmation',
#   'email',
#   'inquired',
#   '@number',
#   'weeks',
#   'claim',
#   '@number',
#   '@number',
#   'weeks'],
#  ['@mention',
#   'flight',
#   'bos',
#   'gt',
#   'las',
#   'tomorrow',
#   'cancelled',
#   'flightled',
#   'notification',
#   'wait',
#   'times',
#   '@number',
#   'hour',
#   'rebook',
#   'another',
#   'airline'],
#  ['@emoji',
#   'rt',
#   '@mention',
#   'met',
#   'match',
#   'got',
#   'status',
#   'another',
#   'airline',
#   'upgrade',
#   'restr',
#   '@url',
#   '@url'],
#  ['@mention', 'way', 'fly', '@hashtag', '@hashtag'],
#  ['@mention', 'guys', 'flights', 'cmh'],
#  ['@mention',
#   'lot',
#   'apologies',
#   'thrown',
#   'customers',
#   'see',
#   'sad',
#   'thanks',
#   'nothing',
#   'worst',
#   'airline',
#   'ever'],
#  ['@mention',
#   'flight',
#   'stuff',
#   'wrong',
#   'nothing',
#   '@hashtag',
#   '@hashtag',
#   'ever'],
#  ['@mention',
#   'issue',
#   'finding',
#   'missing',
#   'item',
#   'plane',
#   'help',
#   'find',
#   'airport',
#   'plane',
#   'headed',
#   'next'],
#  ['@mention', 'match', '@hashtag', 'status', 'cool'],
#  ['@emoji',
#   'met',
#   'match',
#   'got',
#   'status',
#   'another',
#   'airline',
#   'upgrade',
#   '@url',
#   '@mention',
#   '@emoji'],
#  ['@mention',
#   'trying',
#   'book',
#   'flight',
#   'guys',
#   'website',
#   'let',
#   'lose',
#   'business'],
#  ['@mention', 'suck'],
#  ['@mention', 'thanks'],
#  ['@mention', 'dm', 'issue', 'persisting'],
#  ['@mention',
#   'never',
#   'rec',
#   'cancelled',
#   'flightlation',
#   'notice',
#   'left',
#   'w',
#   'options',
#   'fly',
#   'ps',
#   'driving',
#   'la',
#   'red',
#   'eye',
#   'mon',
#   'w',
#   'kids'],
#  ['@mention', 'trying', 'book', 'flight', 'amp', 'site', '@emoji'],
#  ['@mention',
#   'flights',
#   'flying',
#   'boston',
#   'tomorrow',
#   'need',
#   'home',
#   'cancelled',
#   'flightled',
#   'flight',
#   'anything'],
#  ['@mention',
#   'stink',
#   'flight',
#   'cancelled',
#   'flighted',
#   'psp',
#   'jfk',
#   'notification',
#   'ability',
#   'rebook',
#   '@hashtag',
#   '@hashtag',
#   'better'],
#  ['@mention',
#   'love',
#   'guy',
#   'song',
#   'dancing',
#   'high',
#   'school',
#   'dance',
#   'revue'],
#  ['@mention', 'website', 'trying', 'check'],
#  ['@mention',
#   'done',
#   'thank',
#   'quick',
#   'response',
#   'apparently',
#   'faster',
#   'sitting',
#   'hold',
#   '@emoji'],
#  ['@mention',
#   'nervous',
#   'flight',
#   'dc',
#   'lax',
#   'getting',
#   'cancelled',
#   'flightled',
#   'tomorrow',
#   'sent',
#   'dm',
#   'help'],
#  ['@mention',
#   'cool',
#   'picture',
#   'another',
#   'virginamerica',
#   'plane',
#   'wing',
#   'site',
#   '@url'],
#  ['@mention', 'keep', 'great', 'work', '@emoji'],
#  ['@mention',
#   'goodness',
#   'people',
#   '@mention',
#   'field',
#   'amazing',
#   'pressure',
#   '@emoji',
#   'texas',
#   '@hashtag',
#   'crisis',
#   'please',
#   'fly',
#   'ny'],
#  ['@mention',
#   'thanks',
#   'great',
#   'flight',
#   'la',
#   'boston',
#   'pilots',
#   'great',
#   'job',
#   'landing',
#   'snow',
#   'go',
#   'back',
#   'la',
#   '@hashtag'],
#  ['@mention', 'please', 'get', 'new', 'york', 'area', 'monday', 'afternoon'],
#  ['@mention', 'thanks', 'much', 'awesome', 'support', 'guys', 'rock'],
#  ['@mention',
#   'seats',
#   'row',
#   '@number',
#   'recline',
#   'mention',
#   'website',
#   '@hashtag'],
#  ['@mention',
#   'flight',
#   '@number',
#   'delayed',
#   '@number',
#   'hours',
#   'la',
#   'due',
#   'mechanical',
#   'problems',
#   'handle',
#   'like',
#   'pros',
#   'could',
#   'tossed',
#   'us',
#   'free',
#   'drink'],
#  ['@mention',
#   'cancelled',
#   'flight',
#   'flights',
#   'today',
#   'precipitation',
#   'scared',
#   '@emoji'],
#  ['@mention',
#   'twitter',
#   'team',
#   'guys',
#   'killed',
#   'rescheduling',
#   'asap',
#   'thank'],
#  ['@mention',
#   'guys',
#   'charged',
#   '@number',
#   'reschedule',
#   'flight',
#   'cancelled',
#   'flighted',
#   'refusing',
#   'refund',
#   'deal'],
#  ['@mention',
#   'cant',
#   'access',
#   'website',
#   'safari',
#   'iphone',
#   '@number',
#   'seems',
#   'work',
#   'mac',
#   'ipad',
#   'need',
#   'iphone',
#   'add',
#   'passbook'],
#  ['@mention',
#   'ipad',
#   'iphone',
#   'clicking',
#   'checkin',
#   'link',
#   'email',
#   'received',
#   '@number',
#   'hrs',
#   'flight'],
#  ['@mention',
#   'mobile',
#   'site',
#   'broken',
#   'shows',
#   'header',
#   'elevateuser',
#   'numofpointsavailable',
#   '@number',
#   'number',
#   'points',
#   'let',
#   'checkin'],
#  ['@mention',
#   'really',
#   'looking',
#   'forward',
#   'flight',
#   'let',
#   'know',
#   'rescheduled',
#   '@hashtag'],
#  ['@mention',
#   'cancelled',
#   'flight',
#   'flight',
#   'vx',
#   '@number',
#   'one',
#   'sec',
#   'delayed',
#   'airport',
#   'next',
#   'cancelled',
#   'flightled',
#   'gonna',
#   'email',
#   'call',
#   'reschedule'],
#  ['@mention', 'problem', 'link', 'email', 'check', 'thanks'],
#  ['@mention',
#   'change',
#   'another',
#   'airline',
#   'get',
#   'dc',
#   'today',
#   '@mention',
#   'able',
#   'land',
#   'dc',
#   'cost',
#   '@number',
#   'ugh'],
#  ['@mention',
#   'looking',
#   'forward',
#   'first',
#   'flight',
#   'today',
#   'cancelled',
#   'flightled',
#   'along',
#   'subsequent',
#   'one'],
#  ['@mention',
#   'putting',
#   'great',
#   'deals',
#   'pdx',
#   'las',
#   'las',
#   'pdx',
#   'show',
#   'love',
#   '@url'],
#  ['@mention',
#   'wish',
#   'afford',
#   'fly',
#   'next',
#   'friday',
#   'going',
#   'back',
#   'home',
#   'love',
#   'everything',
#   'airline'],
#  ['@mention',
#   'gonna',
#   'deal',
#   'dallas',
#   'dc',
#   'deal',
#   'dc',
#   'dallas',
#   '@hashtag'],
#  ['@mention', 'bug', 'report', 'guys'],
#  ['@mention', 'hold', 'times', 'call', 'center', 'bit', 'much'],
#  ['@mention', 'like', '@url'],
#  ['@mention', 'site', '@hashtag'],
#  ['@mention', 'best', 'flight', 'attendant', 'ever', '@url'],
#  ['awesome',
#   'rt',
#   '@mention',
#   'watch',
#   'nominated',
#   'films',
#   '@number',
#   '@number',
#   'feet',
#   '@hashtag',
#   '@hashtag',
#   '@url'],
#  ['@mention', 'thanks', 'much'],
#  ['@mention',
#   'trying',
#   'reset',
#   'password',
#   'email',
#   'never',
#   'arrives',
#   'help'],
#  ['@mention',
#   'airline',
#   'based',
#   'silicon',
#   'valley',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@mention',
#   '@url'],
#  ['@mention', 'nicely', 'done', '@emoji'],
#  ['@mention',
#   'im',
#   'looking',
#   'forward',
#   'watching',
#   'oscars',
#   'flight',
#   'home',
#   'tomorrow',
#   'might',
#   'even',
#   'get',
#   'something',
#   'bubbly',
#   'drink',
#   '@emoji'],
#  ['@mention',
#   'reason',
#   'delay',
#   'departure',
#   'vx',
#   '@number',
#   'jfk',
#   'afternoon'],
#  ['@mention',
#   'todays',
#   'flight',
#   'palm',
#   'springs',
#   'ca',
#   'jfk',
#   'ny',
#   'cancelled',
#   'flightled'],
#  ['@mention', 'hahaha', '@emoji', 'guys', 'amazing', 'love', 'guys', '@emoji'],
#  ['@mention', 'sounds', 'like', 'fun'],
#  ['@mention', 'updates', 'flight', '@number', 'jfk', 'gt', 'lax'],
#  ['@mention', 'spruce', 'moose'],
#  ['@mention',
#   'css',
#   'site',
#   '@number',
#   'right',
#   'please',
#   'fix',
#   'site',
#   'unusable'],
#  ['@mention',
#   'flight',
#   '@number',
#   'vegas',
#   'boston',
#   'today',
#   'checked',
#   'online',
#   'bag',
#   'count',
#   'register',
#   'fix',
#   'somehow'],
#  ['@mention', 'classiq', 'luv', 'virgin', 'america', 'greetingz'],
#  ['@mention',
#   'hi',
#   'trying',
#   'check',
#   'website',
#   'working',
#   'tried',
#   '@number',
#   'different',
#   'browsers',
#   'problem',
#   'continues'],
#  ['@mention',
#   'thanks',
#   'great',
#   'customer',
#   'service',
#   'today',
#   'amp',
#   'helping',
#   'get',
#   'travel',
#   'sorted'],
#  ['@mention', 'thanks', 'guys', 'sweet', 'route', 'rockies', '@hashtag'],
#  ['@mention',
#   'love',
#   '@number',
#   'music',
#   'blasting',
#   'gate',
#   '@hashtag',
#   'waiting',
#   'flight',
#   '@hashtag',
#   'could',
#   'get',
#   'iced',
#   'coffee'],
#  ['@mention',
#   'passenger',
#   '@number',
#   'flt',
#   '@number',
#   'assaulted',
#   'flown',
#   'trust',
#   'banned',
#   'crew',
#   'filed',
#   'report',
#   '@mention'],
#  ['@mention',
#   'current',
#   'bug',
#   'website',
#   'shows',
#   'select',
#   'departure',
#   'city',
#   'selecting',
#   'destination',
#   'city',
#   '@url'],
#  ['@mention',
#   'luggage',
#   'severely',
#   'dented',
#   'missing',
#   'wheel',
#   'coming',
#   'baggage',
#   'claim',
#   'san',
#   'luggage',
#   'agent',
#   'miranda',
#   'think',
#   'help'],
#  ['@mention',
#   'thank',
#   'easy',
#   'itinerary',
#   'shift',
#   'impending',
#   'weather',
#   'quick',
#   'painless',
#   'amp',
#   'free'],
#  ['@mention',
#   'love',
#   'see',
#   'girls',
#   'inspired',
#   'become',
#   'pilots',
#   'rt',
#   'free',
#   'woaw',
#   'event',
#   'march',
#   '@number',
#   '@number',
#   'abq',
#   '@url'],
#  ['@mention',
#   'thanks',
#   'good',
#   'times',
#   'back',
#   '@hashtag',
#   'entire',
#   'flight',
#   '@emoji',
#   '@hashtag'],
#  ['@mention',
#   'beats',
#   'expectations',
#   'shares',
#   'take',
#   'santa',
#   'cruz',
#   'sentinel',
#   '@url'],
#  ['@mention', 'plans', 'start', 'flying', 'direct', 'dal', 'las'],
#  ['@mention',
#   'big',
#   'love',
#   'gratitude',
#   'mpower',
#   'w',
#   '@url',
#   'werin',
#   '@hashtag',
#   'vipswagbags@',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'great',
#   'job',
#   'adding',
#   'little',
#   'luxuries',
#   'aesthetics',
#   'improve',
#   'air',
#   'travel',
#   'experience',
#   'thank',
#   'keep'],
#  ['@mention',
#   'requested',
#   'window',
#   'seat',
#   'confirmed',
#   'window',
#   'got',
#   'stuck',
#   'middle',
#   'seat',
#   'good',
#   'way',
#   'treat',
#   'silver',
#   'member',
#   '@emoji'],
#  ['@mention', 'grand', 'budapest', 'hotel', '@hashtag'],
#  ['@mention', 'missed', '@mention', 'next', 'trip', '@number'],
#  ['@mention',
#   '@hashtag',
#   'paid',
#   'direct',
#   'flight',
#   'purpose',
#   'stop',
#   'fuel',
#   'exhausted',
#   'frequent',
#   'flier',
#   'nothing',
#   'inconvenience'],
#  ['@mention', 'something', 'wrong', 'website', 'safari', 'iphone'],
#  ['@mention',
#   'thanks',
#   'gate',
#   'checking',
#   'baggage',
#   'full',
#   'flight',
#   'dfw',
#   'lax',
#   '@number',
#   'giving',
#   'early',
#   'boarding',
#   '@hashtag'],
#  ['@mention', 'already', 'checked', 'page', 'expired', '@emoji'],
#  ['@mention',
#   'boo',
#   'refunding',
#   'seat',
#   'upgrade',
#   'fee',
#   'want',
#   'buy',
#   'first',
#   'place'],
#  ['@mention',
#   'shares',
#   'rise',
#   'q',
#   '@number',
#   'financial',
#   'results',
#   'usa',
#   'today',
#   '@url'],
#  ['@mention',
#   'adds',
#   'pillows',
#   'instead',
#   'lie',
#   'flat',
#   'seats',
#   'first',
#   'class',
#   'arms',
#   'race',
#   '@url'],
#  ['@mention', 'see', '@emoji'],
#  ['@mention', 'way', 'take', 'advantage', '@hashtag', '@emoji'],
#  ['@mention', 'know', 'flying', 'virgin', 'fight', '@hashtag'],
#  ['@mention', 'inflight', 'team', 'makes', 'experience', '@hashtag'],
#  ['@mention',
#   'cutest',
#   'salt',
#   'pepper',
#   'shaker',
#   'ever',
#   'think',
#   'guys',
#   'get',
#   'better',
#   '@url'],
#  ['@mention',
#   'moved',
#   'seat',
#   'notice',
#   'better',
#   'seat',
#   'cabin',
#   'select',
#   'behind',
#   'row',
#   'selected',
#   '@emoji',
#   '@hashtag'],
#  ['@mention', 'shares', '@number', 'q', 'results', '@mention', '@url'],
#  ['@mention', 'fav', 'airline'],
#  ['@mention', 'hot', 'female', 'pilot', 'sweet', 'dca', 'sfo', '@emoji'],
#  ['@emoji',
#   '@emoji',
#   'guys',
#   'going',
#   'start',
#   'flying',
#   'paris',
#   '@mention',
#   '@mention',
#   'welcome'],
#  ['@mention',
#   'policy',
#   'flying',
#   'surgery',
#   'still',
#   'waiting',
#   'answer',
#   'tell',
#   'doctor'],
#  ['@mention',
#   'already',
#   'contacted',
#   'central',
#   'baggage',
#   'amp',
#   'sent',
#   'dm',
#   '@mention',
#   'charging',
#   'dress',
#   'lost',
#   'suitcase',
#   '@hashtag'],
#  ['@mention', 'thank'],
#  ['@mention',
#   'anything',
#   'going',
#   'website',
#   'getting',
#   'lot',
#   'errors',
#   'past',
#   '@number',
#   'minutes'],
#  ['@mention',
#   'think',
#   'left',
#   'something',
#   'plane',
#   'yesterday',
#   'call',
#   'ah'],
#  ['@mention', 'need', 'follow', 'back', 'order', 'dm'],
#  ['@mention', 'need', 'start', 'flying', '@mention', '@emoji'],
#  ['@mention', 'told', 'check', 'airline', 'regulation', 'first', 'contacted'],
#  ['@mention',
#   '@mention',
#   'checked',
#   'flight',
#   'sfo',
#   'lax',
#   'amp',
#   'told',
#   'atlantic',
#   'flying',
#   'club',
#   'gold',
#   'get',
#   'benefits'],
#  ['@mention',
#   'husband',
#   'ordered',
#   'three',
#   'drinks',
#   'via',
#   'screen',
#   'never',
#   'came',
#   'awesome'],
#  ['@mention',
#   'soooo',
#   'guys',
#   'going',
#   'leave',
#   'seatbelt',
#   'light',
#   'flight',
#   'barely',
#   'call',
#   'turbulence',
#   '@emoji'],
#  ['@mention', 'policy', 'flying', 'surgery'],
#  ['@mention',
#   'posts',
#   'second',
#   'consecutive',
#   'full',
#   'year',
#   'net',
#   'profit',
#   '@mention',
#   '@url'],
#  ['@mention',
#   'funny',
#   'story',
#   'website',
#   'broken',
#   'missing',
#   'javascript',
#   'stylesheets',
#   'checkin',
#   'process',
#   'dislike'],
#  ['@mention', 'would', 'love', 'virgin', 'like', '@mention'],
#  ['@mention', 'results', 'handily', 'exceed', 'forecasts', '@mention', '@url'],
#  ['@mention',
#   'applied',
#   'position',
#   '@mention',
#   'wondering',
#   'guys',
#   'received',
#   'application'],
#  ['@mention',
#   'achieves',
#   'second',
#   'year',
#   'profitability',
#   'despite',
#   'revenue',
#   'pressure',
#   '@mention',
#   '@url'],
#  ['@mention',
#   'gives',
#   'positive',
#   'outlook',
#   'sees',
#   'increased',
#   'competition',
#   '@mention',
#   '@url'],
#  ['@mention',
#   'trying',
#   'check',
#   '@number',
#   '@number',
#   'ct',
#   'flight',
#   'tmm',
#   'desktop',
#   'website',
#   'working',
#   'sort',
#   'caching',
#   'bug',
#   'sos'],
#  ['@mention',
#   'weather',
#   'delays',
#   'gt',
#   'next',
#   'weeks',
#   '@emoji',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention', '@mention', 'check', 'website', 'go', 'airport'],
#  ['@mention', 'guys', 'know', 'check', 'links', 'emails', 'broken', '@url'],
#  ['@mention',
#   'pilot',
#   'says',
#   'expect',
#   'choppy',
#   'landing',
#   'nyc',
#   'due',
#   'gusty',
#   'winds',
#   'w',
#   'temperature',
#   '@number',
#   'degrees',
#   'amp',
#   'w',
#   'windchill',
#   '@number'],
#  ['@mention',
#   'loved',
#   'wait',
#   'monday',
#   'return',
#   'flight',
#   'mostly',
#   'watch',
#   'inflight',
#   'safety',
#   'video',
#   '@hashtag'],
#  ['@mention',
#   'lost',
#   'luggage',
#   '@number',
#   'days',
#   'ago',
#   'flight',
#   'vx',
#   '@number',
#   'lax',
#   'iad',
#   'amp',
#   'calling',
#   'every',
#   'day',
#   'response',
#   'please',
#   'give',
#   'back',
#   'stuff'],
#  ['@mention',
#   'flight',
#   'booking',
#   'problems',
#   'section',
#   'website',
#   'seems',
#   'broken',
#   'chrome',
#   'might',
#   'wanna',
#   'look'],
#  ['@mention',
#   'hi',
#   'wanted',
#   'see',
#   'new',
#   'routes',
#   'planned',
#   'year',
#   'newark',
#   'love',
#   'flying',
#   'guys',
#   'hope'],
#  ['@mention', 'mean', 'probably', 'inappropriate', 'board'],
#  ['@mention', 'happy', 'spend', 'day', 'together', 'let'],
#  ['@mention', 'saving', 'sanity', 'right', '@url'],
#  ['@mention', 'missed', 'flight', 'standby', 'work'],
#  ['@mention', 'understanding', 'helped', 'thx', '@hashtag'],
#  ['@mention', 'brought', 'way', 'across', 'country', 'today', 'see', '@url'],
#  ['@mention', 'thank', 'absolutely', '@emoji'],
#  ['@mention', 'looks', 'like', 'broken', 'link', 'assets', '@url'],
#  ['@mention',
#   'ready',
#   'let',
#   'say',
#   'together',
#   'noooo',
#   'turbulence',
#   'today',
#   '@emoji'],
#  ['@mention',
#   'manage',
#   'itinerary',
#   'section',
#   'website',
#   'seems',
#   'broken',
#   '@url'],
#  ['@mention',
#   'check',
#   'site',
#   'looks',
#   'like',
#   'every',
#   'time',
#   'loads',
#   '@url'],
#  ['@mention',
#   'u',
#   'help',
#   '@emoji',
#   '@mention',
#   'needs',
#   'urgent',
#   'treatment',
#   '@emoji',
#   'old',
#   'battling',
#   'cancer',
#   'could',
#   'u',
#   'help',
#   'flights',
#   '@emoji',
#   '@hashtag'],
#  ['@mention',
#   'may',
#   'start',
#   'service',
#   'hawaii',
#   '@hashtag',
#   'year',
#   '@url',
#   '@hashtag'],
#  ['@mention',
#   'carriers',
#   'less',
#   'half',
#   'price',
#   'round',
#   'trip',
#   'fare',
#   'stunned',
#   '@url'],
#  ['@mention',
#   'wtf',
#   'happening',
#   'pdx',
#   'late',
#   'flight',
#   'march',
#   'one',
#   'way',
#   'sfo',
#   '@number'],
#  ['@mention', 'add', 'dtw', 'sold'],
#  ['@mention', 'free', 'drinks', 'flight', 'back', 'free', 'promo'],
#  ['@mention', '@mention', 'thanks'],
#  ['@mention', 'momma', 'made', '@emoji'],
#  ['@mention',
#   'please',
#   'contact',
#   'portfolio',
#   'left',
#   'flight',
#   'vx',
#   '@number',
#   'jfk',
#   'sfo',
#   'tonite',
#   'seat',
#   '@number',
#   'need',
#   'returned',
#   'call',
#   '@number',
#   '@number',
#   '@number'],
#  ['@mention',
#   'help',
#   'flight',
#   '@number',
#   'jkf',
#   'tonight',
#   'seat',
#   '@number',
#   'c',
#   'left',
#   'portfolio',
#   'need',
#   'back'],
#  ['@mention',
#   '@mention',
#   'seattle',
#   'bound',
#   'wifey',
#   'got',
#   'duffle',
#   'vday',
#   'keeper',
#   'holla',
#   '@url'],
#  ['@mention',
#   'luggage',
#   'gone',
#   'filed',
#   'paperwork',
#   'promised',
#   'call',
#   'email',
#   'still',
#   'resolution',
#   'response',
#   'central',
#   'luggage'],
#  ['@mention',
#   'debbie',
#   'baldwin',
#   'gave',
#   '@hashtag',
#   'performance',
#   'safety',
#   'demo',
#   'evening',
#   'vx',
#   '@number',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention', 'thanks'],
#  ['@mention',
#   'thanks',
#   'taking',
#   'care',
#   '@mention',
#   'flight',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'thanks',
#   'lovely',
#   'soft',
#   'views',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'requested',
#   'mileage',
#   'challenge',
#   'status',
#   'several',
#   'weeks',
#   'ago',
#   'online',
#   'heard',
#   'back',
#   'get',
#   'help'],
#  ['@mention',
#   'trying',
#   'book',
#   'tickets',
#   'nyc',
#   'facing',
#   'super',
#   'fun',
#   'broken',
#   'styling',
#   'worry',
#   'keep',
#   'trying',
#   '@emoji'],
#  ['@mention',
#   'many',
#   'thanks',
#   'follow',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   'looking',
#   'help',
#   '@emoji',
#   '@emoji',
#   '@emoji',
#   '@url'],
#  ['@mention', 'nice', 'lofty', 'view', '@mention', '@hashtag', '@url'],
#  ['@mention',
#   'applied',
#   'status',
#   'match',
#   'feb',
#   '@number',
#   'got',
#   'confirmation',
#   'email',
#   'day',
#   'still',
#   'news',
#   'though',
#   'guys',
#   'dropped',
#   'ball',
#   'late',
#   'flightly',
#   '@emoji'],
#  ['@mention', 'new', 'go', 'airline'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   '@mention',
#   'help',
#   '@hashtag',
#   'need',
#   'help',
#   '@hashtag',
#   '@emoji',
#   '@url'],
#  ['@mention',
#   'adore',
#   'looking',
#   'forward',
#   'flight',
#   'austin',
#   'two',
#   'weeks'],
#  ['@mention',
#   'glad',
#   'mentioned',
#   'took',
#   'first',
#   'virgin',
#   'flight',
#   'years',
#   'back',
#   'transformative',
#   'experience'],
#  ['@mention',
#   'flight',
#   'booking',
#   'problems',
#   'flight',
#   'uphold',
#   'status',
#   'match',
#   'taxes',
#   'ticket',
#   'count',
#   'earned',
#   'status',
#   'points',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention', 'trying', 'check', 'looks', 'like', 'site'],
#  ['@mention', 'spending', 'birthday', 'night', 'dal', 'dca', 'get', 'home'],
#  ['@mention',
#   'sent',
#   'couple',
#   'messages',
#   'email',
#   'provided',
#   'avail',
#   'try',
#   'next',
#   'year',
#   'cheers'],
#  ['@mention',
#   'first',
#   'time',
#   'flying',
#   'virgin',
#   'went',
#   '@hashtag',
#   'thanks',
#   'smooth',
#   'ride',
#   'easily',
#   'new',
#   'fav',
#   'airline'],
#  ['@mention', 'seriously', 'though', 'direct', 'flights', 'sfo', 'fll', 'may'],
#  ['@mention',
#   'fine',
#   'already',
#   'done',
#   'purchase',
#   'try',
#   'go',
#   'way',
#   'go',
#   'back',
#   '@number'],
#  ['@mention',
#   'really',
#   'experience',
#   'hoping',
#   '@number',
#   'ws',
#   'forced',
#   '@number',
#   'check',
#   'small',
#   'carry',
#   'w',
#   'nothing',
#   'empty',
#   'cabin',
#   'space',
#   'board'],
#  ['@mention', 'wjere', 'luggage', '@hashtag', 'slow', 'lax'],
#  ['@mention', 'jump', '@hashtag', '@hashtag', 'market', '@url'],
#  ['@mention',
#   'spoke',
#   'representative',
#   'offered',
#   'solution',
#   'loyal',
#   'customer',
#   'flies',
#   '@mention',
#   'well'],
#  ['@mention',
#   'deeply',
#   'disappointed',
#   'birthday',
#   'promo',
#   'applied',
#   'trip',
#   'booked',
#   'mere',
#   'days',
#   'received',
#   'email'],
#  ['@mention',
#   'happened',
#   'direct',
#   'flights',
#   'sfo',
#   'fll',
#   'looking',
#   'may',
#   'see',
#   'connecting',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'help',
#   'left',
#   'blazer',
#   'kooples',
#   'jacket',
#   'bag',
#   '@number',
#   'rd',
#   'row',
#   'second',
#   'seat',
#   'right',
#   'gate',
#   '@number',
#   '@number',
#   'lax',
#   'flight',
#   'sfo'],
#  ['@mention',
#   'partners',
#   '@mention',
#   'checkout',
#   'mobile',
#   'payment',
#   'method',
#   'help',
#   'boost',
#   'mobile',
#   'conversion',
#   'rates',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'promoting',
#   'product',
#   'problem',
#   'southwest',
#   'recommend',
#   'noneother',
#   'best',
#   '@url'],
#  ['@mention', 'love', 'guys', 'pls', 'get', 'direct', 'routes', 'las', 'aus'],
#  ['@mention', 'would', 'like', 'help', 'flights', 'please'],
#  ['bruh', '@emoji', '@mention', 'turn', '@hashtag'],
#  ['@mention',
#   'course',
#   'work',
#   '@mention',
#   'obsessed',
#   'entire',
#   'virgin',
#   'family'],
#  ['@mention', 'ok', 'first', 'time', 'flying', 'tonight', '@emoji'],
#  ['@mention',
#   'digging',
#   'swanky',
#   'pink',
#   'mood',
#   'lighting',
#   'flight',
#   'nyc',
#   'sfo',
#   'needs',
#   'cabaret',
#   'singer',
#   'think'],
#  ['@mention',
#   'done',
#   'need',
#   'receipt',
#   'asap',
#   'could',
#   'please',
#   'help',
#   '@hashtag'],
#  ['@mention',
#   '@number',
#   '@number',
#   'embossed',
#   'badges',
#   'patches',
#   'superior',
#   'ones',
#   'currently',
#   'using',
#   '@url'],
#  ['@mention', 'vx', '@number', 'jfk', 'la', 'dirty', 'plane', 'standards'],
#  ['@mention',
#   'flight',
#   'vx',
#   '@number',
#   'headed',
#   'la',
#   'jfk',
#   'dirtiest',
#   'va',
#   'plane',
#   'ever',
#   'sad',
#   'great',
#   'airline'],
#  ['@mention',
#   'got',
#   'squared',
#   'away',
#   'someone',
#   'picked',
#   'soon',
#   'tweeted',
#   'tweeted',
#   'sooner',
#   '@emoji'],
#  ['@mention',
#   'avis',
#   'rental',
#   'continue',
#   'button',
#   'work',
#   'website',
#   'book',
#   'car',
#   'tried',
#   '@number',
#   'times',
#   'phone',
#   'sucks'],
#  ['@mention', 'delayed', '@number', '@number'],
#  ['@mention',
#   'currently',
#   'minute',
#   '@number',
#   'hold',
#   'cust',
#   'service',
#   'need',
#   'anything',
#   'add',
#   'lap',
#   'child',
#   'reservation'],
#  ['@mention',
#   'adds',
#   'pillows',
#   'instead',
#   'lie',
#   'flat',
#   'seats',
#   'first',
#   'class',
#   'arms',
#   'race',
#   '@url',
#   '@mention'],
#  ['@emoji',
#   '@mention',
#   'course',
#   'fun',
#   'celebrating',
#   'thanks',
#   'happy',
#   'chinese',
#   'new',
#   'year'],
#  ['@mention',
#   'flight',
#   'booking',
#   'problems',
#   'last',
#   'second',
#   'flight',
#   'next',
#   'week',
#   'sfo',
#   'san',
#   'chance',
#   'want',
#   'gift',
#   'promo',
#   'code',
#   'since',
#   'love',
#   'guys'],
#  ['@mention',
#   'comenity',
#   'bank',
#   'joke',
#   'please',
#   'change',
#   'nothing',
#   'constant',
#   'problems',
#   'bank'],
#  ['@mention', 'dm', 'u', 'also', 'add'],
#  ['@mention',
#   'grandma',
#   'ella',
#   '@number',
#   'th',
#   'would',
#   'lt',
#   '@number',
#   'bday',
#   'greeting',
#   'flight',
#   'crew',
#   'stewardess',
#   'eastern',
#   'airlines'],
#  ['@mention',
#   'bought',
#   'tix',
#   'atx',
#   'dallas',
#   'route',
#   'thanks',
#   'adding',
#   'love',
#   'yr',
#   'airline',
#   'amp',
#   'yr',
#   'website',
#   'best',
#   'transactional',
#   'site',
#   'ever'],
#  ['@mention', 'anytime', 'sugafly'],
#  ['@mention',
#   'gave',
#   'credit',
#   'late',
#   'flight',
#   'flight',
#   'yesterday',
#   'great',
#   'service',
#   'wow',
#   'moment',
#   'unexpected',
#   'gesture'],
#  ['@mention', 'need', 'receipt', 'flight', 'change', 'send', 'one'],
#  ['@mention',
#   'submitted',
#   'status',
#   'match',
#   'request',
#   'back',
#   'still',
#   'heard',
#   'im',
#   'flying',
#   'monday',
#   'look',
#   'accelerate'],
#  ['@mention',
#   'safety',
#   'video',
#   '@url',
#   'loved',
#   'first',
#   'cross',
#   'country',
#   'flight',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention', 'look', 'fat', 'looks', 'yummy'],
#  ['@mention',
#   'ceo',
#   'says',
#   '@hashtag',
#   'amp',
#   '@hashtag',
#   'strayed',
#   'low',
#   'cost',
#   'model',
#   '@url'],
#  ['@mention', 'brilliant', 'brisk', 'boston', 'cue', 'vx', '@number', '@url'],
#  ['@mention',
#   'atlantic',
#   'ploughs',
#   'lone',
#   'furrow',
#   '@hashtag',
#   '@url',
#   '@mention'],
#  ['@mention',
#   'atlantic',
#   'ploughs',
#   'lone',
#   'furrow',
#   '@hashtag',
#   '@url',
#   '@mention'],
#  ['@mention',
#   'atlantic',
#   'ploughs',
#   'lone',
#   'furrow',
#   '@hashtag',
#   '@url',
#   '@mention'],
#  ['@mention',
#   'omg',
#   'omg',
#   '@emoji',
#   'nonstop',
#   'dallas',
#   'austin',
#   'virgin',
#   '@emoji'],
#  ['@mention', 'planes', 'really', 'pretty', 'thought', 'u', 'know', '@emoji'],
#  ['@mention', 'flying', 'hawaii'],
#  ['@mention',
#   'pulling',
#   'hair',
#   'trying',
#   'book',
#   'flight',
#   'u',
#   'site',
#   'work',
#   'iphone',
#   'ipad',
#   'computer',
#   '@hashtag'],
#  ['@mention', 'thank'],
#  ['@mention',
#   'get',
#   'help',
#   'support',
#   'ticket',
#   '@number',
#   'days',
#   'incident',
#   '@number',
#   '@number',
#   'thank'],
#  ['@mention', 'good', 'home', '@hashtag', '@hashtag', '@url'],
#  ['@mention',
#   'cannot',
#   'even',
#   'open',
#   'laptop',
#   'seat',
#   '@number',
#   'c',
#   'paid',
#   'premium',
#   'let'],
#  ['@mention',
#   'seat',
#   '@number',
#   'c',
#   'cannot',
#   'even',
#   'open',
#   'laptop',
#   'paid',
#   'extra',
#   'seat'],
#  ['@mention',
#   'guys',
#   'starting',
#   'flights',
#   'end',
#   'month',
#   'guess',
#   'im',
#   'still',
#   'road',
#   'tripping',
#   'feb',
#   '@number'],
#  ['@mention',
#   'thanks',
#   'needing',
#   'way',
#   'make',
#   'austin',
#   'trips',
#   'dca',
#   'come'],
#  ['@mention',
#   'announced',
#   'new',
#   'route',
#   'austin',
#   'w',
#   'fares',
#   '@number',
#   'way',
#   '@url'],
#  ['@mention',
#   'really',
#   'sprint',
#   'thought',
#   'guys',
#   'kewl',
#   '@number',
#   '@number'],
#  ['@mention', 'cool', 'never', 'ur', 'planes'],
#  ['@mention', '@number', 'dollar', 'lax', 'las', 'fares'],
#  ['@mention', 'great', 'well', 'deserved'],
#  ['@mention',
#   'fyi',
#   'info@mention',
#   'email',
#   'address',
#   'say',
#   'contact',
#   'password',
#   'reset',
#   'emails',
#   'exist',
#   'emails',
#   'bounce'],
#  ['@mention',
#   'status',
#   'match',
#   '@number',
#   'weeks',
#   'gone',
#   'news',
#   'flt',
#   'next',
#   'week',
#   'hope',
#   'flt',
#   'count',
#   'towards',
#   'requirement',
#   'cust',
#   'svc',
#   'help'],
#  ['@mention',
#   'website',
#   'sucks',
#   'donkey',
#   'dicks',
#   'thought',
#   'know',
#   'best'],
#  ['@mention', 'still', 'develop', 'app', 'favorite', 'airline'],
#  ['@mention', 'crap', 'channels', 'pay', 'watch', 'uk', 'tv'],
#  ['@mention', 'got', 'set', 'thanks'],
#  ['@mention', 'channel', 'year'],
#  ['@mention',
#   'thing',
#   'see',
#   'passbook',
#   'virgin',
#   'mobile',
#   'mexico',
#   'integrate'],
#  ['@mention', 'giants', 'virgin', 'america', 'match', 'made', 'heaven'],
#  ['@mention',
#   'thank',
#   'goodness',
#   'also',
#   'see',
#   'friday',
#   'nwk',
#   'gt',
#   'sf',
#   'boom'],
#  ['@mention',
#   'come',
#   'iphone',
#   'app',
#   'still',
#   'using',
#   'making',
#   'waste',
#   'paper'],
#  ['@mention',
#   'back',
#   'seat',
#   'entertainment',
#   'system',
#   'accept',
#   'credit',
#   'cards',
#   'apostrophe',
#   'surname',
#   '@hashtag'],
#  ['@mention',
#   'vx',
#   'use',
#   '@number',
#   'lga',
#   'slots',
#   'instead',
#   '@number',
#   'today',
#   'adding',
#   'aus',
#   'makes',
#   'less',
#   'likely',
#   '@emoji'],
#  ['@mention',
#   'helping',
#   'step',
#   '@mention',
#   'game',
#   '@hashtag',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'luv',
#   'ur',
#   'people',
#   'product',
#   '@number',
#   'thing',
#   'u',
#   'charge',
#   'herbal',
#   'tea',
# ...
#   'wonderful',
#   'bag',
#   'claim',
#   'people',
#   'finally',
#   'bag',
#   'catch',
#   'earlier',
#   'flight',
#   'original',
#   'flight',
#   'landed',
#   '@hashtag'],
#  ['@mention', 'dmed', 'thank'],
#  ['@mention', 'thanks', 'touch'],
#  ['@mention',
#   'thanks',
#   'karen',
#   'salisbury',
#   'iah',
#   'amazing',
#   'customer',
#   'service',
#   'found',
#   'daughter',
#   'bag',
#   'lost',
#   'ua',
#   '@number',
#   'made',
#   'day'],
#  ['@mention',
#   '@number',
#   'days',
#   'late',
#   'flightr',
#   'bag',
#   'left',
#   'iad',
#   'united',
#   'helping',
#   'everyone',
#   'tells',
#   'different',
#   'story'],
#  ['@mention',
#   '@mention',
#   'hi',
#   'direct',
#   'flights',
#   'houston',
#   'reno',
#   'begin',
#   'see',
#   'days',
#   'march'],
#  ['@mention', 'like', 'continental', 'chicken', 'feat', 'fairs'],
#  ['@mention',
#   'assist',
#   'current',
#   'flight',
#   'status',
#   'flt',
#   '@number',
#   'dfw',
#   'tomorrow',
#   '@number',
#   '@number'],
#  ['@mention', 'left', 'comment', 'customer', 'care', 'thanks', 'contacting'],
#  ['@mention',
#   'lose',
#   'gate',
#   'checked',
#   'bag',
#   'den',
#   'ord',
#   'direct',
#   'flight',
#   'ugh'],
#  ['@mention',
#   'caught',
#   'earlier',
#   'flight',
#   'ord',
#   'gate',
#   'checked',
#   'bag',
#   'lost',
#   'hare',
#   'original',
#   'flight',
#   'lands',
#   '@number',
#   'minutes',
#   '@hashtag'],
#  ['yes',
#   'thanks',
#   'much',
#   '@emoji',
#   '@emoji',
#   '@mention',
#   'see',
#   'spoke',
#   'reservations',
#   'team',
#   'reinstated',
#   'flight',
#   'thanks',
#   'ey'],
#  ['@mention',
#   'captain',
#   'behalf',
#   'front',
#   'office',
#   'welcome',
#   'board',
#   'never',
#   'heard',
#   'laughed',
#   'hard',
#   '@hashtag'],
#  ['@mention', 'please', 'follow', 'dm', 'missing', 'bag'],
#  ['@mention',
#   'clear',
#   'luggage',
#   'comment',
#   'referencing',
#   'photo',
#   'attached',
#   'flight',
#   '@number',
#   'jac',
#   '@url'],
#  ['@mention', 'great', 'fares'],
#  ['@mention',
#   'left',
#   'item',
#   'plane',
#   'calling',
#   'non',
#   'stop',
#   'one',
#   'answering',
#   'please',
#   'help'],
#  ['@mention',
#   'awesome',
#   'book',
#   'next',
#   'christmas',
#   'vacatinn',
#   'december',
#   'ways',
#   'want',
#   'devalue',
#   'mileage',
#   'plus'],
#  ['@mention',
#   'good',
#   'number',
#   'call',
#   'speak',
#   'someone',
#   'fix',
#   '@number',
#   'people',
#   'luggage',
#   'saturday'],
#  ['@mention',
#   'thank',
#   'u',
#   'secured',
#   'room',
#   'night',
#   'thx',
#   'helpful',
#   'customer',
#   'service',
#   'rep',
#   'n',
#   'dorns',
#   'thanked',
#   'u',
#   '@number',
#   '@hashtag'],
#  ['@mention', 'damn', 'bag'],
#  ['@mention',
#   'well',
#   'someone',
#   'tell',
#   'employees',
#   'denver',
#   'baggage',
#   'claim',
#   'still',
#   'bag'],
#  ['@mention',
#   'greetings',
#   'ua',
#   'club',
#   'member',
#   'idea',
#   'use',
#   'air',
#   'canada',
#   'lounge',
#   'yvr',
#   'flying',
#   'ua',
#   'tomorrow'],
#  ['@mention', 'mexico', 'international', 'us'],
#  ['@mention',
#   'diverted',
#   'missed',
#   'connecting',
#   'flight',
#   'told',
#   'bag',
#   'way',
#   'msy',
#   'people',
#   'cared'],
#  ['@mention',
#   'male',
#   'agnt',
#   'las',
#   'threatens',
#   'canadian',
#   'cust',
#   'cust',
#   'takes',
#   'pic',
#   'gate',
#   'agents',
#   'announce',
#   'help',
#   'rebook',
#   '@hashtag'],
#  ['@mention',
#   '@mention',
#   'want',
#   'go',
#   'home',
#   'tonight',
#   'cancelled',
#   'flight',
#   'last',
#   'leg',
#   'reserv',
#   'w',
#   'permission',
#   '@hashtag'],
#  ['@mention',
#   'stressed',
#   'rude',
#   'agents',
#   'overwhelmed',
#   'delyd',
#   'flight',
#   'las',
#   'den',
#   '@number',
#   'yelling',
#   'several',
#   'people',
#   'pretty',
#   '@hashtag'],
#  ['@mention',
#   'landed',
#   'boston',
#   '@number',
#   'last',
#   'night',
#   '@number',
#   'hours',
#   'traveling',
#   'rough',
#   'tho'],
#  ['@mention',
#   'fail',
#   'cancelled',
#   'flightled',
#   'flight',
#   'frm',
#   'gjt',
#   'used',
#   'reserv',
#   'home',
#   'iah',
#   'sea',
#   'reflight',
#   'booking',
#   'problems',
#   'w',
#   'permission',
#   '@hashtag'],
#  ['sent',
#   'thank',
#   'u',
#   'rt',
#   '@mention',
#   '@mention',
#   'please',
#   'dm',
#   'confirmation',
#   'number',
#   'reflight',
#   'booking',
#   'problems',
#   'needed',
#   'thank',
#   'ey'],
#  ['@mention',
#   'made',
#   'fly',
#   'list',
#   'airlines',
#   'wait',
#   'connector',
#   'late',
#   'flight',
#   'stuck',
#   'iah'],
#  ['@mention',
#   'whats',
#   'deal',
#   'u',
#   'provide',
#   'voucher',
#   'overnight',
#   'cozy',
#   'floor',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'also',
#   'mere',
#   'fact',
#   'go',
#   'online',
#   'issue',
#   'statement',
#   'vice',
#   'calling',
#   'talking',
#   'directly',
#   'one',
#   'good',
#   'example'],
#  ['@mention', 'thank', 'flew', 'newark', 'vail', 'eagle'],
#  ['@mention', 'weekend', 'dealing', 'company', 'would', 'say', 'otherwise'],
#  ['@mention',
#   '@url',
#   'flight',
#   'gone',
#   'got',
#   'plane',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'proper',
#   'response',
#   'sorry',
#   'wait',
#   'flight',
#   'look',
#   'issue',
#   '@mention',
#   'would',
#   'handle'],
#  ['@mention',
#   'customer',
#   'service',
#   'terrible',
#   'stood',
#   'inline',
#   '@number',
#   'hours',
#   'flights',
#   '@number',
#   'hours',
#   'late',
#   'flightr',
#   'still',
#   'bag',
#   '@hashtag'],
#  ['@mention',
#   'please',
#   'upload',
#   'march',
#   'demand',
#   'entertainment',
#   'listing',
#   'website',
#   '@emoji'],
#  ['@mention', 'inadequate', 'accident'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   '@',
#   'denver',
#   'international',
#   'airport',
#   '@url'],
#  ['@mention', 'thank', 'responding', 'quickly', 'helpful', 'tool', '@mention'],
#  ['@mention',
#   'boarding',
#   'time',
#   'shows',
#   '@number',
#   'min',
#   'gate',
#   'agent',
#   'started',
#   '@number',
#   'showed',
#   '@number',
#   '@number',
#   'check',
#   'bag',
#   '@url'],
#  ['@mention',
#   'agent',
#   'las',
#   'letting',
#   '@number',
#   'customers',
#   'know',
#   'help',
#   'rebook',
#   'delayed',
#   'flight',
#   'den',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'empathizes',
#   'w',
#   'disappointment',
#   '@number',
#   'stclass',
#   'flight',
#   'w',
#   'nonworking',
#   'entertainmnt',
#   'worth',
#   '@number',
#   '@hashtag',
#   '@url'],
#  ['@mention', 'work'],
#  ['@mention',
#   'seen',
#   'message',
#   'today',
#   'mcdonnell',
#   'douglas',
#   'dc',
#   '@number',
#   'model',
#   'hear',
#   'read',
#   'goodnight'],
#  ['@mention',
#   'searched',
#   'mileage',
#   'tickets',
#   'bom',
#   'find',
#   'single',
#   'one',
#   'saver',
#   'awards',
#   'see',
#   'play',
#   'earn',
#   'miles',
#   'use'],
#  ['@mention',
#   'flight',
#   'arrives',
#   '@number',
#   'minutes',
#   'early',
#   'wait',
#   'hour',
#   'bags'],
#  ['@mention',
#   'issue',
#   'fact',
#   'one',
#   'even',
#   'called',
#   'despite',
#   'promises',
#   'confirm',
#   'bag',
#   'location'],
#  ['@mention',
#   'girl',
#   'gotta',
#   'get',
#   'flight',
#   'name',
#   'change',
#   'bought',
#   'one',
#   'mean',
#   'ex',
#   'boyfriend',
#   'needs',
#   'girl',
#   'trip',
#   'stat'],
#  ['@mention',
#   'thank',
#   'signed',
#   'notifications',
#   'shall',
#   'watch',
#   'wait',
#   '@emoji'],
#  ['@mention',
#   'still',
#   'waiting',
#   'hear',
#   'back',
#   'wallet',
#   'stolen',
#   'one',
#   'planes',
#   'would',
#   'appreciate',
#   'resolution'],
#  ['@mention',
#   'would',
#   'love',
#   'someone',
#   'could',
#   'get',
#   'back',
#   'austin',
#   'tonight',
#   'wish',
#   'wait',
#   'til',
#   'tomorrow',
#   'morning'],
#  ['@mention',
#   '@mention',
#   'lost',
#   'baggage',
#   'heard',
#   'different',
#   'things',
#   'different',
#   'employees',
#   '@mention',
#   '@mention',
#   'said',
#   'nothing'],
#  ['@mention',
#   'cs',
#   'thinks',
#   'miles',
#   'repair',
#   'damage',
#   'done',
#   'interesting',
#   'travel',
#   '@mention',
#   'exp',
#   'worst',
#   'flight',
#   'ever'],
#  ['@mention',
#   '@number',
#   'flight',
#   'dfw',
#   'tuesday',
#   'far',
#   'advance',
#   'give',
#   'notice',
#   'cancelled',
#   'flightled'],
#  ['@mention',
#   'signed',
#   'notifications',
#   'first',
#   'trip',
#   'updated',
#   'sure',
#   'happened'],
#  ['@mention',
#   'thank',
#   'took',
#   'care',
#   'everything',
#   'made',
#   'right',
#   'experience',
#   'used',
#   'opened',
#   'app',
#   'find',
#   'flight',
#   'changed'],
#  ['@mention',
#   'line',
#   'responses',
#   'waiting',
#   'tomorrow',
#   'morning',
#   'flights',
#   'overbooked'],
#  ['@mention',
#   'took',
#   'exact',
#   'aircraft',
#   'lax',
#   '@number',
#   'days',
#   'ago',
#   'fit',
#   'problem',
#   'agent',
#   'today',
#   'told',
#   'nonsense',
#   'policy',
#   'change'],
#  ['@mention',
#   'helpful',
#   'agents',
#   'club',
#   'helped',
#   'baggage',
#   'fees',
#   'night',
#   'life',
#   'stop',
#   'business',
#   '@mention'],
#  ['@mention', 'never', 'heard', '@url'],
#  ['@mention',
#   'charge',
#   'ticket',
#   'change',
#   'fees',
#   'incur',
#   'mysterious',
#   'costs',
#   'incur',
#   '@mention'],
#  ['@mention',
#   'exhausted',
#   'amp',
#   'frustrated',
#   'link',
#   'fb',
#   'post',
#   'abt',
#   'travel',
#   'issue',
#   '@url'],
#  ['@mention',
#   'denied',
#   'getting',
#   'plane',
#   'w',
#   'getting',
#   'chance',
#   'prove',
#   'fits',
#   'rookie',
#   'read',
#   'bio'],
#  ['@mention',
#   'exactly',
#   'point',
#   'fits',
#   'premier',
#   'access',
#   'boarding',
#   'group',
#   '@number',
#   'return',
#   'ticket',
#   '@number',
#   'yrs'],
#  ['@mention',
#   'never',
#   'experienced',
#   'worst',
#   'customer',
#   'service',
#   'placing',
#   'blame',
#   'codeshare',
#   'partners',
#   'assuming',
#   'responsibility',
#   'unacceptable'],
#  ['@mention',
#   'currently',
#   'board',
#   'check',
#   'terrible',
#   'staff',
#   'rude',
#   'expensive',
#   'luggage',
#   'thrown',
#   'around',
#   'etc'],
#  ['@mention',
#   'fucked',
#   'voided',
#   'ticket',
#   'kept',
#   'money',
#   'even',
#   'apology',
#   'never',
#   'fly',
#   'airline',
#   '@hashtag'],
#  ['@mention',
#   'worst',
#   'customer',
#   'svcs',
#   'kevin',
#   'rep',
#   'call',
#   'center',
#   'must',
#   'investigated',
#   'baggage',
#   'lost',
#   'help',
#   'argument'],
#  ['@mention',
#   'sell',
#   'tickets',
#   '@mention',
#   '@url',
#   'terrible',
#   'service',
#   'ua',
#   'staff',
#   'cannot',
#   'reach',
#   'silver'],
#  ['@mention',
#   'got',
#   'demoted',
#   'gold',
#   'cuz',
#   'hubby',
#   'got',
#   '@number',
#   'pqd',
#   'tho',
#   'enuf',
#   'spent',
#   '@number',
#   'golds',
#   '@hashtag'],
#  ['@mention', 'thank'],
#  ['@mention',
#   'direct',
#   'flights',
#   'belfast',
#   'intl',
#   'newark',
#   'resume',
#   'winter',
#   'break',
#   'thanks'],
#  ['@mention', 'favorite', 'way', 'travel', 'thank', '@url'],
#  ['@mention', 'yes', 'awful', 'weather', 'appears', 'get', 'home'],
#  ['@mention',
#   'yes',
#   'lots',
#   'terrible',
#   'customer',
#   'service',
#   'newark',
#   'despite',
#   'raising',
#   'complaint',
#   'ignored',
#   'hence',
#   'tweet'],
#  ['@mention', 'lovely', 'new', 'plane', 'lga', 'ord', 'power', 'outlets'],
#  ['@mention',
#   'tweet',
#   'id',
#   'number',
#   'reveal',
#   'home',
#   'address',
#   'anyone',
#   'web'],
#  ['@mention',
#   'filed',
#   'delayed',
#   'bag',
#   'report',
#   'saturday',
#   'flight',
#   'cancelled',
#   'flightled',
#   'never',
#   'went',
#   'anywhere'],
#  ['@mention',
#   'person',
#   'currently',
#   'bettween',
#   'gates',
#   '@number',
#   '@number',
#   'lax'],
#  ['@mention',
#   'need',
#   'lands',
#   'ewr',
#   'baggage',
#   'claim',
#   'file',
#   'sent',
#   'employee',
#   'droppeditoffyet'],
#  ['@mention',
#   'rarely',
#   'ceases',
#   'amaze',
#   'worse',
#   'hope',
#   'last',
#   'time',
#   'fly'],
#  ['@mention', 'thank', 'quick', 'response', 'cannot', 'dm', 'follow', 'well'],
#  ['@mention',
#   'icloud',
#   'yet',
#   'please',
#   'help',
#   '@number',
#   '@number',
#   '@number'],
#  ['@mention',
#   'need',
#   'phone',
#   'number',
#   'baggage',
#   'claim',
#   'lax',
#   'mom',
#   'left',
#   'phone',
#   'someone',
#   'called',
#   'saying',
#   'would',
#   'put'],
#  ['@mention', 'response', 'back'],
#  ['@mention', 'atrocious', 'customer', 'service'],
#  ['@mention',
#   'honor',
#   'absurdly',
#   'low',
#   'mistake',
#   'fares',
#   '@url',
#   'vì',
#   '@mention'],
#  ['@mention',
#   '@hashtag',
#   'delayed',
#   'departure',
#   'check',
#   'bags',
#   'gate',
#   'claiming',
#   'space',
#   'filled',
#   'walk',
#   'open',
#   'spaces',
#   'delay',
#   '@hashtag'],
#  ['@mention',
#   'cancelled',
#   'flighted',
#   'flights',
#   'reason',
#   'amp',
#   'phone',
#   'hour',
#   'vacation'],
#  ['@mention',
#   '@mention',
#   'response',
#   'shaking',
#   'head',
#   'back',
#   'forth',
#   'tsk',
#   'better',
#   'customer',
#   'service',
#   'apology'],
#  ['@mention',
#   'thanks',
#   '@number',
#   'k',
#   'miles',
#   'rtb',
#   'europe',
#   'multiple',
#   'destination',
#   'could',
#   'stop',
#   'us',
#   'way',
#   'way',
#   'back',
#   'mileage',
#   'diff'],
#  ['@mention', 'course', 'bag', '@emoji', '@hashtag'],
#  ['@mention', 'worst', 'avoid', 'like', 'plague'],
#  ['@mention', 'worst', 'airline', 'world'],
#  ['@mention',
#   'someone',
#   'needs',
#   'dm',
#   'resolve',
#   'correctly',
#   'extremely',
#   'disappointed',
#   'service',
#   'received',
#   'terrible',
#   'management'],
#  ['@mention',
#   'premier',
#   'gold',
#   'desk',
#   'changes',
#   'flight',
#   'waives',
#   'fees',
#   'gives',
#   'wrong',
#   'flight',
#   'jana',
#   'acosta',
#   'salt',
#   'lake',
#   'refuses',
#   'service',
#   'angry'],
#  ['@mention',
#   'give',
#   'one',
#   'thing',
#   'consistent',
#   'unfortunately',
#   'consistent',
#   'job',
#   'well',
#   '@hashtag'],
#  ['@mention', 'right', 'angry'],
#  ['@mention',
#   'first',
#   'time',
#   'flying',
#   'united',
#   'also',
#   'last',
#   'time',
#   '@hashtag',
#   'back',
#   '@mention',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'used',
#   'committed',
#   '@hashtag',
#   'flyer',
#   'merger',
#   'remember',
#   'switched',
#   '@mention',
#   '@hashtag'],
#  ['@mention',
#   'least',
#   'could',
#   'offer',
#   'ticket',
#   'coach',
#   'instead',
#   'cancelled',
#   'flighting',
#   'reservation',
#   'glitch',
#   '@hashtag'],
#  ['@mention',
#   'saying',
#   'made',
#   'flight',
#   'poor',
#   'non',
#   'communication',
#   'unaccounted',
#   'lost',
#   'time',
#   'amp',
#   'lots',
#   'frustrated',
#   'flyers',
#   'standing',
#   'around'],
#  ['@mention', 'think', 'dm', 'would', 'better'],
#  ['@mention',
#   'gate',
#   'announcement',
#   'states',
#   'delay',
#   'due',
#   'maintenance',
#   'yet',
#   'app',
#   'says',
#   'late',
#   'flight',
#   'arriving',
#   'aircraft',
#   'tell',
#   'truth',
#   '@mention'],
#  ['@mention',
#   'easily',
#   'worst',
#   'company',
#   'ever',
#   'experienced',
#   'lost',
#   'someone',
#   'personal',
#   'possessions',
#   'amp',
#   'care',
#   'less'],
#  ['@mention',
#   'app',
#   'show',
#   'arriving',
#   'aircraft',
#   'early',
#   'departing',
#   'flight',
#   'delayed',
#   'due',
#   'late',
#   'flight',
#   'arriving',
#   'aircraft',
#   '@mention'],
#  ['@mention',
#   'already',
#   'airport',
#   '@number',
#   'hrs',
#   'late',
#   'flightr',
#   'still',
#   'guys',
#   'really',
#   'killing',
#   'today',
#   'trying',
#   'stay',
#   'positive'],
#  ['@mention',
#   'united',
#   'service',
#   'levels',
#   'reaches',
#   'etihad',
#   'lets',
#   'realistically',
#   'lufthansa',
#   'ill',
#   'consider'],
#  ['@mention',
#   'really',
#   'someone',
#   'called',
#   'sick',
#   'someone',
#   'forgot',
#   'call',
#   'replacement',
#   'hour',
#   'late',
#   'flight',
#   'take',
#   '@hashtag'],
#  ['@mention',
#   'asked',
#   'flight',
#   'attendant',
#   'typical',
#   'compensation',
#   'would',
#   'amp',
#   'says',
#   'might',
#   'get',
#   'free',
#   'tv',
#   '@hashtag'],
#  ['@mention', 'done'],
#  ['@mention',
#   'thank',
#   'jh',
#   'appreciate',
#   'prompt',
#   'responses',
#   'passengers'],
#  ['@mention',
#   'disappointment',
#   'today',
#   'simply',
#   'put',
#   'rather',
#   'unpleased',
#   'things',
#   'currently',
#   'flight',
#   'delayed',
#   'cant',
#   'wait',
#   'get',
#   'home'],
#  ['@mention',
#   'round',
#   'trip',
#   'non',
#   'english',
#   'speaking',
#   'friend',
#   'stranded',
#   'twice',
#   '@number',
#   'hours',
#   'time',
#   'staff',
#   'members',
#   'rude'],
#  ['@mention',
#   'found',
#   'group',
#   'people',
#   'actually',
#   'hates',
#   'people',
#   'isis',
#   'thats',
#   'right',
#   'united',
#   'airlines'],
#  ['@mention',
#   'nope',
#   'walked',
#   'amp',
#   'orf',
#   'terminal',
#   'amp',
#   'united',
#   'agent',
#   'found',
#   'showed',
#   '@',
#   'last',
#   'minute',
#   'board',
#   'us',
#   'many',
#   'panicked',
#   'people'],
#  ['@mention', 'thank'],
#  ['@mention',
#   'time',
#   'finally',
#   'get',
#   'dallas',
#   'could',
#   'driven',
#   'less',
#   'frustration',
#   'cheaper'],
#  ['@mention',
#   'trying',
#   'get',
#   'final',
#   'destination',
#   'need',
#   'compensation',
#   '@number',
#   'hrs',
#   'personal',
#   'time',
#   'wasted'],
#  ['@mention',
#   'guy',
#   'really',
#   'customer',
#   'service',
#   'clue',
#   'could',
#   'spent',
#   'effort',
#   'clearing',
#   'bins',
#   'rollerboards',
#   'instead',
#   'art',
#   'projects',
#   'mine'],
#  ['@mention', 'priority', 'iove'],
#  ['@mention', 'pleased', 'premier', 'platinum'],
#  ...]

# %%
new_df["no_sw"] = np.array(no_sw)

# %%
new_df.head()
# Out:
#                                                 text airline_sentiment  \
# 0                @VirginAmerica What @dhepburn said.           neutral
# 1  @VirginAmerica plus you've added commercials t...          positive
# 2  @VirginAmerica I didn't today... Must mean I n...           neutral
# 3  @VirginAmerica it's really aggressive to blast...          negative
# 4  @VirginAmerica and it's a really big bad thing...          negative
#
#   negativereason         airline  \
# 0            NaN  Virgin America
# 1            NaN  Virgin America
# 2            NaN  Virgin America
# 3     Bad Flight  Virgin America
# 4     Can't Tell  Virgin America
#
#                                         cleared_text  \
# 0                       @mention what @mention said
# 1  @mention plus you ve added commercials to the ...
# 2  @mention i didn t today must mean i need to ta...
# 3  @mention it s really aggressive to blast obnox...
# 4  @mention and it s a really big bad thing about it
#
#                                                no_sw
# 0                         [@mention, @mention, said]
# 1  [@mention, plus, added, commercials, experienc...
# 2  [@mention, today, must, mean, need, take, anot...
# 3  [@mention, really, aggressive, blast, obnoxiou...
# 4                [@mention, really, big, bad, thing]

# %% [markdown]
# ## 4 - Remove short words
#  with len == 1

# %%
no_sw_ll = []
for i in new_df["no_sw"]:
    tmp = []
    for word in i:
        if len(word) > 1:
            tmp.append(word)
    no_sw_ll.append(tmp)

# %%
no_sw_ll
# Out:
# [['@mention', '@mention', 'said'],
#  ['@mention', 'plus', 'added', 'commercials', 'experience', 'tacky'],
#  ['@mention', 'today', 'must', 'mean', 'need', 'take', 'another', 'trip'],
#  ['@mention',
#   'really',
#   'aggressive',
#   'blast',
#   'obnoxious',
#   'entertainment',
#   'guests',
#   'faces',
#   'amp',
#   'little',
#   'recourse'],
#  ['@mention', 'really', 'big', 'bad', 'thing'],
#  ['@mention',
#   'seriously',
#   'would',
#   'pay',
#   '@number',
#   'flight',
#   'seats',
#   'playing',
#   'really',
#   'bad',
#   'thing',
#   'flying',
#   'va'],
#  ['@mention',
#   'yes',
#   'nearly',
#   'every',
#   'time',
#   'fly',
#   'vx',
#   '@emoji',
#   'worm',
#   'go',
#   'away',
#   '@emoji'],
#  ['@mention',
#   'really',
#   'missed',
#   'prime',
#   'opportunity',
#   'men',
#   'without',
#   'hats',
#   'parody',
#   '@url'],
#  ['@mention', 'well', 'tbut', '@emoji'],
#  ['@mention', 'amazing', 'arrived', 'hour', 'early', 'good'],
#  ['@mention',
#   'know',
#   'suicide',
#   'second',
#   'leading',
#   'cause',
#   'death',
#   'among',
#   'teens',
#   '@number',
#   '@number'],
#  ['@mention',
#   'lt',
#   '@number',
#   'pretty',
#   'graphics',
#   'much',
#   'better',
#   'minimal',
#   'iconography',
#   '@emoji'],
#  ['@mention',
#   'great',
#   'deal',
#   'already',
#   'thinking',
#   '@number',
#   'nd',
#   'trip',
#   '@mention',
#   'amp',
#   'even',
#   'gone',
#   '@number',
#   'st',
#   'trip',
#   'yet',
#   '@emoji'],
#  ['@mention',
#   '@mention',
#   'flying',
#   '@hashtag',
#   '@hashtag',
#   'skies',
#   'take',
#   '@hashtag',
#   'away',
#   'travel',
#   '@url'],
#  ['@mention', 'thanks'],
#  ['@mention', 'sfo', 'pdx', 'schedule', 'still', 'mia'],
#  ['@mention',
#   'excited',
#   'first',
#   'cross',
#   'country',
#   'flight',
#   'lax',
#   'mco',
#   'heard',
#   'nothing',
#   'great',
#   'things',
#   'virgin',
#   'america',
#   '@hashtag'],
#  ['@mention',
#   'flew',
#   'nyc',
#   'sfo',
#   'last',
#   'week',
#   'fully',
#   'sit',
#   'seat',
#   'due',
#   'two',
#   'large',
#   'gentleman',
#   'either',
#   'side',
#   'help'],
#  ['@emoji', 'flying', '@mention', '@emoji'],
#  ['@mention',
#   'know',
#   'would',
#   'amazingly',
#   'awesome',
#   'bos',
#   'fll',
#   'please',
#   'want',
#   'fly'],
#  ['@mention',
#   'first',
#   'fares',
#   'may',
#   'three',
#   'times',
#   'carriers',
#   'seats',
#   'available',
#   'select'],
#  ['@mention', 'love', 'graphic', '@url'],
#  ['@mention', 'love', 'hipster', 'innovation', 'feel', 'good', 'brand'],
#  ['@mention',
#   'making',
#   'bos',
#   'gt',
#   'las',
#   'non',
#   'stop',
#   'permanently',
#   'anytime',
#   'soon'],
#  ['@mention',
#   'guys',
#   'messed',
#   'seating',
#   'reserved',
#   'seating',
#   'friends',
#   'guys',
#   'gave',
#   'seat',
#   'away',
#   '@emoji',
#   'want',
#   'free',
#   'internet'],
#  ['@mention',
#   'status',
#   'match',
#   'program',
#   'applied',
#   'three',
#   'weeks',
#   'called',
#   'emailed',
#   'response'],
#  ['@mention',
#   'happened',
#   '@number',
#   'ur',
#   'vegan',
#   'food',
#   'options',
#   'least',
#   'say',
#   'ur',
#   'site',
#   'know',
#   'able',
#   '@number',
#   'eat',
#   'anything',
#   'next',
#   '@number',
#   'hrs',
#   '@hashtag'],
#  ['@mention', 'miss', 'worry', 'together', 'soon'],
#  ['@mention',
#   'amazing',
#   'get',
#   'cold',
#   'air',
#   'vents',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'lax',
#   'ewr',
#   'middle',
#   'seat',
#   'red',
#   'eye',
#   'noob',
#   'maneuver',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'hi',
#   'bked',
#   'cool',
#   'birthday',
#   'trip',
#   'add',
#   'elevate',
#   'cause',
#   'entered',
#   'middle',
#   'name',
#   'flight',
#   'booking',
#   'problems',
#   '@emoji'],
#  ['@mention',
#   'hours',
#   'operation',
#   'club',
#   'sfo',
#   'posted',
#   'online',
#   'current'],
#  ['@mention',
#   'help',
#   'left',
#   'expensive',
#   'headphones',
#   'flight',
#   '@number',
#   'iad',
#   'lax',
#   'today',
#   'seat',
#   '@number',
#   'one',
#   'answering',
#   'amp',
#   'number',
#   'lax'],
#  ['@mention',
#   'awaiting',
#   'return',
#   'phone',
#   'call',
#   'would',
#   'prefer',
#   'use',
#   'online',
#   'self',
#   'service',
#   'option',
#   '@emoji'],
#  ['@mention',
#   'great',
#   'news',
#   'america',
#   'could',
#   'start',
#   'flights',
#   'hawaii',
#   'end',
#   'year',
#   '@url',
#   'via',
#   '@mention'],
#  ['nice',
#   'rt',
#   '@mention',
#   'vibe',
#   'moodlight',
#   'takeoff',
#   'touchdown',
#   '@hashtag',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'moodlighting',
#   'way',
#   'fly',
#   'best',
#   'experience',
#   'ever',
#   'cool',
#   'calming',
#   '@emoji',
#   '@emoji',
#   '@hashtag'],
#  ['@mention',
#   '@mention',
#   'done',
#   'done',
#   'best',
#   'airline',
#   'around',
#   'hands'],
#  ['@mention', 'book', 'flight', 'hawaii'],
#  ['@mention', 'chat', 'support', 'working', 'site', '@url'],
#  ['@mention',
#   'view',
#   'downtown',
#   'los',
#   'angeles',
#   'hollywood',
#   'sign',
#   'beyond',
#   'rain',
#   'mountains',
#   '@url'],
#  ['@mention',
#   'hey',
#   'first',
#   'time',
#   'flyer',
#   'next',
#   'week',
#   'excited',
#   'hard',
#   'time',
#   'getting',
#   'flights',
#   'added',
#   'elevate',
#   'account',
#   'help'],
#  ['@mention',
#   'plz',
#   'help',
#   'win',
#   'bid',
#   'upgrade',
#   'flight',
#   '@number',
#   '@number',
#   'lax',
#   'gt',
#   'sea',
#   '@emoji',
#   '@emoji'],
#  ['@mention',
#   'unused',
#   'ticket',
#   'moved',
#   'new',
#   'city',
#   'fly',
#   'fly',
#   'expires',
#   '@hashtag'],
#  ['@mention',
#   'flights',
#   'leaving',
#   'dallas',
#   'seattle',
#   'time',
#   'feb',
#   '@number'],
#  ['@mention', '@hashtag', 'good', 'reason', 'rock'],
#  ['@mention', 'dream', '@url', '@url'],
#  ['@mention', 'wow', 'blew', 'mind'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   'last',
#   'night',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@mention',
#   'think',
#   '@mention',
#   'agree'],
#  ['@mention', '@mention', '@mention', 'entertaining'],
#  ['@mention',
#   'flight',
#   '@number',
#   'way',
#   'supposed',
#   'take',
#   '@number',
#   'minutes',
#   'ago',
#   'website',
#   'still',
#   'shows',
#   'time',
#   'flight',
#   'thanks'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   'julie',
#   'andrews',
#   'way',
#   'though',
#   '@mention',
#   'impressive',
#   '@mention'],
#  ['@mention', 'wish', 'flew', 'atlanta', 'soon'],
#  ['@mention', '@mention', '@mention', 'julie', 'andrews', 'hands'],
#  ['@mention',
#   'flights',
#   'leaving',
#   'dallas',
#   'la',
#   'february',
#   '@number',
#   'th'],
#  ['@mention',
#   'hi',
#   'excited',
#   '@number',
#   'lga',
#   'gt',
#   '@emoji',
#   'deal',
#   'trying',
#   '@number',
#   'book',
#   'since',
#   'last',
#   'week',
#   'amp',
#   'page',
#   'never',
#   'loads',
#   'thx'],
#  ['@mention', 'know', 'need', 'spotify', 'stat', '@hashtag'],
#  ['@mention', '@mention', '@mention', 'lady', 'gaga', 'amazing', '@emoji'],
#  ['@mention', '@mention', '@mention', 'carrie'],
#  ['@mention',
#   'new',
#   'marketing',
#   'song',
#   '@url',
#   'let',
#   'us',
#   'know',
#   'think'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   'julie',
#   'andrews',
#   'first',
#   'lady',
#   'gaga',
#   'wow',
#   'last',
#   'night',
#   'carrie',
#   'meh'],
#  ['@mention',
#   'called',
#   '@number',
#   '@number',
#   'weeks',
#   'ago',
#   'adding',
#   '@number',
#   'flights',
#   '@number',
#   'elevate',
#   'still',
#   'shown',
#   'help'],
#  ['@mention', '@mention', '@mention', 'great', 'go', '@hashtag', '@emoji'],
#  ['@mention', '@mention', '@mention', 'sorry', 'mary', 'martin', 'first'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   'love',
#   'three',
#   'really',
#   'beat',
#   'classics'],
#  ['@mention',
#   'flight',
#   '@number',
#   'dal',
#   'dca',
#   '@number',
#   '@number',
#   '@number',
#   '@number',
#   'pm',
#   'tried',
#   'check',
#   'could',
#   'status',
#   'please'],
#  ['@mention',
#   'heyyyy',
#   'guyyyys',
#   'trying',
#   'get',
#   'hour',
#   'someone',
#   'call',
#   'please',
#   '@emoji'],
#  ['@mention',
#   'hi',
#   'virgin',
#   'hold',
#   '@number',
#   '@number',
#   'minutes',
#   'earlier',
#   'flights',
#   'la',
#   'nyc',
#   'tonight',
#   'earlier',
#   '@number',
#   '@number',
#   'pm'],
#  ['@mention',
#   'congrats',
#   'winning',
#   '@mention',
#   'award',
#   'best',
#   'deals',
#   'airline',
#   'us',
#   '@url'],
#  ['@mention', 'everything', 'fine', 'lost', 'bag'],
#  ['@mention',
#   'need',
#   'change',
#   'reservation',
#   'virgin',
#   'credit',
#   'card',
#   'need',
#   'modify',
#   'phone',
#   'waive',
#   'change',
#   'fee',
#   'online'],
#  ['@mention',
#   'emailed',
#   'customer',
#   'service',
#   'team',
#   'let',
#   'know',
#   'need',
#   'tracking',
#   'number'],
#  ['@mention', 'hi', 'booked', 'flight', 'need', 'add', 'baggage'],
#  ['@mention',
#   'airline',
#   'awesome',
#   'lax',
#   'loft',
#   'needs',
#   'step',
#   'game',
#   '@number',
#   'dirty',
#   'tables',
#   'floors',
#   '@url'],
#  ['@mention',
#   'worried',
#   'great',
#   'ride',
#   'new',
#   'plane',
#   'great',
#   'crew',
#   'airlines',
#   'like'],
#  ['@mention',
#   'awesome',
#   'flew',
#   'yall',
#   'sat',
#   'morning',
#   'way',
#   'correct',
#   'bill'],
#  ['@mention',
#   'watch',
#   'best',
#   'student',
#   'films',
#   'country',
#   '@number',
#   '@number',
#   'feet',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'first',
#   'time',
#   'flying',
#   'different',
#   'rate',
#   'policy',
#   'media',
#   'bags',
#   'thanks'],
#  ['@mention',
#   'going',
#   'customer',
#   'service',
#   'anyway',
#   'speak',
#   'human',
#   'asap',
#   'thank'],
#  ['@mention', 'happened', 'doom'],
#  ['@mention',
#   'supp',
#   'biz',
#   'traveler',
#   'like',
#   '@mention',
#   'customer',
#   'service',
#   'like',
#   '@mention',
#   '@hashtag'],
#  ['@mention',
#   'applied',
#   'member',
#   '@hashtag',
#   'crew',
#   'team',
#   'im',
#   '@number',
#   'interested',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'best',
#   'whenever',
#   'begrudgingly',
#   'use',
#   'airline',
#   'delayed',
#   'late',
#   'flight',
#   '@emoji'],
#  ['@mention',
#   'interesting',
#   'flying',
#   'cancelled',
#   'flight',
#   'next',
#   'four',
#   'flights',
#   'planned',
#   '@hashtag'],
#  ['@mention',
#   'disappointing',
#   'experience',
#   'shared',
#   'every',
#   'business',
#   'traveler',
#   'meet',
#   '@hashtag'],
#  ['@mention',
#   'im',
#   'trouble',
#   'adding',
#   'flight',
#   'wife',
#   'booked',
#   'elevate',
#   'account',
#   'help',
#   '@url'],
#  ['@mention',
#   'bring',
#   'reservation',
#   'online',
#   'using',
#   'flight',
#   'booking',
#   'problems',
#   'code'],
#  ['@mention',
#   'random',
#   'distribution',
#   'elevate',
#   'avatars',
#   'bet',
#   'kitty',
#   'disproportionate',
#   'share',
#   '@url'],
#  ['@mention',
#   'lt',
#   '@number',
#   'flying',
#   'va',
#   'life',
#   'happens',
#   'trying',
#   '@hashtag',
#   'trip',
#   'jperhi',
#   'help',
#   'va',
#   'home',
#   'page',
#   'let'],
#  ['@mention', 'site', 'back'],
#  ['@mention', 'rnp', 'yeah', 'know'],
#  ['@mention',
#   'hi',
#   'get',
#   'points',
#   'elevate',
#   'account',
#   'recent',
#   'flight',
#   'add',
#   'flight',
#   'points',
#   'account'],
#  ['@mention',
#   'like',
#   'tv',
#   'interesting',
#   'video',
#   'disappointed',
#   'cancelled',
#   'flightled',
#   'flight',
#   'flights',
#   'went',
#   'jfk',
#   'saturday'],
#  ['@mention',
#   'landed',
#   'lax',
#   'hour',
#   'late',
#   'flight',
#   'bag',
#   'check',
#   'business',
#   'travel',
#   'friendly',
#   '@hashtag'],
#  ['@mention', 'flight', '@number', 'redirected'],
#  ['@mention',
#   'website',
#   'btw',
#   'new',
#   'website',
#   'great',
#   'user',
#   'experience',
#   'time',
#   'another',
#   'redesign'],
#  ['@mention',
#   'check',
#   'add',
#   'bag',
#   'website',
#   'working',
#   'tried',
#   'desktop',
#   'mobile',
#   '@url'],
#  ['@mention',
#   'let',
#   '@number',
#   'scanned',
#   'passengers',
#   'leave',
#   'plane',
#   'told',
#   'someone',
#   'remove',
#   'bag',
#   '@number',
#   'st',
#   'class',
#   'bin',
#   '@hashtag'],
#  ['@mention', 'phone', 'number', 'find', 'call', 'flight', 'reservation'],
#  ['@mention',
#   'anyone',
#   'anything',
#   'today',
#   'website',
#   'useless',
#   'one',
#   'answering',
#   'phone'],
#  ['@mention',
#   'trying',
#   'add',
#   'boy',
#   'prince',
#   'ressie',
#   'sf',
#   'thursday',
#   '@mention',
#   'lax',
#   '@url'],
#  ['@mention',
#   'must',
#   'traveler',
#   'miss',
#   'flight',
#   'late',
#   'flight',
#   'check',
#   'bag',
#   'missed',
#   'morning',
#   'appointments',
#   'lost',
#   'business',
#   '@hashtag'],
#  ['@mention', 'check', 'new', 'music', '@url'],
#  ['@mention',
#   'direct',
#   'flight',
#   'fll',
#   'gt',
#   'sfo',
#   'unexpected',
#   'layover',
#   'vegas',
#   '@number',
#   'fuel',
#   'yet',
#   'peeps',
#   'next',
#   'bought',
#   'vegas',
#   'flight',
#   '@hashtag'],
#  ['@mention',
#   'late',
#   'flight',
#   'bag',
#   'check',
#   'lost',
#   'business',
#   'missed',
#   'flight',
#   'apt',
#   'three',
#   'people',
#   'flight',
#   'exp'],
#  ['@mention',
#   'amazing',
#   'customer',
#   'service',
#   '@emoji',
#   'raeann',
#   'sf',
#   'best',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention', 'called', 'service', 'line', 'hung', 'awesome', '@hashtag'],
#  ['@mention',
#   'site',
#   'tripping',
#   'trying',
#   'check',
#   'getting',
#   'plain',
#   'text',
#   'version',
#   'reluctant',
#   'enter',
#   'card',
#   'info'],
#  ['@mention',
#   'scheduled',
#   'sfo',
#   '@number',
#   'dal',
#   'flight',
#   '@number',
#   'today',
#   'changed',
#   '@number',
#   'th',
#   'due',
#   'weather',
#   'looks',
#   'like',
#   'flight',
#   'still'],
#  ['@mention',
#   'getaway',
#   'deals',
#   'may',
#   '@number',
#   'one',
#   'way',
#   'lots',
#   'cool',
#   'cities',
#   '@url',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'getaway',
#   'deals',
#   'may',
#   '@number',
#   'one',
#   'way',
#   'lots',
#   'cool',
#   'cities',
#   '@url',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'getaway',
#   'deals',
#   'may',
#   '@number',
#   'one',
#   'way',
#   'lots',
#   'cool',
#   'cities',
#   '@url',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'getaway',
#   'deals',
#   'may',
#   '@number',
#   'one',
#   'way',
#   'lots',
#   'cool',
#   'cities',
#   '@url',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention', 'great', 'week', '@emoji', '@emoji'],
#  ['@mention',
#   'come',
#   'back',
#   '@hashtag',
#   'already',
#   'need',
#   'take',
#   'us',
#   'horrible',
#   'cold',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'concerned',
#   'fly',
#   'plane',
#   'needs',
#   'delayed',
#   'due',
#   'tech',
#   'stop'],
#  ['@mention',
#   'best',
#   'airline',
#   'flown',
#   'easy',
#   'change',
#   'reservation',
#   'helpful',
#   'representatives',
#   'amp',
#   'comfortable',
#   'flying',
#   'experience'],
#  ['@mention',
#   'another',
#   'rep',
#   'kicked',
#   'butt',
#   'naelah',
#   'represents',
#   'team',
#   'beautifully',
#   'thank'],
#  ['@mention',
#   'beautiful',
#   'front',
#   'end',
#   'design',
#   'right',
#   'cool',
#   'still',
#   'book',
#   'ticket',
#   'back',
#   'end',
#   'secure'],
#  ['@mention',
#   'love',
#   'team',
#   'running',
#   'gate',
#   '@number',
#   'las',
#   'tonight',
#   'waited',
#   'delayed',
#   'flight',
#   'kept',
#   'things',
#   'entertaining'],
#  ['@mention',
#   'use',
#   'another',
#   'browser',
#   '@number',
#   'amp',
#   'brand',
#   'reputation',
#   'built',
#   'tech',
#   'response',
#   'cross',
#   'browser',
#   'compatible',
#   'website'],
#  ['@mention',
#   'flight',
#   'flight',
#   'booking',
#   'problems',
#   'site',
#   'totally',
#   'folks',
#   'problem'],
#  ['@mention',
#   'like',
#   'customer',
#   'service',
#   '@number',
#   'min',
#   'delay',
#   'connecting',
#   'passengers',
#   'seems',
#   'long',
#   'va',
#   '@number'],
#  ['@mention',
#   'thanks',
#   'outstanding',
#   'nyc',
#   'jfk',
#   'crew',
#   'moved',
#   'mountains',
#   'get',
#   'home',
#   'san',
#   'francisco',
#   'tonight'],
#  ['@mention',
#   'absolute',
#   'best',
#   'team',
#   'customer',
#   'service',
#   'ever',
#   'every',
#   'time',
#   'fly',
#   'delighted',
#   'thank'],
#  ['@mention',
#   'provide',
#   'complimentary',
#   'upgrades',
#   'first',
#   'class',
#   'available',
#   'seats'],
#  ['@mention',
#   'need',
#   'change',
#   'flight',
#   'thats',
#   'scheduled',
#   '@number',
#   'hours',
#   '@number',
#   'min',
#   'wait',
#   'time',
#   'phone',
#   'im',
#   'calling',
#   'intern',
#   'help'],
#  ['@mention',
#   'completely',
#   'awesome',
#   'experience',
#   'last',
#   'month',
#   'bos',
#   'las',
#   'nonstop',
#   'thanks',
#   'awesome',
#   'flight',
#   'depart',
#   'time',
#   '@hashtag'],
#  ['@mention', 'watch', '@hashtag', 'jfk', 'gt', 'sfo', 'flight'],
#  ['@mention', 'flight', '@number', 'cancelled', 'flightled'],
#  ['@mention',
#   'failing',
#   'customers',
#   'check',
#   'process',
#   'link',
#   'tsa',
#   'pre',
#   'check'],
#  ['@mention',
#   '@mention',
#   'us',
#   'terrible',
#   'airline',
#   'gave',
#   'us',
#   'hotel',
#   'hotline',
#   'number',
#   'said',
#   'sorry'],
#  ['@mention',
#   'flight',
#   'number',
#   '@number',
#   'sfo',
#   'cabo',
#   'san',
#   'lucas',
#   'arrived',
#   'yet'],
#  ['@mention',
#   '@mention',
#   'assistance',
#   'yesterday',
#   'cancelled',
#   'flightled',
#   'flight',
#   'give',
#   'us',
#   'hotel',
#   'hotline',
#   'shame'],
#  ['@mention', 'another', 'delayed', 'flight', '@hashtag'],
#  ['@mention',
#   'need',
#   'register',
#   'service',
#   'dog',
#   'first',
#   'class',
#   'ticket',
#   'sfo',
#   'gt',
#   'dulles',
#   'phone',
#   'queue',
#   'hour',
#   'longer',
#   'pls',
#   'advise'],
#  ['@mention',
#   'rock',
#   'making',
#   'watch',
#   '@hashtag',
#   'flight',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention', '@mention', 'dropped', 'track', '@url'],
#  ['@mention', 'always', 'xoxo'],
#  ['@mention',
#   'book',
#   'seats',
#   'flights',
#   'buy',
#   'even',
#   'check',
#   'creates',
#   'much',
#   'anxiety',
#   '@hashtag'],
#  ['@mention',
#   'think',
#   'paying',
#   'extra',
#   '@number',
#   'bucks',
#   'rt',
#   'luggage',
#   'might',
#   'afford',
#   'hiring',
#   'extra',
#   'hand',
#   '@mention',
#   '@hashtag'],
#  ['@mention',
#   'best',
#   'customer',
#   'service',
#   'rep',
#   'world',
#   '@hashtag',
#   'takes',
#   'cake'],
#  ['@mention',
#   'find',
#   'us',
#   'flt',
#   'lax',
#   'sooner',
#   'midnight',
#   'monday',
#   'would',
#   'great',
#   'customer',
#   'service',
#   '@emoji'],
#  ['@mention',
#   'please',
#   'provide',
#   'status',
#   'flight',
#   '@number',
#   'cant',
#   'imagine',
#   'time',
#   'web',
#   'indicates',
#   'dude',
#   'weather',
#   'dallas'],
#  ['@mention',
#   'amazing',
#   'staff',
#   'amp',
#   'super',
#   'helpful',
#   'ran',
#   '@mention',
#   '@hashtag',
#   'spoiled',
#   'comfort'],
#  ['@mention',
#   'paid',
#   'premium',
#   'fly',
#   'across',
#   'country',
#   'cancelled',
#   'flight',
#   'flight',
#   'offer',
#   'check',
#   'fee',
#   'upgrade',
#   'love',
#   'sad',
#   'face',
#   '@emoji'],
#  ['@mention',
#   'question',
#   'possible',
#   'book',
#   'seat',
#   'infant',
#   '@number',
#   'giving',
#   'option',
#   'want',
#   'seat'],
#  ['always', 'together', 'welcome', 'rt', '@mention', '@mention', 'welcome'],
#  ['@mention',
#   '@hashtag',
#   'home',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   'back',
#   '@hashtag',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'understand',
#   'need',
#   'dm',
#   'give',
#   'answer',
#   'damaged',
#   'luggage',
#   'policy'],
#  ['@mention', 'mean', 'policy', 'destroyed', 'luggage'],
#  ['@mention',
#   'special',
#   'assistance',
#   'travel',
#   'alone',
#   '@number',
#   'kids',
#   '@number',
#   'infant',
#   'priority',
#   'boarding'],
#  ['@mention',
#   'thank',
#   'checking',
#   'tickets',
#   'purchased',
#   'customer',
#   'happy',
#   '@emoji'],
#  ['@mention', 'website', 'ever', 'coming', 'back', 'online'],
#  ['@mention',
#   'flight',
#   '@number',
#   'love',
#   'field',
#   'sfo',
#   'definitely',
#   'cancelled',
#   'flightled',
#   'monday',
#   'february',
#   '@number'],
#  ['@mention', 'flight', '@number', 'lga', 'dfw', 'time'],
#  ['@mention',
#   'drivers',
#   'license',
#   'expired',
#   'little',
#   'month',
#   'fly',
#   'friday',
#   'morning',
#   'using',
#   'expired',
#   'license'],
#  ['@mention',
#   'problems',
#   'flight',
#   'booking',
#   'problems',
#   'web',
#   'site',
#   'keeps',
#   'giving',
#   'error',
#   'contact',
#   'phone',
#   'phone',
#   '@number',
#   'minute',
#   'wait'],
#  ['@mention',
#   'reschedule',
#   'cancelled',
#   'flightled',
#   'flights',
#   'online',
#   'change',
#   'button',
#   'greyed'],
#  ['@mention',
#   'rang',
#   'wait',
#   '@number',
#   'minutes',
#   'book',
#   'ticket',
#   'vendor',
#   'fix',
#   'site'],
#  ['@mention',
#   'got',
#   'flight',
#   'told',
#   '@number',
#   '@number',
#   'today',
#   'checked',
#   'email',
#   '@number',
#   '@number',
#   'tomorrow',
#   'unacceptable'],
#  ['@mention',
#   'flight',
#   'lga',
#   'cancelled',
#   'flighted',
#   'stuck',
#   'dallas',
#   'called',
#   'reschedule',
#   'told',
#   'could',
#   'get',
#   'flight',
#   'today',
#   '@number',
#   '@number'],
#  ['@mention',
#   'pairings',
#   'include',
#   'red',
#   'wine',
#   'white',
#   'offered',
#   '@emoji',
#   '@hashtag'],
#  ['@mention', 'website'],
#  ['@mention',
#   'site',
#   'seems',
#   'little',
#   'wonked',
#   'right',
#   'may',
#   'want',
#   'look',
#   'tried',
#   'two',
#   'browsers',
#   'css',
#   '@url'],
#  ['@mention',
#   'disappointed',
#   'agent',
#   'designated',
#   'silver',
#   'status',
#   'check',
#   'line',
#   '@mention',
#   'closed',
#   'assist',
#   'pasengers'],
#  ['@mention',
#   'plans',
#   'include',
#   'austin',
#   'dallas',
#   'route',
#   'topnews',
#   'arab',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'normal',
#   'receive',
#   'reply',
#   'central',
#   'baggage',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'logan',
#   'airport',
#   'waiting',
#   'checkin',
#   '@number',
#   'flight',
#   'checkin',
#   'desk',
#   'open'],
#  ['@mention', 'jump', 'dallas', 'austin', 'market', '@mention', '@url'],
#  ['@mention',
#   'beats',
#   'eps',
#   'views',
#   'takes',
#   '@hashtag',
#   'va',
#   'luv',
#   'investor',
#   'business',
#   'daily',
#   '@url'],
#  ['@mention', 'lister', 'show', 'monday', '@number', '@number'],
#  ['@mention',
#   'begin',
#   'dallas',
#   'austin',
#   '@hashtag',
#   'april',
#   '@number',
#   '@number',
#   'ketr',
#   '@url'],
#  ['@mention',
#   'congrats',
#   'got',
#   'business',
#   'ewr',
#   'sfo',
#   'lax',
#   'fuck',
#   '@mention',
#   'fl',
#   '@number',
#   'sfo',
#   'ewr',
#   'clincher'],
#  ['@mention',
#   'applied',
#   '@number',
#   'weeks',
#   'ago',
#   'heard',
#   'back',
#   'flying',
#   'week',
#   '@hashtag'],
#  ['@mention', 'love', 'know', 'policy', 'damaged', 'luggage'],
#  ['@mention', 'thank', 'follow'],
#  ['@mention',
#   'many',
#   'apologies',
#   'worse',
#   'airlines',
#   'even',
#   'respond',
#   'cudtomers'],
#  ['@mention',
#   'shame',
#   'va',
#   'making',
#   'people',
#   'spend',
#   'money',
#   'stranded',
#   'cities',
#   'airlines',
#   'landing',
#   'jfk',
#   'reimburse'],
#  ['@mention', '@mention', 'dm'],
#  ['@mention',
#   'please',
#   'flights',
#   'sjc',
#   'choice',
#   'fly',
#   'southwest',
#   'vegas',
#   '@emoji'],
#  ['@mention',
#   'bad',
#   'say',
#   'takes',
#   '@number',
#   '@number',
#   'days',
#   'via',
#   'confirmation',
#   'email',
#   'inquired',
#   '@number',
#   'weeks',
#   'claim',
#   '@number',
#   '@number',
#   'weeks'],
#  ['@mention',
#   'flight',
#   'bos',
#   'gt',
#   'las',
#   'tomorrow',
#   'cancelled',
#   'flightled',
#   'notification',
#   'wait',
#   'times',
#   '@number',
#   'hour',
#   'rebook',
#   'another',
#   'airline'],
#  ['@emoji',
#   'rt',
#   '@mention',
#   'met',
#   'match',
#   'got',
#   'status',
#   'another',
#   'airline',
#   'upgrade',
#   'restr',
#   '@url',
#   '@url'],
#  ['@mention', 'way', 'fly', '@hashtag', '@hashtag'],
#  ['@mention', 'guys', 'flights', 'cmh'],
#  ['@mention',
#   'lot',
#   'apologies',
#   'thrown',
#   'customers',
#   'see',
#   'sad',
#   'thanks',
#   'nothing',
#   'worst',
#   'airline',
#   'ever'],
#  ['@mention',
#   'flight',
#   'stuff',
#   'wrong',
#   'nothing',
#   '@hashtag',
#   '@hashtag',
#   'ever'],
#  ['@mention',
#   'issue',
#   'finding',
#   'missing',
#   'item',
#   'plane',
#   'help',
#   'find',
#   'airport',
#   'plane',
#   'headed',
#   'next'],
#  ['@mention', 'match', '@hashtag', 'status', 'cool'],
#  ['@emoji',
#   'met',
#   'match',
#   'got',
#   'status',
#   'another',
#   'airline',
#   'upgrade',
#   '@url',
#   '@mention',
#   '@emoji'],
#  ['@mention',
#   'trying',
#   'book',
#   'flight',
#   'guys',
#   'website',
#   'let',
#   'lose',
#   'business'],
#  ['@mention', 'suck'],
#  ['@mention', 'thanks'],
#  ['@mention', 'dm', 'issue', 'persisting'],
#  ['@mention',
#   'never',
#   'rec',
#   'cancelled',
#   'flightlation',
#   'notice',
#   'left',
#   'options',
#   'fly',
#   'ps',
#   'driving',
#   'la',
#   'red',
#   'eye',
#   'mon',
#   'kids'],
#  ['@mention', 'trying', 'book', 'flight', 'amp', 'site', '@emoji'],
#  ['@mention',
#   'flights',
#   'flying',
#   'boston',
#   'tomorrow',
#   'need',
#   'home',
#   'cancelled',
#   'flightled',
#   'flight',
#   'anything'],
#  ['@mention',
#   'stink',
#   'flight',
#   'cancelled',
#   'flighted',
#   'psp',
#   'jfk',
#   'notification',
#   'ability',
#   'rebook',
#   '@hashtag',
#   '@hashtag',
#   'better'],
#  ['@mention',
#   'love',
#   'guy',
#   'song',
#   'dancing',
#   'high',
#   'school',
#   'dance',
#   'revue'],
#  ['@mention', 'website', 'trying', 'check'],
#  ['@mention',
#   'done',
#   'thank',
#   'quick',
#   'response',
#   'apparently',
#   'faster',
#   'sitting',
#   'hold',
#   '@emoji'],
#  ['@mention',
#   'nervous',
#   'flight',
#   'dc',
#   'lax',
#   'getting',
#   'cancelled',
#   'flightled',
#   'tomorrow',
#   'sent',
#   'dm',
#   'help'],
#  ['@mention',
#   'cool',
#   'picture',
#   'another',
#   'virginamerica',
#   'plane',
#   'wing',
#   'site',
#   '@url'],
#  ['@mention', 'keep', 'great', 'work', '@emoji'],
#  ['@mention',
#   'goodness',
#   'people',
#   '@mention',
#   'field',
#   'amazing',
#   'pressure',
#   '@emoji',
#   'texas',
#   '@hashtag',
#   'crisis',
#   'please',
#   'fly',
#   'ny'],
#  ['@mention',
#   'thanks',
#   'great',
#   'flight',
#   'la',
#   'boston',
#   'pilots',
#   'great',
#   'job',
#   'landing',
#   'snow',
#   'go',
#   'back',
#   'la',
#   '@hashtag'],
#  ['@mention', 'please', 'get', 'new', 'york', 'area', 'monday', 'afternoon'],
#  ['@mention', 'thanks', 'much', 'awesome', 'support', 'guys', 'rock'],
#  ['@mention',
#   'seats',
#   'row',
#   '@number',
#   'recline',
#   'mention',
#   'website',
#   '@hashtag'],
#  ['@mention',
#   'flight',
#   '@number',
#   'delayed',
#   '@number',
#   'hours',
#   'la',
#   'due',
#   'mechanical',
#   'problems',
#   'handle',
#   'like',
#   'pros',
#   'could',
#   'tossed',
#   'us',
#   'free',
#   'drink'],
#  ['@mention',
#   'cancelled',
#   'flight',
#   'flights',
#   'today',
#   'precipitation',
#   'scared',
#   '@emoji'],
#  ['@mention',
#   'twitter',
#   'team',
#   'guys',
#   'killed',
#   'rescheduling',
#   'asap',
#   'thank'],
#  ['@mention',
#   'guys',
#   'charged',
#   '@number',
#   'reschedule',
#   'flight',
#   'cancelled',
#   'flighted',
#   'refusing',
#   'refund',
#   'deal'],
#  ['@mention',
#   'cant',
#   'access',
#   'website',
#   'safari',
#   'iphone',
#   '@number',
#   'seems',
#   'work',
#   'mac',
#   'ipad',
#   'need',
#   'iphone',
#   'add',
#   'passbook'],
#  ['@mention',
#   'ipad',
#   'iphone',
#   'clicking',
#   'checkin',
#   'link',
#   'email',
#   'received',
#   '@number',
#   'hrs',
#   'flight'],
#  ['@mention',
#   'mobile',
#   'site',
#   'broken',
#   'shows',
#   'header',
#   'elevateuser',
#   'numofpointsavailable',
#   '@number',
#   'number',
#   'points',
#   'let',
#   'checkin'],
#  ['@mention',
#   'really',
#   'looking',
#   'forward',
#   'flight',
#   'let',
#   'know',
#   'rescheduled',
#   '@hashtag'],
#  ['@mention',
#   'cancelled',
#   'flight',
#   'flight',
#   'vx',
#   '@number',
#   'one',
#   'sec',
#   'delayed',
#   'airport',
#   'next',
#   'cancelled',
#   'flightled',
#   'gonna',
#   'email',
#   'call',
#   'reschedule'],
#  ['@mention', 'problem', 'link', 'email', 'check', 'thanks'],
#  ['@mention',
#   'change',
#   'another',
#   'airline',
#   'get',
#   'dc',
#   'today',
#   '@mention',
#   'able',
#   'land',
#   'dc',
#   'cost',
#   '@number',
#   'ugh'],
#  ['@mention',
#   'looking',
#   'forward',
#   'first',
#   'flight',
#   'today',
#   'cancelled',
#   'flightled',
#   'along',
#   'subsequent',
#   'one'],
#  ['@mention',
#   'putting',
#   'great',
#   'deals',
#   'pdx',
#   'las',
#   'las',
#   'pdx',
#   'show',
#   'love',
#   '@url'],
#  ['@mention',
#   'wish',
#   'afford',
#   'fly',
#   'next',
#   'friday',
#   'going',
#   'back',
#   'home',
#   'love',
#   'everything',
#   'airline'],
#  ['@mention',
#   'gonna',
#   'deal',
#   'dallas',
#   'dc',
#   'deal',
#   'dc',
#   'dallas',
#   '@hashtag'],
#  ['@mention', 'bug', 'report', 'guys'],
#  ['@mention', 'hold', 'times', 'call', 'center', 'bit', 'much'],
#  ['@mention', 'like', '@url'],
#  ['@mention', 'site', '@hashtag'],
#  ['@mention', 'best', 'flight', 'attendant', 'ever', '@url'],
#  ['awesome',
#   'rt',
#   '@mention',
#   'watch',
#   'nominated',
#   'films',
#   '@number',
#   '@number',
#   'feet',
#   '@hashtag',
#   '@hashtag',
#   '@url'],
#  ['@mention', 'thanks', 'much'],
#  ['@mention',
#   'trying',
#   'reset',
#   'password',
#   'email',
#   'never',
#   'arrives',
#   'help'],
#  ['@mention',
#   'airline',
#   'based',
#   'silicon',
#   'valley',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@mention',
#   '@url'],
#  ['@mention', 'nicely', 'done', '@emoji'],
#  ['@mention',
#   'im',
#   'looking',
#   'forward',
#   'watching',
#   'oscars',
#   'flight',
#   'home',
#   'tomorrow',
#   'might',
#   'even',
#   'get',
#   'something',
#   'bubbly',
#   'drink',
#   '@emoji'],
#  ['@mention',
#   'reason',
#   'delay',
#   'departure',
#   'vx',
#   '@number',
#   'jfk',
#   'afternoon'],
#  ['@mention',
#   'todays',
#   'flight',
#   'palm',
#   'springs',
#   'ca',
#   'jfk',
#   'ny',
#   'cancelled',
#   'flightled'],
#  ['@mention', 'hahaha', '@emoji', 'guys', 'amazing', 'love', 'guys', '@emoji'],
#  ['@mention', 'sounds', 'like', 'fun'],
#  ['@mention', 'updates', 'flight', '@number', 'jfk', 'gt', 'lax'],
#  ['@mention', 'spruce', 'moose'],
#  ['@mention',
#   'css',
#   'site',
#   '@number',
#   'right',
#   'please',
#   'fix',
#   'site',
#   'unusable'],
#  ['@mention',
#   'flight',
#   '@number',
#   'vegas',
#   'boston',
#   'today',
#   'checked',
#   'online',
#   'bag',
#   'count',
#   'register',
#   'fix',
#   'somehow'],
#  ['@mention', 'classiq', 'luv', 'virgin', 'america', 'greetingz'],
#  ['@mention',
#   'hi',
#   'trying',
#   'check',
#   'website',
#   'working',
#   'tried',
#   '@number',
#   'different',
#   'browsers',
#   'problem',
#   'continues'],
#  ['@mention',
#   'thanks',
#   'great',
#   'customer',
#   'service',
#   'today',
#   'amp',
#   'helping',
#   'get',
#   'travel',
#   'sorted'],
#  ['@mention', 'thanks', 'guys', 'sweet', 'route', 'rockies', '@hashtag'],
#  ['@mention',
#   'love',
#   '@number',
#   'music',
#   'blasting',
#   'gate',
#   '@hashtag',
#   'waiting',
#   'flight',
#   '@hashtag',
#   'could',
#   'get',
#   'iced',
#   'coffee'],
#  ['@mention',
#   'passenger',
#   '@number',
#   'flt',
#   '@number',
#   'assaulted',
#   'flown',
#   'trust',
#   'banned',
#   'crew',
#   'filed',
#   'report',
#   '@mention'],
#  ['@mention',
#   'current',
#   'bug',
#   'website',
#   'shows',
#   'select',
#   'departure',
#   'city',
#   'selecting',
#   'destination',
#   'city',
#   '@url'],
#  ['@mention',
#   'luggage',
#   'severely',
#   'dented',
#   'missing',
#   'wheel',
#   'coming',
#   'baggage',
#   'claim',
#   'san',
#   'luggage',
#   'agent',
#   'miranda',
#   'think',
#   'help'],
#  ['@mention',
#   'thank',
#   'easy',
#   'itinerary',
#   'shift',
#   'impending',
#   'weather',
#   'quick',
#   'painless',
#   'amp',
#   'free'],
#  ['@mention',
#   'love',
#   'see',
#   'girls',
#   'inspired',
#   'become',
#   'pilots',
#   'rt',
#   'free',
#   'woaw',
#   'event',
#   'march',
#   '@number',
#   '@number',
#   'abq',
#   '@url'],
#  ['@mention',
#   'thanks',
#   'good',
#   'times',
#   'back',
#   '@hashtag',
#   'entire',
#   'flight',
#   '@emoji',
#   '@hashtag'],
#  ['@mention',
#   'beats',
#   'expectations',
#   'shares',
#   'take',
#   'santa',
#   'cruz',
#   'sentinel',
#   '@url'],
#  ['@mention', 'plans', 'start', 'flying', 'direct', 'dal', 'las'],
#  ['@mention',
#   'big',
#   'love',
#   'gratitude',
#   'mpower',
#   '@url',
#   'werin',
#   '@hashtag',
#   'vipswagbags@',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'great',
#   'job',
#   'adding',
#   'little',
#   'luxuries',
#   'aesthetics',
#   'improve',
#   'air',
#   'travel',
#   'experience',
#   'thank',
#   'keep'],
#  ['@mention',
#   'requested',
#   'window',
#   'seat',
#   'confirmed',
#   'window',
#   'got',
#   'stuck',
#   'middle',
#   'seat',
#   'good',
#   'way',
#   'treat',
#   'silver',
#   'member',
#   '@emoji'],
#  ['@mention', 'grand', 'budapest', 'hotel', '@hashtag'],
#  ['@mention', 'missed', '@mention', 'next', 'trip', '@number'],
#  ['@mention',
#   '@hashtag',
#   'paid',
#   'direct',
#   'flight',
#   'purpose',
#   'stop',
#   'fuel',
#   'exhausted',
#   'frequent',
#   'flier',
#   'nothing',
#   'inconvenience'],
#  ['@mention', 'something', 'wrong', 'website', 'safari', 'iphone'],
#  ['@mention',
#   'thanks',
#   'gate',
#   'checking',
#   'baggage',
#   'full',
#   'flight',
#   'dfw',
#   'lax',
#   '@number',
#   'giving',
#   'early',
#   'boarding',
#   '@hashtag'],
#  ['@mention', 'already', 'checked', 'page', 'expired', '@emoji'],
#  ['@mention',
#   'boo',
#   'refunding',
#   'seat',
#   'upgrade',
#   'fee',
#   'want',
#   'buy',
#   'first',
#   'place'],
#  ['@mention',
#   'shares',
#   'rise',
#   '@number',
#   'financial',
#   'results',
#   'usa',
#   'today',
#   '@url'],
#  ['@mention',
#   'adds',
#   'pillows',
#   'instead',
#   'lie',
#   'flat',
#   'seats',
#   'first',
#   'class',
#   'arms',
#   'race',
#   '@url'],
#  ['@mention', 'see', '@emoji'],
#  ['@mention', 'way', 'take', 'advantage', '@hashtag', '@emoji'],
#  ['@mention', 'know', 'flying', 'virgin', 'fight', '@hashtag'],
#  ['@mention', 'inflight', 'team', 'makes', 'experience', '@hashtag'],
#  ['@mention',
#   'cutest',
#   'salt',
#   'pepper',
#   'shaker',
#   'ever',
#   'think',
#   'guys',
#   'get',
#   'better',
#   '@url'],
#  ['@mention',
#   'moved',
#   'seat',
#   'notice',
#   'better',
#   'seat',
#   'cabin',
#   'select',
#   'behind',
#   'row',
#   'selected',
#   '@emoji',
#   '@hashtag'],
#  ['@mention', 'shares', '@number', 'results', '@mention', '@url'],
#  ['@mention', 'fav', 'airline'],
#  ['@mention', 'hot', 'female', 'pilot', 'sweet', 'dca', 'sfo', '@emoji'],
#  ['@emoji',
#   '@emoji',
#   'guys',
#   'going',
#   'start',
#   'flying',
#   'paris',
#   '@mention',
#   '@mention',
#   'welcome'],
#  ['@mention',
#   'policy',
#   'flying',
#   'surgery',
#   'still',
#   'waiting',
#   'answer',
#   'tell',
#   'doctor'],
#  ['@mention',
#   'already',
#   'contacted',
#   'central',
#   'baggage',
#   'amp',
#   'sent',
#   'dm',
#   '@mention',
#   'charging',
#   'dress',
#   'lost',
#   'suitcase',
#   '@hashtag'],
#  ['@mention', 'thank'],
#  ['@mention',
#   'anything',
#   'going',
#   'website',
#   'getting',
#   'lot',
#   'errors',
#   'past',
#   '@number',
#   'minutes'],
#  ['@mention',
#   'think',
#   'left',
#   'something',
#   'plane',
#   'yesterday',
#   'call',
#   'ah'],
#  ['@mention', 'need', 'follow', 'back', 'order', 'dm'],
#  ['@mention', 'need', 'start', 'flying', '@mention', '@emoji'],
#  ['@mention', 'told', 'check', 'airline', 'regulation', 'first', 'contacted'],
#  ['@mention',
#   '@mention',
#   'checked',
#   'flight',
#   'sfo',
#   'lax',
#   'amp',
#   'told',
#   'atlantic',
#   'flying',
#   'club',
#   'gold',
#   'get',
#   'benefits'],
#  ['@mention',
#   'husband',
#   'ordered',
#   'three',
#   'drinks',
#   'via',
#   'screen',
#   'never',
#   'came',
#   'awesome'],
#  ['@mention',
#   'soooo',
#   'guys',
#   'going',
#   'leave',
#   'seatbelt',
#   'light',
#   'flight',
#   'barely',
#   'call',
#   'turbulence',
#   '@emoji'],
#  ['@mention', 'policy', 'flying', 'surgery'],
#  ['@mention',
#   'posts',
#   'second',
#   'consecutive',
#   'full',
#   'year',
#   'net',
#   'profit',
#   '@mention',
#   '@url'],
#  ['@mention',
#   'funny',
#   'story',
#   'website',
#   'broken',
#   'missing',
#   'javascript',
#   'stylesheets',
#   'checkin',
#   'process',
#   'dislike'],
#  ['@mention', 'would', 'love', 'virgin', 'like', '@mention'],
#  ['@mention', 'results', 'handily', 'exceed', 'forecasts', '@mention', '@url'],
#  ['@mention',
#   'applied',
#   'position',
#   '@mention',
#   'wondering',
#   'guys',
#   'received',
#   'application'],
#  ['@mention',
#   'achieves',
#   'second',
#   'year',
#   'profitability',
#   'despite',
#   'revenue',
#   'pressure',
#   '@mention',
#   '@url'],
#  ['@mention',
#   'gives',
#   'positive',
#   'outlook',
#   'sees',
#   'increased',
#   'competition',
#   '@mention',
#   '@url'],
#  ['@mention',
#   'trying',
#   'check',
#   '@number',
#   '@number',
#   'ct',
#   'flight',
#   'tmm',
#   'desktop',
#   'website',
#   'working',
#   'sort',
#   'caching',
#   'bug',
#   'sos'],
#  ['@mention',
#   'weather',
#   'delays',
#   'gt',
#   'next',
#   'weeks',
#   '@emoji',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention', '@mention', 'check', 'website', 'go', 'airport'],
#  ['@mention', 'guys', 'know', 'check', 'links', 'emails', 'broken', '@url'],
#  ['@mention',
#   'pilot',
#   'says',
#   'expect',
#   'choppy',
#   'landing',
#   'nyc',
#   'due',
#   'gusty',
#   'winds',
#   'temperature',
#   '@number',
#   'degrees',
#   'amp',
#   'windchill',
#   '@number'],
#  ['@mention',
#   'loved',
#   'wait',
#   'monday',
#   'return',
#   'flight',
#   'mostly',
#   'watch',
#   'inflight',
#   'safety',
#   'video',
#   '@hashtag'],
#  ['@mention',
#   'lost',
#   'luggage',
#   '@number',
#   'days',
#   'ago',
#   'flight',
#   'vx',
#   '@number',
#   'lax',
#   'iad',
#   'amp',
#   'calling',
#   'every',
#   'day',
#   'response',
#   'please',
#   'give',
#   'back',
#   'stuff'],
#  ['@mention',
#   'flight',
#   'booking',
#   'problems',
#   'section',
#   'website',
#   'seems',
#   'broken',
#   'chrome',
#   'might',
#   'wanna',
#   'look'],
#  ['@mention',
#   'hi',
#   'wanted',
#   'see',
#   'new',
#   'routes',
#   'planned',
#   'year',
#   'newark',
#   'love',
#   'flying',
#   'guys',
#   'hope'],
#  ['@mention', 'mean', 'probably', 'inappropriate', 'board'],
#  ['@mention', 'happy', 'spend', 'day', 'together', 'let'],
#  ['@mention', 'saving', 'sanity', 'right', '@url'],
#  ['@mention', 'missed', 'flight', 'standby', 'work'],
#  ['@mention', 'understanding', 'helped', 'thx', '@hashtag'],
#  ['@mention', 'brought', 'way', 'across', 'country', 'today', 'see', '@url'],
#  ['@mention', 'thank', 'absolutely', '@emoji'],
#  ['@mention', 'looks', 'like', 'broken', 'link', 'assets', '@url'],
#  ['@mention',
#   'ready',
#   'let',
#   'say',
#   'together',
#   'noooo',
#   'turbulence',
#   'today',
#   '@emoji'],
#  ['@mention',
#   'manage',
#   'itinerary',
#   'section',
#   'website',
#   'seems',
#   'broken',
#   '@url'],
#  ['@mention',
#   'check',
#   'site',
#   'looks',
#   'like',
#   'every',
#   'time',
#   'loads',
#   '@url'],
#  ['@mention',
#   'help',
#   '@emoji',
#   '@mention',
#   'needs',
#   'urgent',
#   'treatment',
#   '@emoji',
#   'old',
#   'battling',
#   'cancer',
#   'could',
#   'help',
#   'flights',
#   '@emoji',
#   '@hashtag'],
#  ['@mention',
#   'may',
#   'start',
#   'service',
#   'hawaii',
#   '@hashtag',
#   'year',
#   '@url',
#   '@hashtag'],
#  ['@mention',
#   'carriers',
#   'less',
#   'half',
#   'price',
#   'round',
#   'trip',
#   'fare',
#   'stunned',
#   '@url'],
#  ['@mention',
#   'wtf',
#   'happening',
#   'pdx',
#   'late',
#   'flight',
#   'march',
#   'one',
#   'way',
#   'sfo',
#   '@number'],
#  ['@mention', 'add', 'dtw', 'sold'],
#  ['@mention', 'free', 'drinks', 'flight', 'back', 'free', 'promo'],
#  ['@mention', '@mention', 'thanks'],
#  ['@mention', 'momma', 'made', '@emoji'],
#  ['@mention',
#   'please',
#   'contact',
#   'portfolio',
#   'left',
#   'flight',
#   'vx',
#   '@number',
#   'jfk',
#   'sfo',
#   'tonite',
#   'seat',
#   '@number',
#   'need',
#   'returned',
#   'call',
#   '@number',
#   '@number',
#   '@number'],
#  ['@mention',
#   'help',
#   'flight',
#   '@number',
#   'jkf',
#   'tonight',
#   'seat',
#   '@number',
#   'left',
#   'portfolio',
#   'need',
#   'back'],
#  ['@mention',
#   '@mention',
#   'seattle',
#   'bound',
#   'wifey',
#   'got',
#   'duffle',
#   'vday',
#   'keeper',
#   'holla',
#   '@url'],
#  ['@mention',
#   'luggage',
#   'gone',
#   'filed',
#   'paperwork',
#   'promised',
#   'call',
#   'email',
#   'still',
#   'resolution',
#   'response',
#   'central',
#   'luggage'],
#  ['@mention',
#   'debbie',
#   'baldwin',
#   'gave',
#   '@hashtag',
#   'performance',
#   'safety',
#   'demo',
#   'evening',
#   'vx',
#   '@number',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention', 'thanks'],
#  ['@mention',
#   'thanks',
#   'taking',
#   'care',
#   '@mention',
#   'flight',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'thanks',
#   'lovely',
#   'soft',
#   'views',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'requested',
#   'mileage',
#   'challenge',
#   'status',
#   'several',
#   'weeks',
#   'ago',
#   'online',
#   'heard',
#   'back',
#   'get',
#   'help'],
#  ['@mention',
#   'trying',
#   'book',
#   'tickets',
#   'nyc',
#   'facing',
#   'super',
#   'fun',
#   'broken',
#   'styling',
#   'worry',
#   'keep',
#   'trying',
#   '@emoji'],
#  ['@mention',
#   'many',
#   'thanks',
#   'follow',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   'looking',
#   'help',
#   '@emoji',
#   '@emoji',
#   '@emoji',
#   '@url'],
#  ['@mention', 'nice', 'lofty', 'view', '@mention', '@hashtag', '@url'],
#  ['@mention',
#   'applied',
#   'status',
#   'match',
#   'feb',
#   '@number',
#   'got',
#   'confirmation',
#   'email',
#   'day',
#   'still',
#   'news',
#   'though',
#   'guys',
#   'dropped',
#   'ball',
#   'late',
#   'flightly',
#   '@emoji'],
#  ['@mention', 'new', 'go', 'airline'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   '@mention',
#   'help',
#   '@hashtag',
#   'need',
#   'help',
#   '@hashtag',
#   '@emoji',
#   '@url'],
#  ['@mention',
#   'adore',
#   'looking',
#   'forward',
#   'flight',
#   'austin',
#   'two',
#   'weeks'],
#  ['@mention',
#   'glad',
#   'mentioned',
#   'took',
#   'first',
#   'virgin',
#   'flight',
#   'years',
#   'back',
#   'transformative',
#   'experience'],
#  ['@mention',
#   'flight',
#   'booking',
#   'problems',
#   'flight',
#   'uphold',
#   'status',
#   'match',
#   'taxes',
#   'ticket',
#   'count',
#   'earned',
#   'status',
#   'points',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention', 'trying', 'check', 'looks', 'like', 'site'],
#  ['@mention', 'spending', 'birthday', 'night', 'dal', 'dca', 'get', 'home'],
#  ['@mention',
#   'sent',
#   'couple',
#   'messages',
#   'email',
#   'provided',
#   'avail',
#   'try',
#   'next',
#   'year',
#   'cheers'],
#  ['@mention',
#   'first',
#   'time',
#   'flying',
#   'virgin',
#   'went',
#   '@hashtag',
#   'thanks',
#   'smooth',
#   'ride',
#   'easily',
#   'new',
#   'fav',
#   'airline'],
#  ['@mention', 'seriously', 'though', 'direct', 'flights', 'sfo', 'fll', 'may'],
#  ['@mention',
#   'fine',
#   'already',
#   'done',
#   'purchase',
#   'try',
#   'go',
#   'way',
#   'go',
#   'back',
#   '@number'],
#  ['@mention',
#   'really',
#   'experience',
#   'hoping',
#   '@number',
#   'ws',
#   'forced',
#   '@number',
#   'check',
#   'small',
#   'carry',
#   'nothing',
#   'empty',
#   'cabin',
#   'space',
#   'board'],
#  ['@mention', 'wjere', 'luggage', '@hashtag', 'slow', 'lax'],
#  ['@mention', 'jump', '@hashtag', '@hashtag', 'market', '@url'],
#  ['@mention',
#   'spoke',
#   'representative',
#   'offered',
#   'solution',
#   'loyal',
#   'customer',
#   'flies',
#   '@mention',
#   'well'],
#  ['@mention',
#   'deeply',
#   'disappointed',
#   'birthday',
#   'promo',
#   'applied',
#   'trip',
#   'booked',
#   'mere',
#   'days',
#   'received',
#   'email'],
#  ['@mention',
#   'happened',
#   'direct',
#   'flights',
#   'sfo',
#   'fll',
#   'looking',
#   'may',
#   'see',
#   'connecting',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'help',
#   'left',
#   'blazer',
#   'kooples',
#   'jacket',
#   'bag',
#   '@number',
#   'rd',
#   'row',
#   'second',
#   'seat',
#   'right',
#   'gate',
#   '@number',
#   '@number',
#   'lax',
#   'flight',
#   'sfo'],
#  ['@mention',
#   'partners',
#   '@mention',
#   'checkout',
#   'mobile',
#   'payment',
#   'method',
#   'help',
#   'boost',
#   'mobile',
#   'conversion',
#   'rates',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'promoting',
#   'product',
#   'problem',
#   'southwest',
#   'recommend',
#   'noneother',
#   'best',
#   '@url'],
#  ['@mention', 'love', 'guys', 'pls', 'get', 'direct', 'routes', 'las', 'aus'],
#  ['@mention', 'would', 'like', 'help', 'flights', 'please'],
#  ['bruh', '@emoji', '@mention', 'turn', '@hashtag'],
#  ['@mention',
#   'course',
#   'work',
#   '@mention',
#   'obsessed',
#   'entire',
#   'virgin',
#   'family'],
#  ['@mention', 'ok', 'first', 'time', 'flying', 'tonight', '@emoji'],
#  ['@mention',
#   'digging',
#   'swanky',
#   'pink',
#   'mood',
#   'lighting',
#   'flight',
#   'nyc',
#   'sfo',
#   'needs',
#   'cabaret',
#   'singer',
#   'think'],
#  ['@mention',
#   'done',
#   'need',
#   'receipt',
#   'asap',
#   'could',
#   'please',
#   'help',
#   '@hashtag'],
#  ['@mention',
#   '@number',
#   '@number',
#   'embossed',
#   'badges',
#   'patches',
#   'superior',
#   'ones',
#   'currently',
#   'using',
#   '@url'],
#  ['@mention', 'vx', '@number', 'jfk', 'la', 'dirty', 'plane', 'standards'],
#  ['@mention',
#   'flight',
#   'vx',
#   '@number',
#   'headed',
#   'la',
#   'jfk',
#   'dirtiest',
#   'va',
#   'plane',
#   'ever',
#   'sad',
#   'great',
#   'airline'],
#  ['@mention',
#   'got',
#   'squared',
#   'away',
#   'someone',
#   'picked',
#   'soon',
#   'tweeted',
#   'tweeted',
#   'sooner',
#   '@emoji'],
#  ['@mention',
#   'avis',
#   'rental',
#   'continue',
#   'button',
#   'work',
#   'website',
#   'book',
#   'car',
#   'tried',
#   '@number',
#   'times',
#   'phone',
#   'sucks'],
#  ['@mention', 'delayed', '@number', '@number'],
#  ['@mention',
#   'currently',
#   'minute',
#   '@number',
#   'hold',
#   'cust',
#   'service',
#   'need',
#   'anything',
#   'add',
#   'lap',
#   'child',
#   'reservation'],
#  ['@mention',
#   'adds',
#   'pillows',
#   'instead',
#   'lie',
#   'flat',
#   'seats',
#   'first',
#   'class',
#   'arms',
#   'race',
#   '@url',
#   '@mention'],
#  ['@emoji',
#   '@mention',
#   'course',
#   'fun',
#   'celebrating',
#   'thanks',
#   'happy',
#   'chinese',
#   'new',
#   'year'],
#  ['@mention',
#   'flight',
#   'booking',
#   'problems',
#   'last',
#   'second',
#   'flight',
#   'next',
#   'week',
#   'sfo',
#   'san',
#   'chance',
#   'want',
#   'gift',
#   'promo',
#   'code',
#   'since',
#   'love',
#   'guys'],
#  ['@mention',
#   'comenity',
#   'bank',
#   'joke',
#   'please',
#   'change',
#   'nothing',
#   'constant',
#   'problems',
#   'bank'],
#  ['@mention', 'dm', 'also', 'add'],
#  ['@mention',
#   'grandma',
#   'ella',
#   '@number',
#   'th',
#   'would',
#   'lt',
#   '@number',
#   'bday',
#   'greeting',
#   'flight',
#   'crew',
#   'stewardess',
#   'eastern',
#   'airlines'],
#  ['@mention',
#   'bought',
#   'tix',
#   'atx',
#   'dallas',
#   'route',
#   'thanks',
#   'adding',
#   'love',
#   'yr',
#   'airline',
#   'amp',
#   'yr',
#   'website',
#   'best',
#   'transactional',
#   'site',
#   'ever'],
#  ['@mention', 'anytime', 'sugafly'],
#  ['@mention',
#   'gave',
#   'credit',
#   'late',
#   'flight',
#   'flight',
#   'yesterday',
#   'great',
#   'service',
#   'wow',
#   'moment',
#   'unexpected',
#   'gesture'],
#  ['@mention', 'need', 'receipt', 'flight', 'change', 'send', 'one'],
#  ['@mention',
#   'submitted',
#   'status',
#   'match',
#   'request',
#   'back',
#   'still',
#   'heard',
#   'im',
#   'flying',
#   'monday',
#   'look',
#   'accelerate'],
#  ['@mention',
#   'safety',
#   'video',
#   '@url',
#   'loved',
#   'first',
#   'cross',
#   'country',
#   'flight',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention', 'look', 'fat', 'looks', 'yummy'],
#  ['@mention',
#   'ceo',
#   'says',
#   '@hashtag',
#   'amp',
#   '@hashtag',
#   'strayed',
#   'low',
#   'cost',
#   'model',
#   '@url'],
#  ['@mention', 'brilliant', 'brisk', 'boston', 'cue', 'vx', '@number', '@url'],
#  ['@mention',
#   'atlantic',
#   'ploughs',
#   'lone',
#   'furrow',
#   '@hashtag',
#   '@url',
#   '@mention'],
#  ['@mention',
#   'atlantic',
#   'ploughs',
#   'lone',
#   'furrow',
#   '@hashtag',
#   '@url',
#   '@mention'],
#  ['@mention',
#   'atlantic',
#   'ploughs',
#   'lone',
#   'furrow',
#   '@hashtag',
#   '@url',
#   '@mention'],
#  ['@mention',
#   'omg',
#   'omg',
#   '@emoji',
#   'nonstop',
#   'dallas',
#   'austin',
#   'virgin',
#   '@emoji'],
#  ['@mention', 'planes', 'really', 'pretty', 'thought', 'know', '@emoji'],
#  ['@mention', 'flying', 'hawaii'],
#  ['@mention',
#   'pulling',
#   'hair',
#   'trying',
#   'book',
#   'flight',
#   'site',
#   'work',
#   'iphone',
#   'ipad',
#   'computer',
#   '@hashtag'],
#  ['@mention', 'thank'],
#  ['@mention',
#   'get',
#   'help',
#   'support',
#   'ticket',
#   '@number',
#   'days',
#   'incident',
#   '@number',
#   '@number',
#   'thank'],
#  ['@mention', 'good', 'home', '@hashtag', '@hashtag', '@url'],
#  ['@mention',
#   'cannot',
#   'even',
#   'open',
#   'laptop',
#   'seat',
#   '@number',
#   'paid',
#   'premium',
#   'let'],
#  ['@mention',
#   'seat',
#   '@number',
#   'cannot',
#   'even',
#   'open',
#   'laptop',
#   'paid',
#   'extra',
#   'seat'],
#  ['@mention',
#   'guys',
#   'starting',
#   'flights',
#   'end',
#   'month',
#   'guess',
#   'im',
#   'still',
#   'road',
#   'tripping',
#   'feb',
#   '@number'],
#  ['@mention',
#   'thanks',
#   'needing',
#   'way',
#   'make',
#   'austin',
#   'trips',
#   'dca',
#   'come'],
#  ['@mention',
#   'announced',
#   'new',
#   'route',
#   'austin',
#   'fares',
#   '@number',
#   'way',
#   '@url'],
#  ['@mention',
#   'really',
#   'sprint',
#   'thought',
#   'guys',
#   'kewl',
#   '@number',
#   '@number'],
#  ['@mention', 'cool', 'never', 'ur', 'planes'],
#  ['@mention', '@number', 'dollar', 'lax', 'las', 'fares'],
#  ['@mention', 'great', 'well', 'deserved'],
#  ['@mention',
#   'fyi',
#   'info@mention',
#   'email',
#   'address',
#   'say',
#   'contact',
#   'password',
#   'reset',
#   'emails',
#   'exist',
#   'emails',
#   'bounce'],
#  ['@mention',
#   'status',
#   'match',
#   '@number',
#   'weeks',
#   'gone',
#   'news',
#   'flt',
#   'next',
#   'week',
#   'hope',
#   'flt',
#   'count',
#   'towards',
#   'requirement',
#   'cust',
#   'svc',
#   'help'],
#  ['@mention',
#   'website',
#   'sucks',
#   'donkey',
#   'dicks',
#   'thought',
#   'know',
#   'best'],
#  ['@mention', 'still', 'develop', 'app', 'favorite', 'airline'],
#  ['@mention', 'crap', 'channels', 'pay', 'watch', 'uk', 'tv'],
#  ['@mention', 'got', 'set', 'thanks'],
#  ['@mention', 'channel', 'year'],
#  ['@mention',
#   'thing',
#   'see',
#   'passbook',
#   'virgin',
#   'mobile',
#   'mexico',
#   'integrate'],
#  ['@mention', 'giants', 'virgin', 'america', 'match', 'made', 'heaven'],
#  ['@mention',
#   'thank',
#   'goodness',
#   'also',
#   'see',
#   'friday',
#   'nwk',
#   'gt',
#   'sf',
#   'boom'],
#  ['@mention',
#   'come',
#   'iphone',
#   'app',
#   'still',
#   'using',
#   'making',
#   'waste',
#   'paper'],
#  ['@mention',
#   'back',
#   'seat',
#   'entertainment',
#   'system',
#   'accept',
#   'credit',
#   'cards',
#   'apostrophe',
#   'surname',
#   '@hashtag'],
#  ['@mention',
#   'vx',
#   'use',
#   '@number',
#   'lga',
#   'slots',
#   'instead',
#   '@number',
#   'today',
#   'adding',
#   'aus',
#   'makes',
#   'less',
#   'likely',
#   '@emoji'],
#  ['@mention',
#   'helping',
#   'step',
#   '@mention',
#   'game',
#   '@hashtag',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'luv',
#   'ur',
#   'people',
#   'product',
#   '@number',
#   'thing',
#   'charge',
#   'herbal',
#   'tea',
#   'black',
#   'tea',
#   'caffeine',
#   'drinker'],
#  ['@mention',
#   'thank',
#   'see',
#   'soon',
#   'excited',
#   'see',
#   'expansion',
#   'destinations',
#   'spread',
#   'wings'],
#  ['@mention',
# ...
#   'please',
#   'see',
#   '@url',
#   'jp',
#   'point',
#   'membership'],
#  ['@mention',
#   'wonderful',
#   'bag',
#   'claim',
#   'people',
#   'finally',
#   'bag',
#   'catch',
#   'earlier',
#   'flight',
#   'original',
#   'flight',
#   'landed',
#   '@hashtag'],
#  ['@mention', 'dmed', 'thank'],
#  ['@mention', 'thanks', 'touch'],
#  ['@mention',
#   'thanks',
#   'karen',
#   'salisbury',
#   'iah',
#   'amazing',
#   'customer',
#   'service',
#   'found',
#   'daughter',
#   'bag',
#   'lost',
#   'ua',
#   '@number',
#   'made',
#   'day'],
#  ['@mention',
#   '@number',
#   'days',
#   'late',
#   'flightr',
#   'bag',
#   'left',
#   'iad',
#   'united',
#   'helping',
#   'everyone',
#   'tells',
#   'different',
#   'story'],
#  ['@mention',
#   '@mention',
#   'hi',
#   'direct',
#   'flights',
#   'houston',
#   'reno',
#   'begin',
#   'see',
#   'days',
#   'march'],
#  ['@mention', 'like', 'continental', 'chicken', 'feat', 'fairs'],
#  ['@mention',
#   'assist',
#   'current',
#   'flight',
#   'status',
#   'flt',
#   '@number',
#   'dfw',
#   'tomorrow',
#   '@number',
#   '@number'],
#  ['@mention', 'left', 'comment', 'customer', 'care', 'thanks', 'contacting'],
#  ['@mention',
#   'lose',
#   'gate',
#   'checked',
#   'bag',
#   'den',
#   'ord',
#   'direct',
#   'flight',
#   'ugh'],
#  ['@mention',
#   'caught',
#   'earlier',
#   'flight',
#   'ord',
#   'gate',
#   'checked',
#   'bag',
#   'lost',
#   'hare',
#   'original',
#   'flight',
#   'lands',
#   '@number',
#   'minutes',
#   '@hashtag'],
#  ['yes',
#   'thanks',
#   'much',
#   '@emoji',
#   '@emoji',
#   '@mention',
#   'see',
#   'spoke',
#   'reservations',
#   'team',
#   'reinstated',
#   'flight',
#   'thanks',
#   'ey'],
#  ['@mention',
#   'captain',
#   'behalf',
#   'front',
#   'office',
#   'welcome',
#   'board',
#   'never',
#   'heard',
#   'laughed',
#   'hard',
#   '@hashtag'],
#  ['@mention', 'please', 'follow', 'dm', 'missing', 'bag'],
#  ['@mention',
#   'clear',
#   'luggage',
#   'comment',
#   'referencing',
#   'photo',
#   'attached',
#   'flight',
#   '@number',
#   'jac',
#   '@url'],
#  ['@mention', 'great', 'fares'],
#  ['@mention',
#   'left',
#   'item',
#   'plane',
#   'calling',
#   'non',
#   'stop',
#   'one',
#   'answering',
#   'please',
#   'help'],
#  ['@mention',
#   'awesome',
#   'book',
#   'next',
#   'christmas',
#   'vacatinn',
#   'december',
#   'ways',
#   'want',
#   'devalue',
#   'mileage',
#   'plus'],
#  ['@mention',
#   'good',
#   'number',
#   'call',
#   'speak',
#   'someone',
#   'fix',
#   '@number',
#   'people',
#   'luggage',
#   'saturday'],
#  ['@mention',
#   'thank',
#   'secured',
#   'room',
#   'night',
#   'thx',
#   'helpful',
#   'customer',
#   'service',
#   'rep',
#   'dorns',
#   'thanked',
#   '@number',
#   '@hashtag'],
#  ['@mention', 'damn', 'bag'],
#  ['@mention',
#   'well',
#   'someone',
#   'tell',
#   'employees',
#   'denver',
#   'baggage',
#   'claim',
#   'still',
#   'bag'],
#  ['@mention',
#   'greetings',
#   'ua',
#   'club',
#   'member',
#   'idea',
#   'use',
#   'air',
#   'canada',
#   'lounge',
#   'yvr',
#   'flying',
#   'ua',
#   'tomorrow'],
#  ['@mention', 'mexico', 'international', 'us'],
#  ['@mention',
#   'diverted',
#   'missed',
#   'connecting',
#   'flight',
#   'told',
#   'bag',
#   'way',
#   'msy',
#   'people',
#   'cared'],
#  ['@mention',
#   'male',
#   'agnt',
#   'las',
#   'threatens',
#   'canadian',
#   'cust',
#   'cust',
#   'takes',
#   'pic',
#   'gate',
#   'agents',
#   'announce',
#   'help',
#   'rebook',
#   '@hashtag'],
#  ['@mention',
#   '@mention',
#   'want',
#   'go',
#   'home',
#   'tonight',
#   'cancelled',
#   'flight',
#   'last',
#   'leg',
#   'reserv',
#   'permission',
#   '@hashtag'],
#  ['@mention',
#   'stressed',
#   'rude',
#   'agents',
#   'overwhelmed',
#   'delyd',
#   'flight',
#   'las',
#   'den',
#   '@number',
#   'yelling',
#   'several',
#   'people',
#   'pretty',
#   '@hashtag'],
#  ['@mention',
#   'landed',
#   'boston',
#   '@number',
#   'last',
#   'night',
#   '@number',
#   'hours',
#   'traveling',
#   'rough',
#   'tho'],
#  ['@mention',
#   'fail',
#   'cancelled',
#   'flightled',
#   'flight',
#   'frm',
#   'gjt',
#   'used',
#   'reserv',
#   'home',
#   'iah',
#   'sea',
#   'reflight',
#   'booking',
#   'problems',
#   'permission',
#   '@hashtag'],
#  ['sent',
#   'thank',
#   'rt',
#   '@mention',
#   '@mention',
#   'please',
#   'dm',
#   'confirmation',
#   'number',
#   'reflight',
#   'booking',
#   'problems',
#   'needed',
#   'thank',
#   'ey'],
#  ['@mention',
#   'made',
#   'fly',
#   'list',
#   'airlines',
#   'wait',
#   'connector',
#   'late',
#   'flight',
#   'stuck',
#   'iah'],
#  ['@mention',
#   'whats',
#   'deal',
#   'provide',
#   'voucher',
#   'overnight',
#   'cozy',
#   'floor',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'also',
#   'mere',
#   'fact',
#   'go',
#   'online',
#   'issue',
#   'statement',
#   'vice',
#   'calling',
#   'talking',
#   'directly',
#   'one',
#   'good',
#   'example'],
#  ['@mention', 'thank', 'flew', 'newark', 'vail', 'eagle'],
#  ['@mention', 'weekend', 'dealing', 'company', 'would', 'say', 'otherwise'],
#  ['@mention',
#   '@url',
#   'flight',
#   'gone',
#   'got',
#   'plane',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'proper',
#   'response',
#   'sorry',
#   'wait',
#   'flight',
#   'look',
#   'issue',
#   '@mention',
#   'would',
#   'handle'],
#  ['@mention',
#   'customer',
#   'service',
#   'terrible',
#   'stood',
#   'inline',
#   '@number',
#   'hours',
#   'flights',
#   '@number',
#   'hours',
#   'late',
#   'flightr',
#   'still',
#   'bag',
#   '@hashtag'],
#  ['@mention',
#   'please',
#   'upload',
#   'march',
#   'demand',
#   'entertainment',
#   'listing',
#   'website',
#   '@emoji'],
#  ['@mention', 'inadequate', 'accident'],
#  ['@mention',
#   '@mention',
#   '@mention',
#   'denver',
#   'international',
#   'airport',
#   '@url'],
#  ['@mention', 'thank', 'responding', 'quickly', 'helpful', 'tool', '@mention'],
#  ['@mention',
#   'boarding',
#   'time',
#   'shows',
#   '@number',
#   'min',
#   'gate',
#   'agent',
#   'started',
#   '@number',
#   'showed',
#   '@number',
#   '@number',
#   'check',
#   'bag',
#   '@url'],
#  ['@mention',
#   'agent',
#   'las',
#   'letting',
#   '@number',
#   'customers',
#   'know',
#   'help',
#   'rebook',
#   'delayed',
#   'flight',
#   'den',
#   '@hashtag',
#   '@url'],
#  ['@mention',
#   'empathizes',
#   'disappointment',
#   '@number',
#   'stclass',
#   'flight',
#   'nonworking',
#   'entertainmnt',
#   'worth',
#   '@number',
#   '@hashtag',
#   '@url'],
#  ['@mention', 'work'],
#  ['@mention',
#   'seen',
#   'message',
#   'today',
#   'mcdonnell',
#   'douglas',
#   'dc',
#   '@number',
#   'model',
#   'hear',
#   'read',
#   'goodnight'],
#  ['@mention',
#   'searched',
#   'mileage',
#   'tickets',
#   'bom',
#   'find',
#   'single',
#   'one',
#   'saver',
#   'awards',
#   'see',
#   'play',
#   'earn',
#   'miles',
#   'use'],
#  ['@mention',
#   'flight',
#   'arrives',
#   '@number',
#   'minutes',
#   'early',
#   'wait',
#   'hour',
#   'bags'],
#  ['@mention',
#   'issue',
#   'fact',
#   'one',
#   'even',
#   'called',
#   'despite',
#   'promises',
#   'confirm',
#   'bag',
#   'location'],
#  ['@mention',
#   'girl',
#   'gotta',
#   'get',
#   'flight',
#   'name',
#   'change',
#   'bought',
#   'one',
#   'mean',
#   'ex',
#   'boyfriend',
#   'needs',
#   'girl',
#   'trip',
#   'stat'],
#  ['@mention',
#   'thank',
#   'signed',
#   'notifications',
#   'shall',
#   'watch',
#   'wait',
#   '@emoji'],
#  ['@mention',
#   'still',
#   'waiting',
#   'hear',
#   'back',
#   'wallet',
#   'stolen',
#   'one',
#   'planes',
#   'would',
#   'appreciate',
#   'resolution'],
#  ['@mention',
#   'would',
#   'love',
#   'someone',
#   'could',
#   'get',
#   'back',
#   'austin',
#   'tonight',
#   'wish',
#   'wait',
#   'til',
#   'tomorrow',
#   'morning'],
#  ['@mention',
#   '@mention',
#   'lost',
#   'baggage',
#   'heard',
#   'different',
#   'things',
#   'different',
#   'employees',
#   '@mention',
#   '@mention',
#   'said',
#   'nothing'],
#  ['@mention',
#   'cs',
#   'thinks',
#   'miles',
#   'repair',
#   'damage',
#   'done',
#   'interesting',
#   'travel',
#   '@mention',
#   'exp',
#   'worst',
#   'flight',
#   'ever'],
#  ['@mention',
#   '@number',
#   'flight',
#   'dfw',
#   'tuesday',
#   'far',
#   'advance',
#   'give',
#   'notice',
#   'cancelled',
#   'flightled'],
#  ['@mention',
#   'signed',
#   'notifications',
#   'first',
#   'trip',
#   'updated',
#   'sure',
#   'happened'],
#  ['@mention',
#   'thank',
#   'took',
#   'care',
#   'everything',
#   'made',
#   'right',
#   'experience',
#   'used',
#   'opened',
#   'app',
#   'find',
#   'flight',
#   'changed'],
#  ['@mention',
#   'line',
#   'responses',
#   'waiting',
#   'tomorrow',
#   'morning',
#   'flights',
#   'overbooked'],
#  ['@mention',
#   'took',
#   'exact',
#   'aircraft',
#   'lax',
#   '@number',
#   'days',
#   'ago',
#   'fit',
#   'problem',
#   'agent',
#   'today',
#   'told',
#   'nonsense',
#   'policy',
#   'change'],
#  ['@mention',
#   'helpful',
#   'agents',
#   'club',
#   'helped',
#   'baggage',
#   'fees',
#   'night',
#   'life',
#   'stop',
#   'business',
#   '@mention'],
#  ['@mention', 'never', 'heard', '@url'],
#  ['@mention',
#   'charge',
#   'ticket',
#   'change',
#   'fees',
#   'incur',
#   'mysterious',
#   'costs',
#   'incur',
#   '@mention'],
#  ['@mention',
#   'exhausted',
#   'amp',
#   'frustrated',
#   'link',
#   'fb',
#   'post',
#   'abt',
#   'travel',
#   'issue',
#   '@url'],
#  ['@mention',
#   'denied',
#   'getting',
#   'plane',
#   'getting',
#   'chance',
#   'prove',
#   'fits',
#   'rookie',
#   'read',
#   'bio'],
#  ['@mention',
#   'exactly',
#   'point',
#   'fits',
#   'premier',
#   'access',
#   'boarding',
#   'group',
#   '@number',
#   'return',
#   'ticket',
#   '@number',
#   'yrs'],
#  ['@mention',
#   'never',
#   'experienced',
#   'worst',
#   'customer',
#   'service',
#   'placing',
#   'blame',
#   'codeshare',
#   'partners',
#   'assuming',
#   'responsibility',
#   'unacceptable'],
#  ['@mention',
#   'currently',
#   'board',
#   'check',
#   'terrible',
#   'staff',
#   'rude',
#   'expensive',
#   'luggage',
#   'thrown',
#   'around',
#   'etc'],
#  ['@mention',
#   'fucked',
#   'voided',
#   'ticket',
#   'kept',
#   'money',
#   'even',
#   'apology',
#   'never',
#   'fly',
#   'airline',
#   '@hashtag'],
#  ['@mention',
#   'worst',
#   'customer',
#   'svcs',
#   'kevin',
#   'rep',
#   'call',
#   'center',
#   'must',
#   'investigated',
#   'baggage',
#   'lost',
#   'help',
#   'argument'],
#  ['@mention',
#   'sell',
#   'tickets',
#   '@mention',
#   '@url',
#   'terrible',
#   'service',
#   'ua',
#   'staff',
#   'cannot',
#   'reach',
#   'silver'],
#  ['@mention',
#   'got',
#   'demoted',
#   'gold',
#   'cuz',
#   'hubby',
#   'got',
#   '@number',
#   'pqd',
#   'tho',
#   'enuf',
#   'spent',
#   '@number',
#   'golds',
#   '@hashtag'],
#  ['@mention', 'thank'],
#  ['@mention',
#   'direct',
#   'flights',
#   'belfast',
#   'intl',
#   'newark',
#   'resume',
#   'winter',
#   'break',
#   'thanks'],
#  ['@mention', 'favorite', 'way', 'travel', 'thank', '@url'],
#  ['@mention', 'yes', 'awful', 'weather', 'appears', 'get', 'home'],
#  ['@mention',
#   'yes',
#   'lots',
#   'terrible',
#   'customer',
#   'service',
#   'newark',
#   'despite',
#   'raising',
#   'complaint',
#   'ignored',
#   'hence',
#   'tweet'],
#  ['@mention', 'lovely', 'new', 'plane', 'lga', 'ord', 'power', 'outlets'],
#  ['@mention',
#   'tweet',
#   'id',
#   'number',
#   'reveal',
#   'home',
#   'address',
#   'anyone',
#   'web'],
#  ['@mention',
#   'filed',
#   'delayed',
#   'bag',
#   'report',
#   'saturday',
#   'flight',
#   'cancelled',
#   'flightled',
#   'never',
#   'went',
#   'anywhere'],
#  ['@mention',
#   'person',
#   'currently',
#   'bettween',
#   'gates',
#   '@number',
#   '@number',
#   'lax'],
#  ['@mention',
#   'need',
#   'lands',
#   'ewr',
#   'baggage',
#   'claim',
#   'file',
#   'sent',
#   'employee',
#   'droppeditoffyet'],
#  ['@mention',
#   'rarely',
#   'ceases',
#   'amaze',
#   'worse',
#   'hope',
#   'last',
#   'time',
#   'fly'],
#  ['@mention', 'thank', 'quick', 'response', 'cannot', 'dm', 'follow', 'well'],
#  ['@mention',
#   'icloud',
#   'yet',
#   'please',
#   'help',
#   '@number',
#   '@number',
#   '@number'],
#  ['@mention',
#   'need',
#   'phone',
#   'number',
#   'baggage',
#   'claim',
#   'lax',
#   'mom',
#   'left',
#   'phone',
#   'someone',
#   'called',
#   'saying',
#   'would',
#   'put'],
#  ['@mention', 'response', 'back'],
#  ['@mention', 'atrocious', 'customer', 'service'],
#  ['@mention',
#   'honor',
#   'absurdly',
#   'low',
#   'mistake',
#   'fares',
#   '@url',
#   'vì',
#   '@mention'],
#  ['@mention',
#   '@hashtag',
#   'delayed',
#   'departure',
#   'check',
#   'bags',
#   'gate',
#   'claiming',
#   'space',
#   'filled',
#   'walk',
#   'open',
#   'spaces',
#   'delay',
#   '@hashtag'],
#  ['@mention',
#   'cancelled',
#   'flighted',
#   'flights',
#   'reason',
#   'amp',
#   'phone',
#   'hour',
#   'vacation'],
#  ['@mention',
#   '@mention',
#   'response',
#   'shaking',
#   'head',
#   'back',
#   'forth',
#   'tsk',
#   'better',
#   'customer',
#   'service',
#   'apology'],
#  ['@mention',
#   'thanks',
#   '@number',
#   'miles',
#   'rtb',
#   'europe',
#   'multiple',
#   'destination',
#   'could',
#   'stop',
#   'us',
#   'way',
#   'way',
#   'back',
#   'mileage',
#   'diff'],
#  ['@mention', 'course', 'bag', '@emoji', '@hashtag'],
#  ['@mention', 'worst', 'avoid', 'like', 'plague'],
#  ['@mention', 'worst', 'airline', 'world'],
#  ['@mention',
#   'someone',
#   'needs',
#   'dm',
#   'resolve',
#   'correctly',
#   'extremely',
#   'disappointed',
#   'service',
#   'received',
#   'terrible',
#   'management'],
#  ['@mention',
#   'premier',
#   'gold',
#   'desk',
#   'changes',
#   'flight',
#   'waives',
#   'fees',
#   'gives',
#   'wrong',
#   'flight',
#   'jana',
#   'acosta',
#   'salt',
#   'lake',
#   'refuses',
#   'service',
#   'angry'],
#  ['@mention',
#   'give',
#   'one',
#   'thing',
#   'consistent',
#   'unfortunately',
#   'consistent',
#   'job',
#   'well',
#   '@hashtag'],
#  ['@mention', 'right', 'angry'],
#  ['@mention',
#   'first',
#   'time',
#   'flying',
#   'united',
#   'also',
#   'last',
#   'time',
#   '@hashtag',
#   'back',
#   '@mention',
#   '@hashtag',
#   '@hashtag',
#   '@hashtag'],
#  ['@mention',
#   'used',
#   'committed',
#   '@hashtag',
#   'flyer',
#   'merger',
#   'remember',
#   'switched',
#   '@mention',
#   '@hashtag'],
#  ['@mention',
#   'least',
#   'could',
#   'offer',
#   'ticket',
#   'coach',
#   'instead',
#   'cancelled',
#   'flighting',
#   'reservation',
#   'glitch',
#   '@hashtag'],
#  ['@mention',
#   'saying',
#   'made',
#   'flight',
#   'poor',
#   'non',
#   'communication',
#   'unaccounted',
#   'lost',
#   'time',
#   'amp',
#   'lots',
#   'frustrated',
#   'flyers',
#   'standing',
#   'around'],
#  ['@mention', 'think', 'dm', 'would', 'better'],
#  ['@mention',
#   'gate',
#   'announcement',
#   'states',
#   'delay',
#   'due',
#   'maintenance',
#   'yet',
#   'app',
#   'says',
#   'late',
#   'flight',
#   'arriving',
#   'aircraft',
#   'tell',
#   'truth',
#   '@mention'],
#  ['@mention',
#   'easily',
#   'worst',
#   'company',
#   'ever',
#   'experienced',
#   'lost',
#   'someone',
#   'personal',
#   'possessions',
#   'amp',
#   'care',
#   'less'],
#  ['@mention',
#   'app',
#   'show',
#   'arriving',
#   'aircraft',
#   'early',
#   'departing',
#   'flight',
#   'delayed',
#   'due',
#   'late',
#   'flight',
#   'arriving',
#   'aircraft',
#   '@mention'],
#  ['@mention',
#   'already',
#   'airport',
#   '@number',
#   'hrs',
#   'late',
#   'flightr',
#   'still',
#   'guys',
#   'really',
#   'killing',
#   'today',
#   'trying',
#   'stay',
#   'positive'],
#  ['@mention',
#   'united',
#   'service',
#   'levels',
#   'reaches',
#   'etihad',
#   'lets',
#   'realistically',
#   'lufthansa',
#   'ill',
#   'consider'],
#  ['@mention',
#   'really',
#   'someone',
#   'called',
#   'sick',
#   'someone',
#   'forgot',
#   'call',
#   'replacement',
#   'hour',
#   'late',
#   'flight',
#   'take',
#   '@hashtag'],
#  ['@mention',
#   'asked',
#   'flight',
#   'attendant',
#   'typical',
#   'compensation',
#   'would',
#   'amp',
#   'says',
#   'might',
#   'get',
#   'free',
#   'tv',
#   '@hashtag'],
#  ['@mention', 'done'],
#  ['@mention',
#   'thank',
#   'jh',
#   'appreciate',
#   'prompt',
#   'responses',
#   'passengers'],
#  ['@mention',
#   'disappointment',
#   'today',
#   'simply',
#   'put',
#   'rather',
#   'unpleased',
#   'things',
#   'currently',
#   'flight',
#   'delayed',
#   'cant',
#   'wait',
#   'get',
#   'home'],
#  ['@mention',
#   'round',
#   'trip',
#   'non',
#   'english',
#   'speaking',
#   'friend',
#   'stranded',
#   'twice',
#   '@number',
#   'hours',
#   'time',
#   'staff',
#   'members',
#   'rude'],
#  ['@mention',
#   'found',
#   'group',
#   'people',
#   'actually',
#   'hates',
#   'people',
#   'isis',
#   'thats',
#   'right',
#   'united',
#   'airlines'],
#  ['@mention',
#   'nope',
#   'walked',
#   'amp',
#   'orf',
#   'terminal',
#   'amp',
#   'united',
#   'agent',
#   'found',
#   'showed',
#   'last',
#   'minute',
#   'board',
#   'us',
#   'many',
#   'panicked',
#   'people'],
#  ['@mention', 'thank'],
#  ['@mention',
#   'time',
#   'finally',
#   'get',
#   'dallas',
#   'could',
#   'driven',
#   'less',
#   'frustration',
#   'cheaper'],
#  ['@mention',
#   'trying',
#   'get',
#   'final',
#   'destination',
#   'need',
#   'compensation',
#   '@number',
#   'hrs',
#   'personal',
#   'time',
#   'wasted'],
#  ['@mention',
#   'guy',
#   'really',
#   'customer',
#   'service',
#   'clue',
#   'could',
#   'spent',
#   'effort',
#   'clearing',
#   'bins',
#   'rollerboards',
#   'instead',
#   'art',
#   'projects',
#   'mine'],
#  ['@mention', 'priority', 'iove'],
#  ['@mention', 'pleased', 'premier', 'platinum'],
#  ...]

# %%
new_df["not_shortw"] = no_sw_ll

# %%
new_df.head()
# Out:
#                                                 text airline_sentiment  \
# 0                @VirginAmerica What @dhepburn said.           neutral
# 1  @VirginAmerica plus you've added commercials t...          positive
# 2  @VirginAmerica I didn't today... Must mean I n...           neutral
# 3  @VirginAmerica it's really aggressive to blast...          negative
# 4  @VirginAmerica and it's a really big bad thing...          negative
#
#   negativereason         airline  \
# 0            NaN  Virgin America
# 1            NaN  Virgin America
# 2            NaN  Virgin America
# 3     Bad Flight  Virgin America
# 4     Can't Tell  Virgin America
#
#                                         cleared_text  \
# 0                       @mention what @mention said
# 1  @mention plus you ve added commercials to the ...
# 2  @mention i didn t today must mean i need to ta...
# 3  @mention it s really aggressive to blast obnox...
# 4  @mention and it s a really big bad thing about it
#
#                                                no_sw  \
# 0                         [@mention, @mention, said]
# 1  [@mention, plus, added, commercials, experienc...
# 2  [@mention, today, must, mean, need, take, anot...
# 3  [@mention, really, aggressive, blast, obnoxiou...
# 4                [@mention, really, big, bad, thing]
#
#                                           not_shortw
# 0                         [@mention, @mention, said]
# 1  [@mention, plus, added, commercials, experienc...
# 2  [@mention, today, must, mean, need, take, anot...
# 3  [@mention, really, aggressive, blast, obnoxiou...
# 4                [@mention, really, big, bad, thing]

# %% [markdown]
# ## 5 - Lemmatization:
# 1) Lemmatization words in new_df["not_shortw"]

# %%
lemmatizer = WordNetLemmatizer()

# %%
def lemmatization(data, lemmatizer):
    new_words_lemm=[]
    for row in data:
        new_words_lemm_tmp=[]
        for word in row:
            lemm_word = lemmatizer.lemmatize(word)
            lemm_word = lemmatizer.lemmatize(lemm_word, pos='v')
            new_words_lemm_tmp.append(lemm_word)
        new_words_lemm.append(new_words_lemm_tmp)
    return new_words_lemm

# %%
new_df["lemmatized"] = lemmatization(new_df["not_shortw"], lemmatizer)

# %%
new_df.head()
# Out:
#                                                 text airline_sentiment  \
# 0                @VirginAmerica What @dhepburn said.           neutral
# 1  @VirginAmerica plus you've added commercials t...          positive
# 2  @VirginAmerica I didn't today... Must mean I n...           neutral
# 3  @VirginAmerica it's really aggressive to blast...          negative
# 4  @VirginAmerica and it's a really big bad thing...          negative
#
#   negativereason         airline  \
# 0            NaN  Virgin America
# 1            NaN  Virgin America
# 2            NaN  Virgin America
# 3     Bad Flight  Virgin America
# 4     Can't Tell  Virgin America
#
#                                         cleared_text  \
# 0                       @mention what @mention said
# 1  @mention plus you ve added commercials to the ...
# 2  @mention i didn t today must mean i need to ta...
# 3  @mention it s really aggressive to blast obnox...
# 4  @mention and it s a really big bad thing about it
#
#                                                no_sw  \
# 0                         [@mention, @mention, said]
# 1  [@mention, plus, added, commercials, experienc...
# 2  [@mention, today, must, mean, need, take, anot...
# 3  [@mention, really, aggressive, blast, obnoxiou...
# 4                [@mention, really, big, bad, thing]
#
#                                           not_shortw  \
# 0                         [@mention, @mention, said]
# 1  [@mention, plus, added, commercials, experienc...
# 2  [@mention, today, must, mean, need, take, anot...
# 3  [@mention, really, aggressive, blast, obnoxiou...
# 4                [@mention, really, big, bad, thing]
#
#                                           lemmatized
# 0                          [@mention, @mention, say]
# 1  [@mention, plus, add, commercial, experience, ...
# 2  [@mention, today, must, mean, need, take, anot...
# 3  [@mention, really, aggressive, blast, obnoxiou...
# 4                [@mention, really, big, bad, thing]

# %%
new_df.columns
# Out:
# Index(['text', 'airline_sentiment', 'negativereason', 'airline',
#        'cleared_text', 'no_sw', 'not_shortw', 'lemmatized'],
#       dtype='object')

# %%
new_col = []
for words in new_df["lemmatized"]:
    string_col = ""
    for word in words:
        string_col = string_col + word + " "
    new_col.append(string_col)

# %%
new_df["preprocessed_text"] = new_col

# %%
new_df['length'] = [len(t) for t in new_df.preprocessed_text]
new_df.head()
# Out:
#                                                 text airline_sentiment  \
# 0                @VirginAmerica What @dhepburn said.           neutral
# 1  @VirginAmerica plus you've added commercials t...          positive
# 2  @VirginAmerica I didn't today... Must mean I n...           neutral
# 3  @VirginAmerica it's really aggressive to blast...          negative
# 4  @VirginAmerica and it's a really big bad thing...          negative
#
#   negativereason         airline  \
# 0            NaN  Virgin America
# 1            NaN  Virgin America
# 2            NaN  Virgin America
# 3     Bad Flight  Virgin America
# 4     Can't Tell  Virgin America
#
#                                         cleared_text  \
# 0                       @mention what @mention said
# 1  @mention plus you ve added commercials to the ...
# 2  @mention i didn t today must mean i need to ta...
# 3  @mention it s really aggressive to blast obnox...
# 4  @mention and it s a really big bad thing about it
#
#                                                no_sw  \
# 0                         [@mention, @mention, said]
# 1  [@mention, plus, added, commercials, experienc...
# 2  [@mention, today, must, mean, need, take, anot...
# 3  [@mention, really, aggressive, blast, obnoxiou...
# 4                [@mention, really, big, bad, thing]
#
#                                           not_shortw  \
# 0                         [@mention, @mention, said]
# 1  [@mention, plus, added, commercials, experienc...
# 2  [@mention, today, must, mean, need, take, anot...
# 3  [@mention, really, aggressive, blast, obnoxiou...
# 4                [@mention, really, big, bad, thing]
#
#                                           lemmatized  \
# 0                          [@mention, @mention, say]
# 1  [@mention, plus, add, commercial, experience, ...
# 2  [@mention, today, must, mean, need, take, anot...
# 3  [@mention, really, aggressive, blast, obnoxiou...
# 4                [@mention, really, big, bad, thing]
#
#                                    preprocessed_text  length
# 0                             @mention @mention say       22
# 1     @mention plus add commercial experience tacky       46
# 2   @mention today must mean need take another trip       48
# 3  @mention really aggressive blast obnoxious ent...      88
# 4                     @mention really big bad thing       30

# %% [markdown]
# ## 6 - Store preprocessed data

# %%
def delet_tag(corpus):
    clear_text = []
    for phrase in corpus:
        # Replace the @
        phrase = re.sub("@\S+", "", phrase)
        clear_text.append(phrase)
    return clear_text

# %%
new_df["not_tag"] = delet_tag(new_df["preprocessed_text"])

# %%
final_df = pd.DataFrame({"original_text": new_df["text"], 
                         "preprocessed_text": new_df["preprocessed_text"], 
                         "length_text": new_df["length"],
                         "not_tag_text": new_df["not_tag"],
                         "airline": new_df["airline"], 
                         "airline_sentiment": new_df["airline_sentiment"], 
                         "negative_reason": new_df["negativereason"]})

# %%
final_df
# Out:
#                                            original_text  \
# 0                    @VirginAmerica What @dhepburn said.
# 1      @VirginAmerica plus you've added commercials t...
# 2      @VirginAmerica I didn't today... Must mean I n...
# 3      @VirginAmerica it's really aggressive to blast...
# 4      @VirginAmerica and it's a really big bad thing...
# ...                                                  ...
# 14635  @AmericanAir thank you we got on a different f...
# 14636  @AmericanAir leaving over 20 minutes Late Flig...
# 14637  @AmericanAir Please bring American Airlines to...
# 14638  @AmericanAir you have my money, you change my ...
# 14639  @AmericanAir we have 8 ppl so we need 2 know h...
#
#                                        preprocessed_text  length_text  \
# 0                                 @mention @mention say            22
# 1         @mention plus add commercial experience tacky            46
# 2       @mention today must mean need take another trip            48
# 3      @mention really aggressive blast obnoxious ent...           88
# 4                         @mention really big bad thing            30
# ...                                                  ...          ...
# 14635       @mention thank get different flight chicago            44
# 14636  @mention leave @number minute late flight warn...          113
# 14637   @mention please bring american airline @hashtag            48
# 14638  @mention money change flight answer phone sugg...           69
# 14639  @mention @number ppl need @number know many se...          106
#
#                                             not_tag_text         airline  \
# 0                                                   say   Virgin America
# 1                  plus add commercial experience tacky   Virgin America
# 2                today must mean need take another trip   Virgin America
# 3       really aggressive blast obnoxious entertainme...  Virgin America
# 4                                  really big bad thing   Virgin America
# ...                                                  ...             ...
# 14635                thank get different flight chicago         American
# 14636   leave  minute late flight warn communication ...        American
# 14637                    please bring american airline          American
# 14638   money change flight answer phone suggestion m...        American
# 14639    ppl need  know many seat next flight plz put...        American
#
#       airline_sentiment         negative_reason
# 0               neutral                     NaN
# 1              positive                     NaN
# 2               neutral                     NaN
# 3              negative              Bad Flight
# 4              negative              Can't Tell
# ...                 ...                     ...
# 14635          positive                     NaN
# 14636          negative  Customer Service Issue
# 14637           neutral                     NaN
# 14638          negative  Customer Service Issue
# 14639           neutral                     NaN
#
# [14640 rows x 7 columns]

# %%
final_df.to_csv("DataSet/final_dataset.csv", index=False)
